# %% [markdown]
# # Examples of Turing Machines
#
#
# You may wish to watch this video and then play with TM definitions.
#
# You may also wish to convert some "old fashioned" TMs (created before
# automd was designed) to the automd markdown syntax.

# %%
# This Youtube video walks through this notebook
from IPython.display import YouTubeVideo
YouTubeVideo('E1X8OTWUxJ0')

# %% [markdown]
# # Turing Machines

# %%
import sys
import os

#----TURN THESE ON IF RUNNING ON JOVE ON COLAB by removing the triple quotes

'''
! if [ ! -d Jove ]; then git clone https://github.com/ganeshutah/Jove Jove; fi
import sys
sys.path.append('./Jove')
sys.path.append('./Jove/jove')
from jove.Def_TM     import *
from jove.Def_md2mc  import *
from jove.DotBashers import *
from jove.JoveEditor import *
from jove.AnimateTM import * #-- usage: AnimateTM(whas101DTM, FuseEdges=True)
os.chdir('./Jove/First_Jove_Tutorial/CH13/')
#---- ALWAYS INCLUDE BEFORE ANY call such as AnimateNFA, AnimateDFA, etc ----
# Unfortunately this has to be within EACH iframe... so can't hard-wire
# into the Animate... functions
display(HTML('<link rel="stylesheet" href="//stackpath.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css"/>'))
'''

#----TURN THESE ON IF RUNNING ON OWN INSTALLATION (default turned-on)

sys.path[0:0] = ['../..','../../3rdparty'] # Put these at the head of the search path
from jove.Def_TM     import *
from jove.Def_md2mc  import *
from jove.DotBashers import *
from jove.JoveEditor import *
from jove.AnimateTM import * #-- usage: AnimateTM(whas101DTM, FuseEdges=True)


#---- COMMON IMPORTS BELOW : Add more/less imports as needed/tolerable ---

# EMPTY imports for TM...
# Out:
# You may use any of these help commands:
# help(step_tm)
# help(run_tm)
# help(explore_tm)
#
# You may use any of these help commands:
# help(md2mc)
# .. and if you want to dig more, then ..
# help(default_line_attr)
# help(length_ok_input_items)
# help(union_line_attr_list_fld)
# help(extend_rsltdict)
# help(form_delta)
# help(get_machine_components)
#
# You may use any of these help commands:
# help(ResetStNum)
# help(NxtStateStr)

# %% [markdown]
# # Various DTMs and NDTMs below

# %%
flipperTM = md2mc('''TM
I : . ; ., S -> F
I : 0 ; 1, R -> I
I : 1 ; 0, R -> I
''')
DOflipperTM = dotObj_tm(flipperTM, FuseEdges=True)
DOflipperTM

# %%
explore_tm(flipperTM, "010011", 100)
# Out:
# Allocating  8  tape cells to the RIGHT!
# Detailing the halted configs now.
# Accepted at  ('F', 6, '101100........', 93)
#  via ..
#  ->('I', 0, '010011', 100)
#  ->('I', 1, '110011', 99)
#  ->('I', 2, '100011', 98)
#  ->('I', 3, '101011', 97)
#  ->('I', 4, '101111', 96)
#  ->('I', 5, '101101', 95)
#  ->('I', 6, '101100', 94)
#  ->('F', 6, '101100........', 93)

# %%
help(explore_tm)
# Out:
# Help on function explore_tm in module jove.Def_TM:
#
# explore_tm(T, tape, nsteps)
#     A handy routine to print the result of run_tm plus making
#     future extensions to explore run-results.

# %%
# The following display(...) call is needed to see the animation buttons in Colab
display(HTML('<link rel="stylesheet" href="//stackpath.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css"/>'))
AnimateTM(flipperTM, FuseEdges=True)
# Out:
# <link rel="stylesheet" href="//stackpath.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css"/>
# VBox(children=(HBox(children=(Text(value='', description='Input:', layout=Layout(width='500px'), placeholder='…

# %%
wpw_tm = md2mc(src='File', fname="wpw.tm")
dotObj_tm(wpw_tm, FuseEdges = True)

# %%
DOwpw = dotObj_tm(wpw_tm, FuseEdges = True)

# %%
explore_tm(wpw_tm, "001#001", 120)
# Out:
# Allocating  8  tape cells to the RIGHT!
# Detailing the halted configs now.
# Accepted at  ('Fq6', 8, 'XXY#XXY........', 88)
#  via ..
#  ->('Iq0', 0, '001#001', 120)
#  ->('q1', 1, 'X01#001', 119)
#  ->('q1', 2, 'X01#001', 118)
#  ->('q1', 3, 'X01#001', 117)
#  ->('q2', 4, 'X01#001', 116)
#  ->('q3', 3, 'X01#X01', 115)
#  ->('q4', 2, 'X01#X01', 114)
#  ->('q4', 1, 'X01#X01', 113)
#  ->('q4', 0, 'X01#X01', 112)
#  ->('Iq0', 1, 'X01#X01', 111)
#  ->('q1', 2, 'XX1#X01', 110)
#  ->('q1', 3, 'XX1#X01', 109)
#  ->('q2', 4, 'XX1#X01', 108)
#  ->('q2', 5, 'XX1#X01', 107)
#  ->('q3', 4, 'XX1#XX1', 106)
#  ->('q3', 3, 'XX1#XX1', 105)
#  ->('q4', 2, 'XX1#XX1', 104)
#  ->('q4', 1, 'XX1#XX1', 103)
#  ->('Iq0', 2, 'XX1#XX1', 102)
#  ->('q7', 3, 'XXY#XX1', 101)
#  ->('q8', 4, 'XXY#XX1', 100)
#  ->('q8', 5, 'XXY#XX1', 99)
#  ->('q8', 6, 'XXY#XX1', 98)
#  ->('q3', 5, 'XXY#XXY', 97)
#  ->('q3', 4, 'XXY#XXY', 96)
#  ->('q3', 3, 'XXY#XXY', 95)
#  ->('q4', 2, 'XXY#XXY', 94)
#  ->('Iq0', 3, 'XXY#XXY', 93)
#  ->('q5', 4, 'XXY#XXY', 92)
#  ->('q5', 5, 'XXY#XXY', 91)
#  ->('q5', 6, 'XXY#XXY', 90)
#  ->('q5', 7, 'XXY#XXY', 89)
#  ->('Fq6', 8, 'XXY#XXY........', 88)

# %%
# The following display(...) call is needed to see the animation buttons in Colab
display(HTML('<link rel="stylesheet" href="//stackpath.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css"/>'))

#---SET FUEL TO 100 OR SO, else there will be no animation shown---
AnimateTM(wpw_tm, FuseEdges=True)
# Out:
# <link rel="stylesheet" href="//stackpath.bootstrapcdn.com/font-awesome/4.7.0/css/font-awesome.min.css"/>
# VBox(children=(HBox(children=(Text(value='', description='Input:', layout=Layout(width='500px'), placeholder='…

# %%
wwndtm_md = md2mc(src='File', fname="wwndtm.tm")
dotObj_tm(wwndtm_md)

# %%
DOwwndtm = dotObj_tm(wwndtm_md, FuseEdges=True)
DOwwndtm

# %%
explore_tm(wwndtm_md, "001001", 170)
# Out:
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the RIGHT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the RIGHT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# Detailing the halted configs now.
# Rejected at  ('q14', 6, '001001', 163)
#  via ..
#  ->('Iq0', 0, '001001', 170)
#  ->('q14', 0, '001001', 169)
#  ->('q14', 1, '001001', 168)
#  ->('q14', 2, '001001', 167)
#  ->('q14', 3, '001001', 166)
#  ->('q14', 4, '001001', 165)
#  ->('q14', 5, '001001', 164)
#  ->('q14', 6, '001001', 163)
# Rejected at  ('q4', 13, '........P0100Y', 152)
#  via ..
#  ->('Iq0', 0, '001001', 170)
#  ->('q14', 0, '001001', 169)
#  ->('q14', 1, '001001', 168)
#  ->('q14', 2, '001001', 167)
#  ->('q14', 3, '001001', 166)
#  ->('q14', 4, '001001', 165)
#  ->('q14', 5, '001001', 164)
#  ->('q2', 4, '00100Y', 163)
#  ->('q2', 3, '00100Y', 162)
#  ->('q2', 2, '00100Y', 161)
#  ->('q2', 1, '00100Y', 160)
#  ->('q2', 0, '00100Y', 159)
#  ->('q2', 7, '........00100Y', 158)
#  ->('q3', 8, '........00100Y', 157)
#  ->('q4', 9, '........P0100Y', 156)
#  ->('q4', 10, '........P0100Y', 155)
#  ->('q4', 11, '........P0100Y', 154)
#  ->('q4', 12, '........P0100Y', 153)
#  ->('q4', 13, '........P0100Y', 152)
# Rejected at  ('q4', 13, '........PP102Y', 144)
#  via ..
#  ->('Iq0', 0, '001001', 170)
#  ->('q14', 0, '001001', 169)
#  ->('q14', 1, '001001', 168)
#  ->('q14', 2, '001001', 167)
#  ->('q14', 3, '001001', 166)
#  ->('q14', 4, '001001', 165)
#  ->('q2', 3, '0010X1', 164)
#  ->('q2', 2, '0010X1', 163)
#  ->('q2', 1, '0010X1', 162)
#  ->('q2', 0, '0010X1', 161)
#  ->('q2', 7, '........0010X1', 160)
#  ->('q3', 8, '........0010X1', 159)
#  ->('q4', 9, '........P010X1', 158)
#  ->('q4', 10, '........P010X1', 157)
#  ->('q4', 11, '........P010X1', 156)
#  ->('q4', 12, '........P010X1', 155)
#  ->('q10', 13, '........P01021', 154)
#  ->('q8', 12, '........P0102Y', 153)
#  ->('q8', 11, '........P0102Y', 152)
#  ->('q8', 10, '........P0102Y', 151)
#  ->('q8', 9, '........P0102Y', 150)
#  ->('q8', 8, '........P0102Y', 149)
#  ->('q3', 9, '........P0102Y', 148)
#  ->('q4', 10, '........PP102Y', 147)
#  ->('q4', 11, '........PP102Y', 146)
#  ->('q4', 12, '........PP102Y', 145)
#  ->('q4', 13, '........PP102Y', 144)
# Accepted at  ('Fq13', 15, '........PPQ223........', 130)
#  via ..
#  ->('Iq0', 0, '001001', 170)
#  ->('q14', 0, '001001', 169)
#  ->('q14', 1, '001001', 168)
#  ->('q14', 2, '001001', 167)
#  ->('q14', 3, '001001', 166)
#  ->('q2', 2, '001X01', 165)
#  ->('q2', 1, '001X01', 164)
#  ->('q2', 0, '001X01', 163)
#  ->('q2', 7, '........001X01', 162)
#  ->('q3', 8, '........001X01', 161)
#  ->('q4', 9, '........P01X01', 160)
#  ->('q4', 10, '........P01X01', 159)
#  ->('q4', 11, '........P01X01', 158)
#  ->('q10', 12, '........P01201', 157)
#  ->('q8', 11, '........P012X1', 156)
#  ->('q8', 10, '........P012X1', 155)
#  ->('q8', 9, '........P012X1', 154)
#  ->('q8', 8, '........P012X1', 153)
#  ->('q3', 9, '........P012X1', 152)
#  ->('q4', 10, '........PP12X1', 151)
#  ->('q4', 11, '........PP12X1', 150)
#  ->('q4', 12, '........PP12X1', 149)
#  ->('q10', 13, '........PP1221', 148)
#  ->('q8', 12, '........PP122Y', 147)
#  ->('q8', 11, '........PP122Y', 146)
#  ->('q8', 10, '........PP122Y', 145)
#  ->('q8', 9, '........PP122Y', 144)
#  ->('q3', 10, '........PP122Y', 143)
#  ->('q5', 11, '........PPQ22Y', 142)
#  ->('q5', 12, '........PPQ22Y', 141)
#  ->('q5', 13, '........PPQ22Y', 140)
#  ->('q11', 14, '........PPQ223', 139)
#  ->('q9', 13, '........PPQ223........', 138)
#  ->('q9', 12, '........PPQ223........', 137)
#  ->('q9', 11, '........PPQ223........', 136)
#  ->('q9', 10, '........PPQ223........', 135)
#  ->('q3', 11, '........PPQ223........', 134)
#  ->('q12', 12, '........PPQ223........', 133)
#  ->('q12', 13, '........PPQ223........', 132)
#  ->('q12', 14, '........PPQ223........', 131)
#  ->('Fq13', 15, '........PPQ223........', 130)
# Rejected at  ('q4', 10, '........P0Y001', 161)
#  via ..
#  ->('Iq0', 0, '001001', 170)
#  ->('q14', 0, '001001', 169)
#  ->('q14', 1, '001001', 168)
#  ->('q14', 2, '001001', 167)
#  ->('q2', 1, '00Y001', 166)
#  ->('q2', 0, '00Y001', 165)
#  ->('q2', 7, '........00Y001', 164)
#  ->('q3', 8, '........00Y001', 163)
#  ->('q4', 9, '........P0Y001', 162)
#  ->('q4', 10, '........P0Y001', 161)
# Rejected at  ('q12', 10, '........P2Y001', 159)
#  via ..
#  ->('Iq0', 0, '001001', 170)
#  ->('q14', 0, '001001', 169)
#  ->('q14', 1, '001001', 168)
#  ->('q2', 0, '0X1001', 167)
#  ->('q2', 7, '........0X1001', 166)
#  ->('q3', 8, '........0X1001', 165)
#  ->('q4', 9, '........PX1001', 164)
#  ->('q10', 10, '........P21001', 163)
#  ->('q8', 9, '........P2Y001', 162)
#  ->('q8', 8, '........P2Y001', 161)
#  ->('q3', 9, '........P2Y001', 160)
#  ->('q12', 10, '........P2Y001', 159)
# Rejected at  ('q6', 9, '........X01001', 166)
#  via ..
#  ->('Iq0', 0, '001001', 170)
#  ->('q14', 0, '001001', 169)
#  ->('q2', 7, '........X01001', 168)
#  ->('q3', 8, '........X01001', 167)
#  ->('q6', 9, '........X01001', 166)

# %%
#---SET FUEL TO 100 OR SO, else there will be no animation shown---
AnimateTM(wwndtm_md, FuseEdges=True)
# Out:
# VBox(children=(HBox(children=(Text(value='', description='Input:', layout=Layout(width='500px'), placeholder='…

# %%
Jaddtm = md2mc('''TM

# !!-------------------------------------------------------------------------------
# !! Designed by Ian Briggs, PhD student, SoC, Univ of Utah
# !! 
# !!  M adds two numbers in base 2.
# !!
# !! Input: matches the regex [01][01]*\+[01][01]*
# !!        Interpreted as a+b where a and b are unsigned integers in big-endian
# !!          form.
# !! Start:  Starts in Istart
# !! Output: Occurs on a halt in the Fdone state.
# !!         The sum of the numbers in big endian form.
# !!         No other characters will be on the tape.
# !!         There willbe no leading zeros on the answer.
# !! Errors: The only errors that can occur are input errors which lead to
# !!           a halt on the error state. This indicates the input does
# !!           not conform to the input requirement.
# !! Detail: There is no length maximums on the input.
# !!         The numbers can be of different lengths.
# !!         Leading zeros on inputs only cause a longer runtime.
# !!-------------------------------------------------------------------------------

# !! Begin input validation

        Istart:  . ;  ., S  -> error 
        Istart:  + ;  ., S -> error
        Istart:  0 ;  0, R -> check_a
        Istart:  1 ;  1, R -> check_a
        
 # !!
         check_a: 0 ;  0, R -> check_a
         check_a: 1 ;  1, R -> check_a
         check_a: . ;  ., S -> error
         check_a: + ;  a, R -> check_b_start
 
 # !!
         check_b_start: 0 ;  0, R -> check_b
         check_b_start: 1 ;  1, R -> check_b
         check_b_start: . ;  ., S -> error
         check_b_start: + ;  +, S -> error
 
 # !!
         check_b: 0 ;  0, R -> check_b
         check_b: 1 ;  1, R -> check_b
         check_b: . ;  b, L -> read_next_b_digit
         check_b: + ;  +, S -> error
 
 # !! End input validation
 
 
 # !! Begin adder
         read_next_b_digit: 0 ;  X, L -> 0_scan_to_a
         read_next_b_digit: 1 ;  Y, L -> 1_scan_to_a
 
 # !!
         0_scan_to_a: 0 ;  0, L -> 0_scan_to_a
         0_scan_to_a: 1 ;  1, L -> 0_scan_to_a
         0_scan_to_a: a ;  a, L -> 0_scan_to_a_digit
 
 # !!
         1_scan_to_a: 0 ;  0, L -> 1_scan_to_a
         1_scan_to_a: 1 ;  1, L -> 1_scan_to_a
         1_scan_to_a: a ;  a, L -> 1_scan_to_a_digit
 
 # !!
         n_scan_to_a: 0 ;  0, L -> n_scan_to_a
         n_scan_to_a: 1 ;  1, L -> n_scan_to_a
         n_scan_to_a: a ;  a, L -> n_scan_to_a_digit
 
 # !!
         0_scan_to_a_digit: X ;  X, L -> 0_scan_to_a_digit
         0_scan_to_a_digit: Y ;  Y, L -> 0_scan_to_a_digit
         0_scan_to_a_digit: 0 ;  X, R -> 0_scan_to_output
         0_scan_to_a_digit: 1 ;  Y, R -> 1_scan_to_output
         0_scan_to_a_digit: . ;  s, R -> 0_scan_to_output
         0_scan_to_a_digit: s ;  s, R -> 0_scan_to_output
 
 # !!
         1_scan_to_a_digit: X ;  X, L -> 1_scan_to_a_digit
         1_scan_to_a_digit: Y ;  Y, L -> 1_scan_to_a_digit
         1_scan_to_a_digit: 0 ;  X, R -> 1_scan_to_output
         1_scan_to_a_digit: 1 ;  Y, R -> c0_scan_to_output
         1_scan_to_a_digit: . ;  s, R -> 1_scan_to_output
         1_scan_to_a_digit: s ;  s, R -> 1_scan_to_output
 
 # !!
         n_scan_to_a_digit: X ;  X, L -> n_scan_to_a_digit
         n_scan_to_a_digit: Y ;  Y, L -> n_scan_to_a_digit
         n_scan_to_a_digit: 0 ;  X, R -> 0_scan_to_output
         n_scan_to_a_digit: 1 ;  Y, R -> 1_scan_to_output
         n_scan_to_a_digit: . ;  s, R -> erase_until_sum
         n_scan_to_a_digit: s ;  s, R -> erase_until_sum
 
 # !!
         0_scan_to_output: 0 ;  0, R -> 0_scan_to_output
         0_scan_to_output: 1 ;  1, R -> 0_scan_to_output
         0_scan_to_output: X ;  X, R -> 0_scan_to_output
         0_scan_to_output: Y ;  Y, R -> 0_scan_to_output
         0_scan_to_output: a ;  a, R -> 0_scan_to_output
         0_scan_to_output: b ;  b, R -> 0_scan_to_output
         0_scan_to_output: . ;  0, L -> scan_to_b
         0_scan_to_output: c ;  1, L -> scan_to_b
 
 # !!
         1_scan_to_output: 0 ;  0, R -> 1_scan_to_output
         1_scan_to_output: 1 ;  1, R -> 1_scan_to_output
         1_scan_to_output: X ;  X, R -> 1_scan_to_output
         1_scan_to_output: Y ;  Y, R -> 1_scan_to_output
         1_scan_to_output: a ;  a, R -> 1_scan_to_output
         1_scan_to_output: b ;  b, R -> 1_scan_to_output
         1_scan_to_output: . ;  1, L -> scan_to_b
         1_scan_to_output: c ;  0, R -> write_carry
 
 # !!
         c0_scan_to_output: 0 ;  0, R -> c0_scan_to_output
         c0_scan_to_output: 1 ;  1, R -> c0_scan_to_output
         c0_scan_to_output: X ;  X, R -> c0_scan_to_output
         c0_scan_to_output: Y ;  Y, R -> c0_scan_to_output
         c0_scan_to_output: a ;  a, R -> c0_scan_to_output
         c0_scan_to_output: b ;  b, R -> c0_scan_to_output
         c0_scan_to_output: . ;  0, R -> write_carry
         c0_scan_to_output: c ;  1, R -> write_carry
 
 # !!
         write_carry: . ;  c, L -> scan_to_b
 
 # !!
         scan_to_b: 0 ;  0, L -> scan_to_b
         scan_to_b: 1 ;  1, L -> scan_to_b
         scan_to_b: b ;  b, L -> scan_to_b_digit
 
 # !!
         scan_to_b_digit: X ;  X, L -> scan_to_b_digit
         scan_to_b_digit: Y ;  Y, L -> scan_to_b_digit
         scan_to_b_digit: 0 ;  0, S -> read_next_b_digit
         scan_to_b_digit: 1 ;  1, S -> read_next_b_digit
         scan_to_b_digit: a ;  a, S -> n_scan_to_a
 
 # !! End adder
 
 # !! Begin answer formatting
         erase_until_sum: 0 ;  ., R -> erase_until_sum
         erase_until_sum: 1 ;  ., R -> erase_until_sum
         erase_until_sum: X ;  ., R -> erase_until_sum
         erase_until_sum: Y ;  ., R -> erase_until_sum
         erase_until_sum: a ;  ., R -> erase_until_sum
         erase_until_sum: b ;  ., R -> find_end_of_sum
 
 # !!
         find_end_of_sum: 0 ;  0, R -> find_end_of_sum
         find_end_of_sum: 1 ;  1, R -> find_end_of_sum
         find_end_of_sum: c ;  1, S -> read_msb_of_sum
         find_end_of_sum: . ;  ., L -> read_msb_of_sum
 
 # !!
         read_msb_of_sum: 0 ;  ., L -> 0_check_end_of_sum
         read_msb_of_sum: 1 ;  ., L -> 1_check_end_of_sum
 
 # !!
         0_check_end_of_sum: 0 ;  0, L -> 0_find_end_of_sum
         0_check_end_of_sum: 1 ;  1, L -> 0_find_end_of_sum
         0_check_end_of_sum: . ;  ., L -> 0_write_last_digit
 
 # !!
         1_check_end_of_sum: 0 ;  0, L -> 1_find_end_of_sum
         1_check_end_of_sum: 1 ;  1, L -> 1_find_end_of_sum
         1_check_end_of_sum: . ;  ., L -> 1_write_last_digit
 
 # !!
         0_write_last_digit: . ;  ., L -> 0_write_last_digit
         0_write_last_digit: 0 ;  0, R -> write_last_0
         0_write_last_digit: 1 ;  1, R -> write_last_0
         0_write_last_digit: s ;  ., R -> write_last_0
 
 # !!
         1_write_last_digit: . ;  ., L -> 1_write_last_digit
         1_write_last_digit: 0 ;  0, R -> write_last_1
         1_write_last_digit: 1 ;  1, R -> write_last_1
         1_write_last_digit: s ;  ., R -> write_last_1
 
 # !!
         write_last_0: . ;  0, S -> find_start_of_answer
 
 # !!
         write_last_1: . ;  1, S -> find_start_of_answer
 
 # !!
         0_find_end_of_sum: 0 ;  0, L -> 0_find_end_of_sum
         0_find_end_of_sum: 1 ;  1, L -> 0_find_end_of_sum
         0_find_end_of_sum: . ;  ., L -> 0_find_answer
 
 # !!
         1_find_end_of_sum: 0 ;  0, L -> 1_find_end_of_sum
         1_find_end_of_sum: 1 ;  1, L -> 1_find_end_of_sum
         1_find_end_of_sum: . ;  ., L -> 1_find_answer
 
 # !!
         0_find_answer: . ;  ., L -> 0_find_answer
         0_find_answer: 0 ;  0, R -> write_0
         0_find_answer: 1 ;  1, R -> write_0
         0_find_answer: s ;  ., R -> write_0
 
 # !!
         1_find_answer: . ;  ., L -> 1_find_answer
         1_find_answer: 0 ;  0, R -> write_1
         1_find_answer: 1 ;  1, R -> write_1
         1_find_answer: s ;  ., R -> write_1
 
 # !!
         write_0: . ;  0, R -> find_start_of_sum
 
 # !!
         write_1: . ;  1, R -> find_start_of_sum
 
 # !!
         find_start_of_sum: . ;  ., R -> find_start_of_sum
         find_start_of_sum: 0 ;  0, S -> find_end_of_sum
         find_start_of_sum: 1 ;  1, S -> find_end_of_sum
 
 # !!
         find_start_of_answer: 0 ;  0, L -> find_start_of_answer
         find_start_of_answer: 1 ;  1, L -> find_start_of_answer
         find_start_of_answer: . ;  ., R -> erase_leading_zeros
 


# !!- !!
         erase_leading_zeros: 0 ;  ., R -> erase_leading_zeros
         erase_leading_zeros: 1 ;  1, S -> Fdone
         erase_leading_zeros: . ;  0, S -> Fdone
 
 # !! End answer formatting
 
 ''')

# %%
dotObj_tm(Jaddtm, FuseEdges=True)

# %%
explore_tm(Jaddtm, "1+111", 735)
# Out:
# Allocating  8  tape cells to the RIGHT!
# Allocating  8  tape cells to the LEFT!
# Detailing the halted configs now.
# Accepted at  ('Fdone', 8, '........1000.........', 592)
#  via ..
#  ->('Istart', 0, '1+111', 735)
#  ->('check_a', 1, '1+111', 734)
#  ->('check_b_start', 2, '1a111', 733)
#  ->('check_b', 3, '1a111', 732)
#  ->('check_b', 4, '1a111', 731)
#  ->('check_b', 5, '1a111', 730)
#  ->('read_next_b_digit', 4, '1a111b.......', 729)
#  ->('1_scan_to_a', 3, '1a11Yb.......', 728)
#  ->('1_scan_to_a', 2, '1a11Yb.......', 727)
#  ->('1_scan_to_a', 1, '1a11Yb.......', 726)
#  ->('1_scan_to_a_digit', 0, '1a11Yb.......', 725)
#  ->('c0_scan_to_output', 1, 'Ya11Yb.......', 724)
#  ->('c0_scan_to_output', 2, 'Ya11Yb.......', 723)
#  ->('c0_scan_to_output', 3, 'Ya11Yb.......', 722)
#  ->('c0_scan_to_output', 4, 'Ya11Yb.......', 721)
#  ->('c0_scan_to_output', 5, 'Ya11Yb.......', 720)
#  ->('c0_scan_to_output', 6, 'Ya11Yb.......', 719)
#  ->('write_carry', 7, 'Ya11Yb0......', 718)
#  ->('scan_to_b', 6, 'Ya11Yb0c.....', 717)
#  ->('scan_to_b', 5, 'Ya11Yb0c.....', 716)
#  ->('scan_to_b_digit', 4, 'Ya11Yb0c.....', 715)
#  ->('scan_to_b_digit', 3, 'Ya11Yb0c.....', 714)
#  ->('read_next_b_digit', 3, 'Ya11Yb0c.....', 713)
#  ->('1_scan_to_a', 2, 'Ya1YYb0c.....', 712)
#  ->('1_scan_to_a', 1, 'Ya1YYb0c.....', 711)
#  ->('1_scan_to_a_digit', 0, 'Ya1YYb0c.....', 710)
#  ->('1_scan_to_a_digit', 7, '........Ya1YYb0c.....', 709)
#  ->('1_scan_to_output', 8, '.......sYa1YYb0c.....', 708)
#  ->('1_scan_to_output', 9, '.......sYa1YYb0c.....', 707)
#  ->('1_scan_to_output', 10, '.......sYa1YYb0c.....', 706)
#  ->('1_scan_to_output', 11, '.......sYa1YYb0c.....', 705)
#  ->('1_scan_to_output', 12, '.......sYa1YYb0c.....', 704)
#  ->('1_scan_to_output', 13, '.......sYa1YYb0c.....', 703)
#  ->('1_scan_to_output', 14, '.......sYa1YYb0c.....', 702)
#  ->('1_scan_to_output', 15, '.......sYa1YYb0c.....', 701)
#  ->('write_carry', 16, '.......sYa1YYb00.....', 700)
#  ->('scan_to_b', 15, '.......sYa1YYb00c....', 699)
#  ->('scan_to_b', 14, '.......sYa1YYb00c....', 698)
#  ->('scan_to_b', 13, '.......sYa1YYb00c....', 697)
#  ->('scan_to_b_digit', 12, '.......sYa1YYb00c....', 696)
#  ->('scan_to_b_digit', 11, '.......sYa1YYb00c....', 695)
#  ->('scan_to_b_digit', 10, '.......sYa1YYb00c....', 694)
#  ->('read_next_b_digit', 10, '.......sYa1YYb00c....', 693)
#  ->('1_scan_to_a', 9, '.......sYaYYYb00c....', 692)
#  ->('1_scan_to_a_digit', 8, '.......sYaYYYb00c....', 691)
#  ->('1_scan_to_a_digit', 7, '.......sYaYYYb00c....', 690)
#  ->('1_scan_to_output', 8, '.......sYaYYYb00c....', 689)
#  ->('1_scan_to_output', 9, '.......sYaYYYb00c....', 688)
#  ->('1_scan_to_output', 10, '.......sYaYYYb00c....', 687)
#  ->('1_scan_to_output', 11, '.......sYaYYYb00c....', 686)
#  ->('1_scan_to_output', 12, '.......sYaYYYb00c....', 685)
#  ->('1_scan_to_output', 13, '.......sYaYYYb00c....', 684)
#  ->('1_scan_to_output', 14, '.......sYaYYYb00c....', 683)
#  ->('1_scan_to_output', 15, '.......sYaYYYb00c....', 682)
#  ->('1_scan_to_output', 16, '.......sYaYYYb00c....', 681)
#  ->('write_carry', 17, '.......sYaYYYb000....', 680)
#  ->('scan_to_b', 16, '.......sYaYYYb000c...', 679)
#  ->('scan_to_b', 15, '.......sYaYYYb000c...', 678)
#  ->('scan_to_b', 14, '.......sYaYYYb000c...', 677)
#  ->('scan_to_b', 13, '.......sYaYYYb000c...', 676)
#  ->('scan_to_b_digit', 12, '.......sYaYYYb000c...', 675)
#  ->('scan_to_b_digit', 11, '.......sYaYYYb000c...', 674)
#  ->('scan_to_b_digit', 10, '.......sYaYYYb000c...', 673)
#  ->('scan_to_b_digit', 9, '.......sYaYYYb000c...', 672)
#  ->('n_scan_to_a', 9, '.......sYaYYYb000c...', 671)
#  ->('n_scan_to_a_digit', 8, '.......sYaYYYb000c...', 670)
#  ->('n_scan_to_a_digit', 7, '.......sYaYYYb000c...', 669)
#  ->('erase_until_sum', 8, '.......sYaYYYb000c...', 668)
#  ->('erase_until_sum', 9, '.......s.aYYYb000c...', 667)
#  ->('erase_until_sum', 10, '.......s..YYYb000c...', 666)
#  ->('erase_until_sum', 11, '.......s...YYb000c...', 665)
#  ->('erase_until_sum', 12, '.......s....Yb000c...', 664)
#  ->('erase_until_sum', 13, '.......s.....b000c...', 663)
#  ->('find_end_of_sum', 14, '.......s......000c...', 662)
#  ->('find_end_of_sum', 15, '.......s......000c...', 661)
#  ->('find_end_of_sum', 16, '.......s......000c...', 660)
#  ->('find_end_of_sum', 17, '.......s......000c...', 659)
#  ->('read_msb_of_sum', 17, '.......s......0001...', 658)
#  ->('1_check_end_of_sum', 16, '.......s......000....', 657)
#  ->('1_find_end_of_sum', 15, '.......s......000....', 656)
#  ->('1_find_end_of_sum', 14, '.......s......000....', 655)
#  ->('1_find_end_of_sum', 13, '.......s......000....', 654)
#  ->('1_find_answer', 12, '.......s......000....', 653)
#  ->('1_find_answer', 11, '.......s......000....', 652)
#  ->('1_find_answer', 10, '.......s......000....', 651)
#  ->('1_find_answer', 9, '.......s......000....', 650)
#  ->('1_find_answer', 8, '.......s......000....', 649)
#  ->('1_find_answer', 7, '.......s......000....', 648)
#  ->('write_1', 8, '..............000....', 647)
#  ->('find_start_of_sum', 9, '........1.....000....', 646)
#  ->('find_start_of_sum', 10, '........1.....000....', 645)
#  ->('find_start_of_sum', 11, '........1.....000....', 644)
#  ->('find_start_of_sum', 12, '........1.....000....', 643)
#  ->('find_start_of_sum', 13, '........1.....000....', 642)
#  ->('find_start_of_sum', 14, '........1.....000....', 641)
#  ->('find_end_of_sum', 14, '........1.....000....', 640)
#  ->('find_end_of_sum', 15, '........1.....000....', 639)
#  ->('find_end_of_sum', 16, '........1.....000....', 638)
#  ->('find_end_of_sum', 17, '........1.....000....', 637)
#  ->('read_msb_of_sum', 16, '........1.....000....', 636)
#  ->('0_check_end_of_sum', 15, '........1.....00.....', 635)
#  ->('0_find_end_of_sum', 14, '........1.....00.....', 634)
#  ->('0_find_end_of_sum', 13, '........1.....00.....', 633)
#  ->('0_find_answer', 12, '........1.....00.....', 632)
#  ->('0_find_answer', 11, '........1.....00.....', 631)
#  ->('0_find_answer', 10, '........1.....00.....', 630)
#  ->('0_find_answer', 9, '........1.....00.....', 629)
#  ->('0_find_answer', 8, '........1.....00.....', 628)
#  ->('write_0', 9, '........1.....00.....', 627)
#  ->('find_start_of_sum', 10, '........10....00.....', 626)
#  ->('find_start_of_sum', 11, '........10....00.....', 625)
#  ->('find_start_of_sum', 12, '........10....00.....', 624)
#  ->('find_start_of_sum', 13, '........10....00.....', 623)
#  ->('find_start_of_sum', 14, '........10....00.....', 622)
#  ->('find_end_of_sum', 14, '........10....00.....', 621)
#  ->('find_end_of_sum', 15, '........10....00.....', 620)
#  ->('find_end_of_sum', 16, '........10....00.....', 619)
#  ->('read_msb_of_sum', 15, '........10....00.....', 618)
#  ->('0_check_end_of_sum', 14, '........10....0......', 617)
#  ->('0_find_end_of_sum', 13, '........10....0......', 616)
#  ->('0_find_answer', 12, '........10....0......', 615)
#  ->('0_find_answer', 11, '........10....0......', 614)
#  ->('0_find_answer', 10, '........10....0......', 613)
#  ->('0_find_answer', 9, '........10....0......', 612)
#  ->('write_0', 10, '........10....0......', 611)
#  ->('find_start_of_sum', 11, '........100...0......', 610)
#  ->('find_start_of_sum', 12, '........100...0......', 609)
#  ->('find_start_of_sum', 13, '........100...0......', 608)
#  ->('find_start_of_sum', 14, '........100...0......', 607)
#  ->('find_end_of_sum', 14, '........100...0......', 606)
#  ->('find_end_of_sum', 15, '........100...0......', 605)
#  ->('read_msb_of_sum', 14, '........100...0......', 604)
#  ->('0_check_end_of_sum', 13, '........100..........', 603)
#  ->('0_write_last_digit', 12, '........100..........', 602)
#  ->('0_write_last_digit', 11, '........100..........', 601)
#  ->('0_write_last_digit', 10, '........100..........', 600)
#  ->('write_last_0', 11, '........100..........', 599)
#  ->('find_start_of_answer', 11, '........1000.........', 598)
#  ->('find_start_of_answer', 10, '........1000.........', 597)
#  ->('find_start_of_answer', 9, '........1000.........', 596)
#  ->('find_start_of_answer', 8, '........1000.........', 595)
#  ->('find_start_of_answer', 7, '........1000.........', 594)
#  ->('erase_leading_zeros', 8, '........1000.........', 593)
#  ->('Fdone', 8, '........1000.........', 592)

# %%
explore_tm(Jaddtm, "1001+0111", 735)
# Out:
# Allocating  8  tape cells to the RIGHT!
# Allocating  8  tape cells to the LEFT!
# Detailing the halted configs now.
# Accepted at  ('Fdone', 8, '........10000............', 488)
#  via ..
#  ->('Istart', 0, '1001+0111', 735)
#  ->('check_a', 1, '1001+0111', 734)
#  ->('check_a', 2, '1001+0111', 733)
#  ->('check_a', 3, '1001+0111', 732)
#  ->('check_a', 4, '1001+0111', 731)
#  ->('check_b_start', 5, '1001a0111', 730)
#  ->('check_b', 6, '1001a0111', 729)
#  ->('check_b', 7, '1001a0111', 728)
#  ->('check_b', 8, '1001a0111', 727)
#  ->('check_b', 9, '1001a0111', 726)
#  ->('read_next_b_digit', 8, '1001a0111b.......', 725)
#  ->('1_scan_to_a', 7, '1001a011Yb.......', 724)
#  ->('1_scan_to_a', 6, '1001a011Yb.......', 723)
#  ->('1_scan_to_a', 5, '1001a011Yb.......', 722)
#  ->('1_scan_to_a', 4, '1001a011Yb.......', 721)
#  ->('1_scan_to_a_digit', 3, '1001a011Yb.......', 720)
#  ->('c0_scan_to_output', 4, '100Ya011Yb.......', 719)
#  ->('c0_scan_to_output', 5, '100Ya011Yb.......', 718)
#  ->('c0_scan_to_output', 6, '100Ya011Yb.......', 717)
#  ->('c0_scan_to_output', 7, '100Ya011Yb.......', 716)
#  ->('c0_scan_to_output', 8, '100Ya011Yb.......', 715)
#  ->('c0_scan_to_output', 9, '100Ya011Yb.......', 714)
#  ->('c0_scan_to_output', 10, '100Ya011Yb.......', 713)
#  ->('write_carry', 11, '100Ya011Yb0......', 712)
#  ->('scan_to_b', 10, '100Ya011Yb0c.....', 711)
#  ->('scan_to_b', 9, '100Ya011Yb0c.....', 710)
#  ->('scan_to_b_digit', 8, '100Ya011Yb0c.....', 709)
#  ->('scan_to_b_digit', 7, '100Ya011Yb0c.....', 708)
#  ->('read_next_b_digit', 7, '100Ya011Yb0c.....', 707)
#  ->('1_scan_to_a', 6, '100Ya01YYb0c.....', 706)
#  ->('1_scan_to_a', 5, '100Ya01YYb0c.....', 705)
#  ->('1_scan_to_a', 4, '100Ya01YYb0c.....', 704)
#  ->('1_scan_to_a_digit', 3, '100Ya01YYb0c.....', 703)
#  ->('1_scan_to_a_digit', 2, '100Ya01YYb0c.....', 702)
#  ->('1_scan_to_output', 3, '10XYa01YYb0c.....', 701)
#  ->('1_scan_to_output', 4, '10XYa01YYb0c.....', 700)
#  ->('1_scan_to_output', 5, '10XYa01YYb0c.....', 699)
#  ->('1_scan_to_output', 6, '10XYa01YYb0c.....', 698)
#  ->('1_scan_to_output', 7, '10XYa01YYb0c.....', 697)
#  ->('1_scan_to_output', 8, '10XYa01YYb0c.....', 696)
#  ->('1_scan_to_output', 9, '10XYa01YYb0c.....', 695)
#  ->('1_scan_to_output', 10, '10XYa01YYb0c.....', 694)
#  ->('1_scan_to_output', 11, '10XYa01YYb0c.....', 693)
#  ->('write_carry', 12, '10XYa01YYb00.....', 692)
#  ->('scan_to_b', 11, '10XYa01YYb00c....', 691)
#  ->('scan_to_b', 10, '10XYa01YYb00c....', 690)
#  ->('scan_to_b', 9, '10XYa01YYb00c....', 689)
#  ->('scan_to_b_digit', 8, '10XYa01YYb00c....', 688)
#  ->('scan_to_b_digit', 7, '10XYa01YYb00c....', 687)
#  ->('scan_to_b_digit', 6, '10XYa01YYb00c....', 686)
#  ->('read_next_b_digit', 6, '10XYa01YYb00c....', 685)
#  ->('1_scan_to_a', 5, '10XYa0YYYb00c....', 684)
#  ->('1_scan_to_a', 4, '10XYa0YYYb00c....', 683)
#  ->('1_scan_to_a_digit', 3, '10XYa0YYYb00c....', 682)
#  ->('1_scan_to_a_digit', 2, '10XYa0YYYb00c....', 681)
#  ->('1_scan_to_a_digit', 1, '10XYa0YYYb00c....', 680)
#  ->('1_scan_to_output', 2, '1XXYa0YYYb00c....', 679)
#  ->('1_scan_to_output', 3, '1XXYa0YYYb00c....', 678)
#  ->('1_scan_to_output', 4, '1XXYa0YYYb00c....', 677)
#  ->('1_scan_to_output', 5, '1XXYa0YYYb00c....', 676)
#  ->('1_scan_to_output', 6, '1XXYa0YYYb00c....', 675)
#  ->('1_scan_to_output', 7, '1XXYa0YYYb00c....', 674)
#  ->('1_scan_to_output', 8, '1XXYa0YYYb00c....', 673)
#  ->('1_scan_to_output', 9, '1XXYa0YYYb00c....', 672)
#  ->('1_scan_to_output', 10, '1XXYa0YYYb00c....', 671)
#  ->('1_scan_to_output', 11, '1XXYa0YYYb00c....', 670)
#  ->('1_scan_to_output', 12, '1XXYa0YYYb00c....', 669)
#  ->('write_carry', 13, '1XXYa0YYYb000....', 668)
#  ->('scan_to_b', 12, '1XXYa0YYYb000c...', 667)
#  ->('scan_to_b', 11, '1XXYa0YYYb000c...', 666)
#  ->('scan_to_b', 10, '1XXYa0YYYb000c...', 665)
#  ->('scan_to_b', 9, '1XXYa0YYYb000c...', 664)
#  ->('scan_to_b_digit', 8, '1XXYa0YYYb000c...', 663)
#  ->('scan_to_b_digit', 7, '1XXYa0YYYb000c...', 662)
#  ->('scan_to_b_digit', 6, '1XXYa0YYYb000c...', 661)
#  ->('scan_to_b_digit', 5, '1XXYa0YYYb000c...', 660)
#  ->('read_next_b_digit', 5, '1XXYa0YYYb000c...', 659)
#  ->('0_scan_to_a', 4, '1XXYaXYYYb000c...', 658)
#  ->('0_scan_to_a_digit', 3, '1XXYaXYYYb000c...', 657)
#  ->('0_scan_to_a_digit', 2, '1XXYaXYYYb000c...', 656)
#  ->('0_scan_to_a_digit', 1, '1XXYaXYYYb000c...', 655)
#  ->('0_scan_to_a_digit', 0, '1XXYaXYYYb000c...', 654)
#  ->('1_scan_to_output', 1, 'YXXYaXYYYb000c...', 653)
#  ->('1_scan_to_output', 2, 'YXXYaXYYYb000c...', 652)
#  ->('1_scan_to_output', 3, 'YXXYaXYYYb000c...', 651)
#  ->('1_scan_to_output', 4, 'YXXYaXYYYb000c...', 650)
#  ->('1_scan_to_output', 5, 'YXXYaXYYYb000c...', 649)
#  ->('1_scan_to_output', 6, 'YXXYaXYYYb000c...', 648)
#  ->('1_scan_to_output', 7, 'YXXYaXYYYb000c...', 647)
#  ->('1_scan_to_output', 8, 'YXXYaXYYYb000c...', 646)
#  ->('1_scan_to_output', 9, 'YXXYaXYYYb000c...', 645)
#  ->('1_scan_to_output', 10, 'YXXYaXYYYb000c...', 644)
#  ->('1_scan_to_output', 11, 'YXXYaXYYYb000c...', 643)
#  ->('1_scan_to_output', 12, 'YXXYaXYYYb000c...', 642)
#  ->('1_scan_to_output', 13, 'YXXYaXYYYb000c...', 641)
#  ->('write_carry', 14, 'YXXYaXYYYb0000...', 640)
#  ->('scan_to_b', 13, 'YXXYaXYYYb0000c..', 639)
#  ->('scan_to_b', 12, 'YXXYaXYYYb0000c..', 638)
#  ->('scan_to_b', 11, 'YXXYaXYYYb0000c..', 637)
#  ->('scan_to_b', 10, 'YXXYaXYYYb0000c..', 636)
#  ->('scan_to_b', 9, 'YXXYaXYYYb0000c..', 635)
#  ->('scan_to_b_digit', 8, 'YXXYaXYYYb0000c..', 634)
#  ->('scan_to_b_digit', 7, 'YXXYaXYYYb0000c..', 633)
#  ->('scan_to_b_digit', 6, 'YXXYaXYYYb0000c..', 632)
#  ->('scan_to_b_digit', 5, 'YXXYaXYYYb0000c..', 631)
#  ->('scan_to_b_digit', 4, 'YXXYaXYYYb0000c..', 630)
#  ->('n_scan_to_a', 4, 'YXXYaXYYYb0000c..', 629)
#  ->('n_scan_to_a_digit', 3, 'YXXYaXYYYb0000c..', 628)
#  ->('n_scan_to_a_digit', 2, 'YXXYaXYYYb0000c..', 627)
#  ->('n_scan_to_a_digit', 1, 'YXXYaXYYYb0000c..', 626)
#  ->('n_scan_to_a_digit', 0, 'YXXYaXYYYb0000c..', 625)
#  ->('n_scan_to_a_digit', 7, '........YXXYaXYYYb0000c..', 624)
#  ->('erase_until_sum', 8, '.......sYXXYaXYYYb0000c..', 623)
#  ->('erase_until_sum', 9, '.......s.XXYaXYYYb0000c..', 622)
#  ->('erase_until_sum', 10, '.......s..XYaXYYYb0000c..', 621)
#  ->('erase_until_sum', 11, '.......s...YaXYYYb0000c..', 620)
#  ->('erase_until_sum', 12, '.......s....aXYYYb0000c..', 619)
#  ->('erase_until_sum', 13, '.......s.....XYYYb0000c..', 618)
#  ->('erase_until_sum', 14, '.......s......YYYb0000c..', 617)
#  ->('erase_until_sum', 15, '.......s.......YYb0000c..', 616)
#  ->('erase_until_sum', 16, '.......s........Yb0000c..', 615)
#  ->('erase_until_sum', 17, '.......s.........b0000c..', 614)
#  ->('find_end_of_sum', 18, '.......s..........0000c..', 613)
#  ->('find_end_of_sum', 19, '.......s..........0000c..', 612)
#  ->('find_end_of_sum', 20, '.......s..........0000c..', 611)
#  ->('find_end_of_sum', 21, '.......s..........0000c..', 610)
#  ->('find_end_of_sum', 22, '.......s..........0000c..', 609)
#  ->('read_msb_of_sum', 22, '.......s..........00001..', 608)
#  ->('1_check_end_of_sum', 21, '.......s..........0000...', 607)
#  ->('1_find_end_of_sum', 20, '.......s..........0000...', 606)
#  ->('1_find_end_of_sum', 19, '.......s..........0000...', 605)
#  ->('1_find_end_of_sum', 18, '.......s..........0000...', 604)
#  ->('1_find_end_of_sum', 17, '.......s..........0000...', 603)
#  ->('1_find_answer', 16, '.......s..........0000...', 602)
#  ->('1_find_answer', 15, '.......s..........0000...', 601)
#  ->('1_find_answer', 14, '.......s..........0000...', 600)
#  ->('1_find_answer', 13, '.......s..........0000...', 599)
#  ->('1_find_answer', 12, '.......s..........0000...', 598)
#  ->('1_find_answer', 11, '.......s..........0000...', 597)
#  ->('1_find_answer', 10, '.......s..........0000...', 596)
#  ->('1_find_answer', 9, '.......s..........0000...', 595)
#  ->('1_find_answer', 8, '.......s..........0000...', 594)
#  ->('1_find_answer', 7, '.......s..........0000...', 593)
#  ->('write_1', 8, '..................0000...', 592)
#  ->('find_start_of_sum', 9, '........1.........0000...', 591)
#  ->('find_start_of_sum', 10, '........1.........0000...', 590)
#  ->('find_start_of_sum', 11, '........1.........0000...', 589)
#  ->('find_start_of_sum', 12, '........1.........0000...', 588)
#  ->('find_start_of_sum', 13, '........1.........0000...', 587)
#  ->('find_start_of_sum', 14, '........1.........0000...', 586)
#  ->('find_start_of_sum', 15, '........1.........0000...', 585)
#  ->('find_start_of_sum', 16, '........1.........0000...', 584)
#  ->('find_start_of_sum', 17, '........1.........0000...', 583)
#  ->('find_start_of_sum', 18, '........1.........0000...', 582)
#  ->('find_end_of_sum', 18, '........1.........0000...', 581)
#  ->('find_end_of_sum', 19, '........1.........0000...', 580)
#  ->('find_end_of_sum', 20, '........1.........0000...', 579)
#  ->('find_end_of_sum', 21, '........1.........0000...', 578)
#  ->('find_end_of_sum', 22, '........1.........0000...', 577)
#  ->('read_msb_of_sum', 21, '........1.........0000...', 576)
#  ->('0_check_end_of_sum', 20, '........1.........000....', 575)
#  ->('0_find_end_of_sum', 19, '........1.........000....', 574)
#  ->('0_find_end_of_sum', 18, '........1.........000....', 573)
#  ->('0_find_end_of_sum', 17, '........1.........000....', 572)
#  ->('0_find_answer', 16, '........1.........000....', 571)
#  ->('0_find_answer', 15, '........1.........000....', 570)
#  ->('0_find_answer', 14, '........1.........000....', 569)
#  ->('0_find_answer', 13, '........1.........000....', 568)
#  ->('0_find_answer', 12, '........1.........000....', 567)
#  ->('0_find_answer', 11, '........1.........000....', 566)
#  ->('0_find_answer', 10, '........1.........000....', 565)
#  ->('0_find_answer', 9, '........1.........000....', 564)
#  ->('0_find_answer', 8, '........1.........000....', 563)
#  ->('write_0', 9, '........1.........000....', 562)
#  ->('find_start_of_sum', 10, '........10........000....', 561)
#  ->('find_start_of_sum', 11, '........10........000....', 560)
#  ->('find_start_of_sum', 12, '........10........000....', 559)
#  ->('find_start_of_sum', 13, '........10........000....', 558)
#  ->('find_start_of_sum', 14, '........10........000....', 557)
#  ->('find_start_of_sum', 15, '........10........000....', 556)
#  ->('find_start_of_sum', 16, '........10........000....', 555)
#  ->('find_start_of_sum', 17, '........10........000....', 554)
#  ->('find_start_of_sum', 18, '........10........000....', 553)
#  ->('find_end_of_sum', 18, '........10........000....', 552)
#  ->('find_end_of_sum', 19, '........10........000....', 551)
#  ->('find_end_of_sum', 20, '........10........000....', 550)
#  ->('find_end_of_sum', 21, '........10........000....', 549)
#  ->('read_msb_of_sum', 20, '........10........000....', 548)
#  ->('0_check_end_of_sum', 19, '........10........00.....', 547)
#  ->('0_find_end_of_sum', 18, '........10........00.....', 546)
#  ->('0_find_end_of_sum', 17, '........10........00.....', 545)
#  ->('0_find_answer', 16, '........10........00.....', 544)
#  ->('0_find_answer', 15, '........10........00.....', 543)
#  ->('0_find_answer', 14, '........10........00.....', 542)
#  ->('0_find_answer', 13, '........10........00.....', 541)
#  ->('0_find_answer', 12, '........10........00.....', 540)
#  ->('0_find_answer', 11, '........10........00.....', 539)
#  ->('0_find_answer', 10, '........10........00.....', 538)
#  ->('0_find_answer', 9, '........10........00.....', 537)
#  ->('write_0', 10, '........10........00.....', 536)
#  ->('find_start_of_sum', 11, '........100.......00.....', 535)
#  ->('find_start_of_sum', 12, '........100.......00.....', 534)
#  ->('find_start_of_sum', 13, '........100.......00.....', 533)
#  ->('find_start_of_sum', 14, '........100.......00.....', 532)
#  ->('find_start_of_sum', 15, '........100.......00.....', 531)
#  ->('find_start_of_sum', 16, '........100.......00.....', 530)
#  ->('find_start_of_sum', 17, '........100.......00.....', 529)
#  ->('find_start_of_sum', 18, '........100.......00.....', 528)
#  ->('find_end_of_sum', 18, '........100.......00.....', 527)
#  ->('find_end_of_sum', 19, '........100.......00.....', 526)
#  ->('find_end_of_sum', 20, '........100.......00.....', 525)
#  ->('read_msb_of_sum', 19, '........100.......00.....', 524)
#  ->('0_check_end_of_sum', 18, '........100.......0......', 523)
#  ->('0_find_end_of_sum', 17, '........100.......0......', 522)
#  ->('0_find_answer', 16, '........100.......0......', 521)
#  ->('0_find_answer', 15, '........100.......0......', 520)
#  ->('0_find_answer', 14, '........100.......0......', 519)
#  ->('0_find_answer', 13, '........100.......0......', 518)
#  ->('0_find_answer', 12, '........100.......0......', 517)
#  ->('0_find_answer', 11, '........100.......0......', 516)
#  ->('0_find_answer', 10, '........100.......0......', 515)
#  ->('write_0', 11, '........100.......0......', 514)
#  ->('find_start_of_sum', 12, '........1000......0......', 513)
#  ->('find_start_of_sum', 13, '........1000......0......', 512)
#  ->('find_start_of_sum', 14, '........1000......0......', 511)
#  ->('find_start_of_sum', 15, '........1000......0......', 510)
#  ->('find_start_of_sum', 16, '........1000......0......', 509)
#  ->('find_start_of_sum', 17, '........1000......0......', 508)
#  ->('find_start_of_sum', 18, '........1000......0......', 507)
#  ->('find_end_of_sum', 18, '........1000......0......', 506)
#  ->('find_end_of_sum', 19, '........1000......0......', 505)
#  ->('read_msb_of_sum', 18, '........1000......0......', 504)
#  ->('0_check_end_of_sum', 17, '........1000.............', 503)
#  ->('0_write_last_digit', 16, '........1000.............', 502)
#  ->('0_write_last_digit', 15, '........1000.............', 501)
#  ->('0_write_last_digit', 14, '........1000.............', 500)
#  ->('0_write_last_digit', 13, '........1000.............', 499)
#  ->('0_write_last_digit', 12, '........1000.............', 498)
#  ->('0_write_last_digit', 11, '........1000.............', 497)
#  ->('write_last_0', 12, '........1000.............', 496)
#  ->('find_start_of_answer', 12, '........10000............', 495)
#  ->('find_start_of_answer', 11, '........10000............', 494)
#  ->('find_start_of_answer', 10, '........10000............', 493)
#  ->('find_start_of_answer', 9, '........10000............', 492)
#  ->('find_start_of_answer', 8, '........10000............', 491)
#  ->('find_start_of_answer', 7, '........10000............', 490)
#  ->('erase_leading_zeros', 8, '........10000............', 489)
#  ->('Fdone', 8, '........10000............', 488)

# %%
dec_doub = md2mc(src='File', fname='decimal_double_tm.tm')
dotObj_tm(dec_doub)

# %%
dotObj_tm(dec_doub, FuseEdges = True)

# %%
# Doubles the number given on the tape in decimal!
explore_tm(dec_doub, "231", 100)
# Out:
# Allocating  8  tape cells to the RIGHT!
# Allocating  8  tape cells to the LEFT!
# Detailing the halted configs now.
# Accepted at  ('f_done', 7, '........462........', 92)
#  via ..
#  ->('i_start', 0, '231', 100)
#  ->('goto_lsd', 1, '231', 99)
#  ->('goto_lsd', 2, '231', 98)
#  ->('goto_lsd', 3, '231', 97)
#  ->('0_carry', 2, '231........', 96)
#  ->('0_carry', 1, '232........', 95)
#  ->('0_carry', 0, '262........', 94)
#  ->('0_carry', 7, '........462........', 93)
#  ->('f_done', 7, '........462........', 92)

# %%
collatz_tm = md2mc(src='File', fname='collatz_tm.tm')
dotObj_tm(collatz_tm)

# %%
DOcollatz = dotObj_tm(collatz_tm, FuseEdges=True)
DOcollatz

# %%
# Will loop if the Collatz ("3x+1") program will ever loop!
explore_tm(collatz_tm, "0110", 100)
# Out:
# Allocating  8  tape cells to the RIGHT!
# Allocating  8  tape cells to the LEFT!
# Detailing the halted configs now.
# Accepted at  ('f_halt', 5, '.....1..............', 65)
#  via ..
#  ->('i_start', 0, '0110', 100)
#  ->('i_start', 1, '.110', 99)
#  ->('goto_lsb', 2, '.110', 98)
#  ->('goto_lsb', 3, '.110', 97)
#  ->('goto_lsb', 4, '.110', 96)
#  ->('branch', 3, '.110........', 95)
#  ->('branch', 2, '.11.........', 94)
#  ->('check_n_eq_1', 1, '.11.........', 93)
#  ->('01_fma', 2, '.11.........', 92)
#  ->('10_fma', 1, '.10.........', 91)
#  ->('10_fma', 0, '.10.........', 90)
#  ->('01_fma', 7, '........010.........', 89)
#  ->('goto_lsb', 8, '.......1010.........', 88)
#  ->('goto_lsb', 9, '.......1010.........', 87)
#  ->('goto_lsb', 10, '.......1010.........', 86)
#  ->('goto_lsb', 11, '.......1010.........', 85)
#  ->('branch', 10, '.......1010.........', 84)
#  ->('branch', 9, '.......101..........', 83)
#  ->('check_n_eq_1', 8, '.......101..........', 82)
#  ->('01_fma', 9, '.......101..........', 81)
#  ->('10_fma', 8, '.......100..........', 80)
#  ->('01_fma', 7, '.......100..........', 79)
#  ->('10_fma', 6, '.......000..........', 78)
#  ->('01_fma', 5, '......0000..........', 77)
#  ->('goto_lsb', 6, '.....10000..........', 76)
#  ->('goto_lsb', 7, '.....10000..........', 75)
#  ->('goto_lsb', 8, '.....10000..........', 74)
#  ->('goto_lsb', 9, '.....10000..........', 73)
#  ->('goto_lsb', 10, '.....10000..........', 72)
#  ->('branch', 9, '.....10000..........', 71)
#  ->('branch', 8, '.....1000...........', 70)
#  ->('branch', 7, '.....100............', 69)
#  ->('branch', 6, '.....10.............', 68)
#  ->('branch', 5, '.....1..............', 67)
#  ->('check_n_eq_1', 4, '.....1..............', 66)
#  ->('f_halt', 5, '.....1..............', 65)

# %%
shiftl_tm = md2mc(src='File', fname='shift_left_tm.tm')
dotObj_tm(shiftl_tm)

# %%
dotObj_tm(shiftl_tm, FuseEdges=True)

# %%
explore_tm(shiftl_tm, "abaaba", 100)
# Out:
# Allocating  8  tape cells to the RIGHT!
# Allocating  8  tape cells to the LEFT!
# Detailing the halted configs now.
# Accepted at  ('f_done', 6, '.......abaab.a........', 86)
#  via ..
#  ->('i_start', 0, 'abaaba', 100)
#  ->('scan_to_end', 1, 'abaaba', 99)
#  ->('scan_to_end', 2, 'abaaba', 98)
#  ->('scan_to_end', 3, 'abaaba', 97)
#  ->('scan_to_end', 4, 'abaaba', 96)
#  ->('scan_to_end', 5, 'abaaba', 95)
#  ->('scan_to_end', 6, 'abaaba', 94)
#  ->('move_left', 5, 'abaaba........', 93)
#  ->('read', 4, 'abaaba........', 92)
#  ->('b_next', 3, 'abaa.a........', 91)
#  ->('a_next', 2, 'abab.a........', 90)
#  ->('a_next', 1, 'abab.a........', 89)
#  ->('b_next', 0, 'aaab.a........', 88)
#  ->('a_next', 7, '........baab.a........', 87)
#  ->('f_done', 6, '.......abaab.a........', 86)

# %%
shiftr_tm = md2mc(src='File', fname='shift_right_tm.tm')
dotObj_tm(shiftr_tm)

# %%
dotObj_tm(shiftr_tm, True)

# %%
explore_tm(shiftr_tm, "ababba", 100)
# Out:
# Allocating  8  tape cells to the RIGHT!
# Detailing the halted configs now.
# Accepted at  ('f_done', 6, 'a.babba.......', 93)
#  via ..
#  ->('i_move_right', 0, 'ababba', 100)
#  ->('read', 1, 'ababba', 99)
#  ->('b_next', 2, 'a.abba', 98)
#  ->('a_next', 3, 'a.bbba', 97)
#  ->('b_next', 4, 'a.baba', 96)
#  ->('b_next', 5, 'a.baba', 95)
#  ->('a_next', 6, 'a.babb', 94)
#  ->('f_done', 6, 'a.babba.......', 93)
