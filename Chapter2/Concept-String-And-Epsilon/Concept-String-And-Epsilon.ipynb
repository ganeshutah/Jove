# %% [markdown]
# # Chapter 2 &mdash; Strings, $\varepsilon$, and "over an Alphabet"
#
# **Concept 3 of the Chapter 2 decomposition:** *String (Word), the Empty String, and "over an Alphabet"*
#
# A string is a <b>finitely long, possibly empty</b> sequence of symbols. "Over an alphabet" is a one-way containment, not an equality.
#
# ---
#
# *Run on Colab:* [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ganeshutah/Jove/blob/master/Chapter2/Concept-String-And-Epsilon/Concept-String-And-Epsilon.ipynb)
# *Or run locally from inside a Jove checkout.*

# %% [markdown]
# ## 0. Setup

# %%
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Run this cell first. It works both on Colab and on your own machine.
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
import sys

try:                       # -- are we on Colab? --
    import google.colab
    OWN_INSTALL = False
except ImportError:
    OWN_INSTALL = True

if OWN_INSTALL:
    # Running from Jove/Chapter<N>/Concept-<Name>/ : reach the Jove root.
    sys.path[0:0] = ['../..', '../../3rdparty',
                     '../../..', '../../../3rdparty',
                     '..', '../3rdparty', '.']
else:
    ! if [ ! -d Jove ]; then git clone -q https://github.com/ganeshutah/Jove Jove; fi
    sys.path.append('./Jove')
    sys.path.append('./Jove/jove')

# -- imports needed by this notebook --
from jove.LangDef        import *
#~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
print("Jove loaded. Ready.")

# %% [markdown]
# ## 1. The idea
#
#
# A **string** (or **word**) is a *finitely long*, *possibly empty* sequence of symbols,
# read left to right. This book never deals with infinite strings.
#
# The **empty string** is $\varepsilon$, written `""` or `''` in Python, and **its length
# is 0 by definition**.
#
# "Over an alphabet" is looser than it looks: a string may be regarded as over **any
# larger** alphabet &mdash; `"dad"` is a string over $\{a,b,c,d\}$. The only hard requirement
# is that every symbol **in** the string is **in** the alphabet.

# %% [markdown]
# ## 2. Definitions

# %% [markdown]
# ### $\varepsilon$ and length

# %%
eps = ''
print("epsilon repr :", repr(eps), " length :", len(eps))
assert len(eps) == 0

# %% [markdown]
# ### The "over" relation &mdash; one-way containment

# %%
def symbols_of(s):
    return set(s)

def is_over(s, Sigma):
    """Every symbol of s must be in Sigma. Sigma may be LARGER."""
    return symbols_of(s) <= Sigma

# %% [markdown]
# ## 3. Tests

# %% [markdown]
# `"ateAnApple"` uses eight distinct symbols &mdash; and is over any alphabet containing them.

# %%
w = "ateAnApple"
print("symbols in", repr(w), ":", sorted(symbols_of(w)))
print("count :", len(symbols_of(w)))

# %% [markdown]
# `"dad"` is over $\{a,d\}$ **and** over $\{a,b,c,d\}$ &mdash; the user simply did not press
# some keys.

# %%
for Sigma in [{'a','d'}, {'a','b','c','d'}, {'a','b'}]:
    print("'dad' over %-18s ? %s" % (sorted(Sigma), is_over('dad', Sigma)))
assert is_over('dad', {'a','b','c','d'}) and not is_over('dad', {'a','b'})

# %% [markdown]
# $\varepsilon$ is over **every** alphabet &mdash; it has no symbols to violate anything.

# %%
print("epsilon over {0,1} :", is_over('', {'0','1'}))
print("epsilon over {}    :", is_over('', set()))
print()
print("Strings are FINITE. This book has no infinite strings anywhere.")

# %% [markdown]
# ## 4. Exercises
#
#
# 1. Say in one sentence why `is_over` uses `<=` (subset) rather than `==`.
# 2. Are all palindromes the concatenation of a string with its reverse? Test
#    `'aba'`. What goes wrong, and what does that tell you about odd lengths?
# 3. The book says "alphabet $\Sigma$ underlies string $s$" as an alternative phrasing.
#    Rewrite `is_over` with that name and check nothing changes.

# %%
# Your work for the exercises above.
