# %% [markdown]
# # Chapter 2 &mdash; Finite Approximation: Looking at an Infinite Language
#
# **Concept 8 of the Chapter 2 decomposition:** *Finite Approximation of Infinite Languages*
#
# Most languages here are infinite, so Jove prints all strings under a length bound &mdash; like writing $\pi = 3.1415926$.
#
# ---
#
# *Run on Colab:* [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ganeshutah/Jove/blob/master/Chapter2/Concept-Finite-Approximation/Concept-Finite-Approximation.ipynb)
# *Or run locally from inside a Jove checkout.*

# %% [markdown]
# ## 0. Setup

# %%
# Run me first.  Works on Colab and on a local Jove checkout.
import os, subprocess, sys

def _git(*a):
    r = subprocess.run(('git',) + a, capture_output=True, text=True)
    return r.stdout.strip() if r.returncode == 0 else ''

REPO = 'https://github.com/ganeshutah/Jove'
try:                       # ---- Colab: clone once, pull thereafter ----
    import google.colab
    was = _git('-C', 'Jove', 'rev-parse', '--short', 'HEAD') if os.path.isdir('Jove') else ''
    if os.path.isdir('Jove') and not was:
        print('Jove: WARNING ./Jove exists but is not a git checkout -- left as is')
    elif was:
        _git('-C', 'Jove', 'pull', '-q', '--ff-only')
        now = _git('-C', 'Jove', 'rev-parse', '--short', 'HEAD')
        if now and now != was:
            print('Jove: PULLED  %s -> %s' % (was, now))
            print(_git('-C', 'Jove', 'log', '--oneline', was + '..' + now))
        else:
            print('Jove: PULLED  already current at %s' % (now or was))
    else:
        _git('clone', '-q', REPO, 'Jove')
        print('Jove: CLONED  at %s' % (_git('-C', 'Jove', 'rev-parse',
                                             '--short', 'HEAD') or '?'))
    JOVE = 'Jove'
except ImportError:        # ---- local: the checkout above Chapter<N>/ ----
    JOVE = next((p for p in ('../..', '../../..', '..', '.')
                 if os.path.isdir(os.path.join(p, 'jove'))), '../..')
    print('Jove: LOCAL   checkout at %s'
          % (_git('-C', JOVE, 'rev-parse', '--short', 'HEAD') or '?'))
sys.path.insert(0, JOVE)

# A session can already hold an OLDER jove in sys.modules.  The pull above
# updates the files on disk, but `import` would hand back the cached module --
# so a fixed library still behaves like the broken one.  Drop them first.
for _m in [k for k in list(sys.modules) if k == 'jove' or k.startswith('jove.')]:
    del sys.modules[_m]

from jove.LangDef        import *

import jove; print('Jove loaded from', list(jove.__path__)[0])

# %% [markdown]
# ## 1. The idea
#
#
# Infinite languages cannot be printed. The remedy used throughout Jove is **finite
# approximation**: show every string under a given bound.
#
# It gives a rough idea without seeing everything &mdash; exactly as $\pi = 3.1415926$ does.
#
# The skill to build here is translating a set-builder definition into a comprehension,
# **in both directions**.

# %% [markdown]
# ## 2. Definitions

# %% [markdown]
# ### From set-builder to comprehension

# %%
# L = { a^i b^j : i,j >= 0 and i < j },  approximated to i,j <= 9
La_lt_b_9 = {"a"*i + "b"*j for i in range(10) for j in range(10) if i < j}
print("size :", len(La_lt_b_9))

# %% [markdown]
# ### A reusable "bounded view" helper
#
# Sets are unordered, so we sort for display &mdash; **order within a set does not matter**.

# %%
def view(L, upto=None, n=12):
    xs = sorted(L, key=lambda s: (len(s), s))
    if upto is not None:
        xs = [s for s in xs if len(s) <= upto]
    return xs[:n]

# %% [markdown]
# ## 3. Tests

# %% [markdown]
# A window onto the language, shortest first.

# %%
print(view(La_lt_b_9, upto=4))

# %% [markdown]
# Growing the bound reveals more. It never reveals *all* &mdash; there is no all.

# %%
for b in [3, 5, 9]:
    Lb = {"a"*i + "b"*j for i in range(b+1) for j in range(b+1) if i < j}
    print("bound %d -> %3d strings, longest %d" % (b, len(Lb), max(len(s) for s in Lb)))

# %% [markdown]
# Jove's own `lstar` is a finite approximation in exactly this sense.

# %%
approx = lstar({'0','1'}, 3)
print("lstar({0,1},3) size :", len(approx))
print("sample              :", view(approx, n=10))
assert '' in approx and '111' in approx
print()
print("This is all strings of length <= 3. The true {0,1}* is infinite.")

# %% [markdown]
# ## 4. Exercises
#
#
# 1. Write a comprehension for all strings of $n$ `(` then $n$ `)` for $0 \le n \le 5$.
# 2. `view` sorts by `(len, s)`. Why is sorting by `s` alone misleading here?
#    (Compare Chapter 3's lexicographic-vs-numeric order.)
# 3. If two comprehensions produce the same set at bound 9, are the languages equal?

# %%
# Your work for the exercises above.

# %% [markdown]
# ## 5. Where next

# %%
# Previous / next, and a search box for all 245 concepts.
# Type a chapter (Chapter7, ch7) or words from a title (pumping, subset).
#
# Following a link opens a NEW Colab runtime. To pull another concept's
# definitions into THIS session instead:  load_here('Chapter7/Concept-...')
from jove.Nav import nav, load_here
nav(here='Chapter2/Concept-Finite-Approximation')
