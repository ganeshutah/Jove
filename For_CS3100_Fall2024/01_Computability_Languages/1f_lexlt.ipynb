# %% [markdown]
# <a href="https://colab.research.google.com/github/ganeshutah/Jove/blob/master/For_CS3100_Fall2024/01_Computability_Languages/1f_lexlt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Try defining "lexlt" yourselves. Use the hints below.
# # Please do not use to AI to generate your code in any CS 3100 Jove exercise. Turn AI off in "settings". Follow the screenshot below on how to do this.

# %% [markdown]
# ![Screenshot 2024-08-16 at 11.33.25 AM.png](data:image/png;base64,...)

# %% [markdown]
# ### Lexlt of L1 and L2 from our book

# %%
# Check if the functions exist
help(filter)

# %%
from itertools import *
help(product)

# %%
L1 = {"abacus", "bandana", "pig", "cat", "dodo", "zulu", "physics"}
L2 = {"dog", "zebra", "zzxyz", "pimento"}

# %%
L1

# %%
L2

# %%
list(product(L1,L2))

# %%
(1,2)[0]

# %%
"ab" < "a" #returns false ; < works as a lexicographic relation over strings

# %%
"now you can write a 1-liner to finish the required task"

# %% [markdown]
# # End of lexlt
