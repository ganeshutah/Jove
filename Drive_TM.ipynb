# %% [markdown]
# # Turing Machines

# %%
from Imports.Def_TM     import *
from Imports.Def_md2mc  import *
from Imports.DotBashers import *
# Out:
# You may use any of these help commands:
# help(step_tm)
# help(run_tm)
# help(explore_tm)
#
# You may use any of these help commands:
# help(md2mc)
# .. and if you want to dig more, then ..
# help(default_line_attr)
# help(length_ok_input_items)
# help(union_line_attr_list_fld)
# help(extend_rsltdict)
# help(form_delta)
# help(get_machine_components)

# %% [markdown]
# # DTM: accepts "w#w" (markdown)

# %%
help(explore_tm)
# Out:
# Help on function explore_tm in module Imports.Def_TM:
#
# explore_tm(T, tape, nsteps)
#     A handy routine to print the result of run_tm plus making
#     future extensions to explore run-results.

# %%
wpw_tm = md2mc(src='File', fname="tmfiles/wpw.tm")
dotObj_tm(wpw_tm)

# %%
DOwpw = dotObj_tm(wpw_tm, FuseEdges = True)

# %%
DOwpw.source
# Out:
# '// TO_St2\ndigraph {\n\tgraph [rankdir=LR]\n\t\tEMPTY [label="" shape=plaintext]\n\t\tq1 [label=q1 peripheries=1 shape=circle]\n\t\tq2 [label=q2 peripheries=1 shape=circle]\n\t\tq7 [label=q7 peripheries=1 shape=circle]\n\t\tq3 [label=q3 peripheries=1 shape=circle]\n\t\tIq0 [label=Iq0 peripheries=1 shape=circle]\n\t\tq4 [label=q4 peripheries=1 shape=circle]\n\t\tq8 [label=q8 peripheries=1 shape=circle]\n\t\tq5 [label=q5 peripheries=1 shape=circle]\n\t\tFq6 [label=Fq6 peripheries=2 shape=circle]\n\t\t\tEMPTY -> Iq0\n\t\t\tIq0 -> q1 [label="0 ; X,R"]\n\t\t\tIq0 -> q7 [label="1 ; Y,R"]\n\t\t\tIq0 -> q5 [label="# ; #,R"]\n\t\t\tq5 -> q5 [label="X ; X,R \n Y ; Y,R"]\n\t\t\tq5 -> Fq6 [label=". ; .,R"]\n\t\t\tq1 -> q1 [label="0 ; 0,R \n 1 ; 1,R"]\n\t\t\tq1 -> q2 [label="# ; #,R"]\n\t\t\tq2 -> q2 [label="X ; X,R \n Y ; Y,R"]\n\t\t\tq2 -> q3 [label="0 ; X,L"]\n\t\t\tq3 -> q3 [label="Y ; Y,L \n X ; X,L"]\n\t\t\tq3 -> q4 [label="# ; #,L"]\n\t\t\tq4 -> q4 [label="0 ; 0,L \n 1 ; 1,L"]\n\t\t\tq4 -> Iq0 [label="X ; X,R \n Y ; Y,R"]\n\t\t\tq7 -> q7 [label="0 ; 0,R \n 1 ; 1,R"]\n\t\t\tq7 -> q8 [label="# ; #,R"]\n\t\t\tq8 -> q8 [label="X ; X,R \n Y ; Y,R"]\n\t\t\tq8 -> q3 [label="1 ; Y,L"]\n}'

# %%
explore_tm(wpw_tm, "001#001", 120)
# Out:
# Allocating  8  tape cells to the RIGHT!
# Detailing the halted configs now.
# Accepted at  ('Fq6', 8, 'XXY#XXY........', 88)
#  via ..
#  ->('Iq0', 0, '001#001', 120)
#  ->('q1', 1, 'X01#001', 119)
#  ->('q1', 2, 'X01#001', 118)
#  ->('q1', 3, 'X01#001', 117)
#  ->('q2', 4, 'X01#001', 116)
#  ->('q3', 3, 'X01#X01', 115)
#  ->('q4', 2, 'X01#X01', 114)
#  ->('q4', 1, 'X01#X01', 113)
#  ->('q4', 0, 'X01#X01', 112)
#  ->('Iq0', 1, 'X01#X01', 111)
#  ->('q1', 2, 'XX1#X01', 110)
#  ->('q1', 3, 'XX1#X01', 109)
#  ->('q2', 4, 'XX1#X01', 108)
#  ->('q2', 5, 'XX1#X01', 107)
#  ->('q3', 4, 'XX1#XX1', 106)
#  ->('q3', 3, 'XX1#XX1', 105)
#  ->('q4', 2, 'XX1#XX1', 104)
#  ->('q4', 1, 'XX1#XX1', 103)
#  ->('Iq0', 2, 'XX1#XX1', 102)
#  ->('q7', 3, 'XXY#XX1', 101)
#  ->('q8', 4, 'XXY#XX1', 100)
#  ->('q8', 5, 'XXY#XX1', 99)
#  ->('q8', 6, 'XXY#XX1', 98)
#  ->('q3', 5, 'XXY#XXY', 97)
#  ->('q3', 4, 'XXY#XXY', 96)
#  ->('q3', 3, 'XXY#XXY', 95)
#  ->('q4', 2, 'XXY#XXY', 94)
#  ->('Iq0', 3, 'XXY#XXY', 93)
#  ->('q5', 4, 'XXY#XXY', 92)
#  ->('q5', 5, 'XXY#XXY', 91)
#  ->('q5', 6, 'XXY#XXY', 90)
#  ->('q5', 7, 'XXY#XXY', 89)
#  ->('Fq6', 8, 'XXY#XXY........', 88)

# %%
wwndtm_md = md2mc(src='File', fname="tmfiles/wwndtm.tm")
dotObj_tm(wwndtm_md)

# %%
DOwwndtm = dotObj_tm(wwndtm_md, FuseEdges=True)
DOwwndtm

# %%
DOwwndtm.source
# Out:
# '// TO_St4\ndigraph {\n\tgraph [rankdir=LR]\n\t\tEMPTY [label="" shape=plaintext]\n\t\tq9 [label=q9 peripheries=1 shape=circle]\n\t\tq14 [label=q14 peripheries=1 shape=circle]\n\t\tq2 [label=q2 peripheries=1 shape=circle]\n\t\tq7 [label=q7 peripheries=1 shape=circle]\n\t\tq3 [label=q3 peripheries=1 shape=circle]\n\t\tIq0 [label=Iq0 peripheries=1 shape=circle]\n\t\tq11 [label=q11 peripheries=1 shape=circle]\n\t\tq12 [label=q12 peripheries=1 shape=circle]\n\t\tq10 [label=q10 peripheries=1 shape=circle]\n\t\tq4 [label=q4 peripheries=1 shape=circle]\n\t\tq8 [label=q8 peripheries=1 shape=circle]\n\t\tq6 [label=q6 peripheries=1 shape=circle]\n\t\tq5 [label=q5 peripheries=1 shape=circle]\n\t\tFq13 [label=Fq13 peripheries=2 shape=circle]\n\t\tFq1 [label=Fq1 peripheries=2 shape=circle]\n\t\t\tEMPTY -> Iq0\n\t\t\tIq0 -> q14 [label="0 ; 0,S \n 1 ; 1,S"]\n\t\t\tIq0 -> Fq1 [label=". ; .,R"]\n\t\t\tq14 -> q14 [label="0 ; 0,R \n 1 ; 1,R"]\n\t\t\tq14 -> q2 [label="1 ; Y,L \n 0 ; X,L"]\n\t\t\tq2 -> q2 [label="0 ; 0,L \n 1 ; 1,L"]\n\t\t\tq2 -> q3 [label=". ; .,R"]\n\t\t\tq3 -> q6 [label="X ; X,R"]\n\t\t\tq3 -> q7 [label="Y ; Y,R"]\n\t\t\tq3 -> q5 [label="1 ; Q,R"]\n\t\t\tq5 -> q5 [label="0 ; 0,R \n 1 ; 1,R \n 2 ; 2,R \n 3 ; 3,R"]\n\t\t\tq5 -> q11 [label="Y ; 3,R"]\n\t\t\tq11 -> q9 [label=". ; .,L \n 1 ; Y,L \n 0 ; X,L"]\n\t\t\tq9 -> q9 [label="2 ; 2,L \n 0 ; 0,L \n 3 ; 3,L \n 1 ; 1,L"]\n\t\t\tq9 -> q3 [label="Q ; Q,R"]\n\t\t\tq3 -> q4 [label="0 ; P,R"]\n\t\t\tq4 -> q4 [label="0 ; 0,R \n 1 ; 1,R \n 2 ; 2,R \n 3 ; 3,R"]\n\t\t\tq4 -> q10 [label="X ; 2,R"]\n\t\t\tq10 -> q8 [label=". ; .,L \n 1 ; Y,L \n 0 ; X,L"]\n\t\t\tq8 -> q8 [label="2 ; 2,L \n 0 ; 0,L \n 3 ; 3,L \n 1 ; 1,L"]\n\t\t\tq8 -> q3 [label="P ; P,R"]\n\t\t\tq3 -> q12 [label="2 ; 2,R \n 3 ; 3,R"]\n\t\t\tq12 -> q12 [label="2 ; 2,R \n 3 ; 3,R"]\n\t\t\tq12 -> Fq13 [label=". ; .,R"]\n}'

# %%
explore_tm(wwndtm_md, "001001", 170)
# Out:
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the RIGHT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the RIGHT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# Detailing the halted configs now.
# Rejected at  ('q14', 6, '001001', 163)
#  via ..
#  ->('Iq0', 0, '001001', 170)
#  ->('q14', 0, '001001', 169)
#  ->('q14', 1, '001001', 168)
#  ->('q14', 2, '001001', 167)
#  ->('q14', 3, '001001', 166)
#  ->('q14', 4, '001001', 165)
#  ->('q14', 5, '001001', 164)
#  ->('q14', 6, '001001', 163)
# Rejected at  ('q4', 13, '........P0100Y', 152)
#  via ..
#  ->('Iq0', 0, '001001', 170)
#  ->('q14', 0, '001001', 169)
#  ->('q14', 1, '001001', 168)
#  ->('q14', 2, '001001', 167)
#  ->('q14', 3, '001001', 166)
#  ->('q14', 4, '001001', 165)
#  ->('q14', 5, '001001', 164)
#  ->('q2', 4, '00100Y', 163)
#  ->('q2', 3, '00100Y', 162)
#  ->('q2', 2, '00100Y', 161)
#  ->('q2', 1, '00100Y', 160)
#  ->('q2', 0, '00100Y', 159)
#  ->('q2', 7, '........00100Y', 158)
#  ->('q3', 8, '........00100Y', 157)
#  ->('q4', 9, '........P0100Y', 156)
#  ->('q4', 10, '........P0100Y', 155)
#  ->('q4', 11, '........P0100Y', 154)
#  ->('q4', 12, '........P0100Y', 153)
#  ->('q4', 13, '........P0100Y', 152)
# Rejected at  ('q4', 13, '........PP102Y', 144)
#  via ..
#  ->('Iq0', 0, '001001', 170)
#  ->('q14', 0, '001001', 169)
#  ->('q14', 1, '001001', 168)
#  ->('q14', 2, '001001', 167)
#  ->('q14', 3, '001001', 166)
#  ->('q14', 4, '001001', 165)
#  ->('q2', 3, '0010X1', 164)
#  ->('q2', 2, '0010X1', 163)
#  ->('q2', 1, '0010X1', 162)
#  ->('q2', 0, '0010X1', 161)
#  ->('q2', 7, '........0010X1', 160)
#  ->('q3', 8, '........0010X1', 159)
#  ->('q4', 9, '........P010X1', 158)
#  ->('q4', 10, '........P010X1', 157)
#  ->('q4', 11, '........P010X1', 156)
#  ->('q4', 12, '........P010X1', 155)
#  ->('q10', 13, '........P01021', 154)
#  ->('q8', 12, '........P0102Y', 153)
#  ->('q8', 11, '........P0102Y', 152)
#  ->('q8', 10, '........P0102Y', 151)
#  ->('q8', 9, '........P0102Y', 150)
#  ->('q8', 8, '........P0102Y', 149)
#  ->('q3', 9, '........P0102Y', 148)
#  ->('q4', 10, '........PP102Y', 147)
#  ->('q4', 11, '........PP102Y', 146)
#  ->('q4', 12, '........PP102Y', 145)
#  ->('q4', 13, '........PP102Y', 144)
# Accepted at  ('Fq13', 15, '........PPQ223........', 130)
#  via ..
#  ->('Iq0', 0, '001001', 170)
#  ->('q14', 0, '001001', 169)
#  ->('q14', 1, '001001', 168)
#  ->('q14', 2, '001001', 167)
#  ->('q14', 3, '001001', 166)
#  ->('q2', 2, '001X01', 165)
#  ->('q2', 1, '001X01', 164)
#  ->('q2', 0, '001X01', 163)
#  ->('q2', 7, '........001X01', 162)
#  ->('q3', 8, '........001X01', 161)
#  ->('q4', 9, '........P01X01', 160)
#  ->('q4', 10, '........P01X01', 159)
#  ->('q4', 11, '........P01X01', 158)
#  ->('q10', 12, '........P01201', 157)
#  ->('q8', 11, '........P012X1', 156)
#  ->('q8', 10, '........P012X1', 155)
#  ->('q8', 9, '........P012X1', 154)
#  ->('q8', 8, '........P012X1', 153)
#  ->('q3', 9, '........P012X1', 152)
#  ->('q4', 10, '........PP12X1', 151)
#  ->('q4', 11, '........PP12X1', 150)
#  ->('q4', 12, '........PP12X1', 149)
#  ->('q10', 13, '........PP1221', 148)
#  ->('q8', 12, '........PP122Y', 147)
#  ->('q8', 11, '........PP122Y', 146)
#  ->('q8', 10, '........PP122Y', 145)
#  ->('q8', 9, '........PP122Y', 144)
#  ->('q3', 10, '........PP122Y', 143)
#  ->('q5', 11, '........PPQ22Y', 142)
#  ->('q5', 12, '........PPQ22Y', 141)
#  ->('q5', 13, '........PPQ22Y', 140)
#  ->('q11', 14, '........PPQ223', 139)
#  ->('q9', 13, '........PPQ223........', 138)
#  ->('q9', 12, '........PPQ223........', 137)
#  ->('q9', 11, '........PPQ223........', 136)
#  ->('q9', 10, '........PPQ223........', 135)
#  ->('q3', 11, '........PPQ223........', 134)
#  ->('q12', 12, '........PPQ223........', 133)
#  ->('q12', 13, '........PPQ223........', 132)
#  ->('q12', 14, '........PPQ223........', 131)
#  ->('Fq13', 15, '........PPQ223........', 130)
# Rejected at  ('q4', 10, '........P0Y001', 161)
#  via ..
#  ->('Iq0', 0, '001001', 170)
#  ->('q14', 0, '001001', 169)
#  ->('q14', 1, '001001', 168)
#  ->('q14', 2, '001001', 167)
#  ->('q2', 1, '00Y001', 166)
#  ->('q2', 0, '00Y001', 165)
#  ->('q2', 7, '........00Y001', 164)
#  ->('q3', 8, '........00Y001', 163)
#  ->('q4', 9, '........P0Y001', 162)
#  ->('q4', 10, '........P0Y001', 161)
# Rejected at  ('q12', 10, '........P2Y001', 159)
#  via ..
#  ->('Iq0', 0, '001001', 170)
#  ->('q14', 0, '001001', 169)
#  ->('q14', 1, '001001', 168)
#  ->('q2', 0, '0X1001', 167)
#  ->('q2', 7, '........0X1001', 166)
#  ->('q3', 8, '........0X1001', 165)
#  ->('q4', 9, '........PX1001', 164)
#  ->('q10', 10, '........P21001', 163)
#  ->('q8', 9, '........P2Y001', 162)
#  ->('q8', 8, '........P2Y001', 161)
#  ->('q3', 9, '........P2Y001', 160)
#  ->('q12', 10, '........P2Y001', 159)
# Rejected at  ('q6', 9, '........X01001', 166)
#  via ..
#  ->('Iq0', 0, '001001', 170)
#  ->('q14', 0, '001001', 169)
#  ->('q2', 7, '........X01001', 168)
#  ->('q3', 8, '........X01001', 167)
#  ->('q6', 9, '........X01001', 166)

# %% [markdown]
# # DTM: accepts "w#w" (direct)
#
# This TM is made deterministic by going to exactly one new ID (the set of next states in the transition table has a cardinality of one). We will enter the TM (called wpw) and use dotObj_tm to plot it.

# %%
# Example TM that recognizes w#w. We use "." to denote blanks.
# Blanks are of course user-selectable
wpw = {
 "Q": {"q0","q1","q2","q3","q4","q5","q6","q7","q8","q9","q10"},
 "Sigma" : {'0','1'},
 "Gamma" : {'0','1','X','Y','#','.'},
 "Delta" : {  
     ("q0","0") : { ("q1","X","R")},
     ("q0","#") : { ("q5","#","R")},
     ("q0","1") : { ("q7","Y","R")},
     #
     ("q1","0") : { ("q1","0","R")},     
     ("q1","1") : { ("q1","1","R")},
     ("q1","#") : { ("q2","#","R")},
     #
     ("q2","X") : { ("q2","X","R")},
     ("q2","Y") : { ("q2","Y","R")},     
     ("q2","0") : { ("q3","X","L")},
     #
     ("q3","X") : { ("q3","X","L")},  
     ("q3","Y") : { ("q3","Y","L")},
     ("q3","#") : { ("q4","#","L")}, 
     #
     ("q4","0") : { ("q4","0","L")},
     ("q4","1") : { ("q4","1","L")},     
     ("q4","X") : { ("q0","X","R")},
     ("q4","Y") : { ("q0","Y","R")},
     #
     ("q5","X") : { ("q5","X","R")},     
     ("q5","Y") : { ("q5","Y","R")},
     ("q5",".") : { ("q6",".","R")},  
     #
     ("q7","0") : { ("q7","0","R")},
     ("q7","1") : { ("q7","1","R")},     
     ("q7","#") : { ("q8","#","R")},
     #
     ("q8","X") : { ("q8","X","R")},     
     ("q8","Y") : { ("q8","Y","R")},
     ("q8","1") : { ("q9","Y","L")}, 
     #
     ("q9","X") : { ("q9","X","L")},     
     ("q9","Y") : { ("q9","Y","L")},
     ("q9","#") : { ("q10","#","L")},  
     #
     ("q10","0") : { ("q10","0","L")},     
     ("q10","1") : { ("q10","1","L")},
     ("q10","X") : { ("q0","X","R")},
     ("q10","Y") : { ("q0","Y","R")},
 },
 "q0"    : "q0",
 "B"     : '.',
 "F"     : {"q6"}
}

# %%
wpw
# Out:
# {'B': '.',
#  'Delta': {('q0', '#'): {('q5', '#', 'R')},
#   ('q0', '0'): {('q1', 'X', 'R')},
#   ('q0', '1'): {('q7', 'Y', 'R')},
#   ('q1', '#'): {('q2', '#', 'R')},
#   ('q1', '0'): {('q1', '0', 'R')},
#   ('q1', '1'): {('q1', '1', 'R')},
#   ('q10', '0'): {('q10', '0', 'L')},
#   ('q10', '1'): {('q10', '1', 'L')},
#   ('q10', 'X'): {('q0', 'X', 'R')},
#   ('q10', 'Y'): {('q0', 'Y', 'R')},
#   ('q2', '0'): {('q3', 'X', 'L')},
#   ('q2', 'X'): {('q2', 'X', 'R')},
#   ('q2', 'Y'): {('q2', 'Y', 'R')},
#   ('q3', '#'): {('q4', '#', 'L')},
#   ('q3', 'X'): {('q3', 'X', 'L')},
#   ('q3', 'Y'): {('q3', 'Y', 'L')},
#   ('q4', '0'): {('q4', '0', 'L')},
#   ('q4', '1'): {('q4', '1', 'L')},
#   ('q4', 'X'): {('q0', 'X', 'R')},
#   ('q4', 'Y'): {('q0', 'Y', 'R')},
#   ('q5', '.'): {('q6', '.', 'R')},
#   ('q5', 'X'): {('q5', 'X', 'R')},
#   ('q5', 'Y'): {('q5', 'Y', 'R')},
#   ('q7', '#'): {('q8', '#', 'R')},
#   ('q7', '0'): {('q7', '0', 'R')},
#   ('q7', '1'): {('q7', '1', 'R')},
#   ('q8', '1'): {('q9', 'Y', 'L')},
#   ('q8', 'X'): {('q8', 'X', 'R')},
#   ('q8', 'Y'): {('q8', 'Y', 'R')},
#   ('q9', '#'): {('q10', '#', 'L')},
#   ('q9', 'X'): {('q9', 'X', 'L')},
#   ('q9', 'Y'): {('q9', 'Y', 'L')}},
#  'F': {'q6'},
#  'Gamma': {'#', '.', '0', '1', 'X', 'Y'},
#  'Q': {'q0', 'q1', 'q10', 'q2', 'q3', 'q4', 'q5', 'q6', 'q7', 'q8', 'q9'},
#  'Sigma': {'0', '1'},
#  'q0': 'q0'}

# %%
wpwobj = dotObj_tm(wpw)

# %%
wwndtm = {
 "Q": {"q0","q1","q2","q3","q4","q5","q6","q7","q8","q9","q10",
       "q11","q12","q13","q14"},
 "Sigma" : {'0','1'},
 "Gamma" : {'0','1','X','Y','2','3',
            'P','Q','.'},
 "Delta" : {  
     ("q0",".") : { ("q1",".","R")},
     ("q0","0") : { ("q14","0","S")},
     ("q0","1") : { ("q14","1","S")},
     #
     ("q14","0") : { ("q14","0","R"), ('q2','X','L')},
     ("q14","1") : { ("q14","1","R"), ('q2','Y','L')},
     #
     ("q2","0") : { ("q2","0","L")},
     ("q2","1") : { ("q2","1","L")},     
     ("q2",".") : { ("q3",".","R")},
     #
     ("q3","X") : { ("q6","X","R")},  
     ("q3","Y") : { ("q7","Y","R")},
     #
     ("q3","0") : { ("q4","P","R")},
     ("q3","1") : { ("q5","Q","R")},          
     #
     ("q3","2") : { ("q12","2","R")},
     ("q3","3") : { ("q12","3","R")},
     #
     #--
     ("q4","0") : { ("q4","0","R")},
     ("q4","1") : { ("q4","1","R")},
     ("q4","2") : { ("q4","2","R")},
     ("q4","3") : { ("q4","3","R")},
     ("q4","X") : { ("q10","2","R")},     
     #
     ("q5","0") : { ("q5","0","R")},
     ("q5","1") : { ("q5","1","R")},
     ("q5","2") : { ("q5","2","R")},
     ("q5","3") : { ("q5","3","R")},
     ("q5","Y") : { ("q11","3","R")},     
     #     
     ("q10","0") : { ("q8","X","L")},     
     ("q10","1") : { ("q8","Y","L")},
     ("q10",".") : { ("q8",".","L")},
     #     
     ("q11","0") : { ("q9","X","L")},     
     ("q11","1") : { ("q9","Y","L")},
     ("q11",".") : { ("q9",".","L")},     
     #
     ("q8","0") : { ("q8","0","L")},     
     ("q8","1") : { ("q8","1","L")},
     ("q8","2") : { ("q8","2","L")},
     ("q8","3") : { ("q8","3","L")},
     ("q8","P") : { ("q3","P","R")},
     #
     ("q9","0") : { ("q9","0","L")},     
     ("q9","1") : { ("q9","1","L")},
     ("q9","2") : { ("q9","2","L")},
     ("q9","3") : { ("q9","3","L")},
     ("q9","Q") : { ("q3","Q","R")},
     #
     ("q12","2") : { ("q12","2","R")},
     ("q12","3") : { ("q12","3","R")},
     ("q12",".") : { ("q13",".","R")}
 },
 "q0"    : "q0",
 "B"     : '.',
 "F"     : {"q1","q13"}
}

# %%
step_tm(wpw, ("q0",0,"0#1", 3), [], set({}))
# Out:
# ([(('q1', 1, 'X#1', 2), [('q0', 0, '0#1', 3)])], set())

# %%
step_tm(wwndtm, ("q14",0, "00", 100), [], set({}))
# Out:
# Allocating  8  tape cells to the LEFT!
# ([(('q14', 1, '00', 99), [('q14', 0, '00', 100)]),
#   (('q2', 7, '........X0', 99), [('q14', 0, '00', 100)])],
#  set())

# %%
run_tm(wpw, "01#01..", 19)
# Out:
# ([],
#  [(('q6', 6, 'XY#XY..', 1),
#    [('q0', 0, '01#01..', 19),
#     ('q1', 1, 'X1#01..', 18),
#     ('q1', 2, 'X1#01..', 17),
#     ('q2', 3, 'X1#01..', 16),
#     ('q3', 2, 'X1#X1..', 15),
#     ('q4', 1, 'X1#X1..', 14),
#     ('q4', 0, 'X1#X1..', 13),
#     ('q0', 1, 'X1#X1..', 12),
#     ('q7', 2, 'XY#X1..', 11),
#     ('q8', 3, 'XY#X1..', 10),
#     ('q8', 4, 'XY#X1..', 9),
#     ('q9', 3, 'XY#XY..', 8),
#     ('q9', 2, 'XY#XY..', 7),
#     ('q10', 1, 'XY#XY..', 6),
#     ('q0', 2, 'XY#XY..', 5),
#     ('q5', 3, 'XY#XY..', 4),
#     ('q5', 4, 'XY#XY..', 3),
#     ('q5', 5, 'XY#XY..', 2)])])

# %%
explore_tm(wpw, "01#01..", 19)
# Out:
# Detailing the halted configs now.
# Accepted at  ('q6', 6, 'XY#XY..', 1)
#  via ..
#  ->('q0', 0, '01#01..', 19)
#  ->('q1', 1, 'X1#01..', 18)
#  ->('q1', 2, 'X1#01..', 17)
#  ->('q2', 3, 'X1#01..', 16)
#  ->('q3', 2, 'X1#X1..', 15)
#  ->('q4', 1, 'X1#X1..', 14)
#  ->('q4', 0, 'X1#X1..', 13)
#  ->('q0', 1, 'X1#X1..', 12)
#  ->('q7', 2, 'XY#X1..', 11)
#  ->('q8', 3, 'XY#X1..', 10)
#  ->('q8', 4, 'XY#X1..', 9)
#  ->('q9', 3, 'XY#XY..', 8)
#  ->('q9', 2, 'XY#XY..', 7)
#  ->('q10', 1, 'XY#XY..', 6)
#  ->('q0', 2, 'XY#XY..', 5)
#  ->('q5', 3, 'XY#XY..', 4)
#  ->('q5', 4, 'XY#XY..', 3)
#  ->('q5', 5, 'XY#XY..', 2)
#  ->('q6', 6, 'XY#XY..', 1)

# %%
run_tm(wwndtm, "0100101001", 888)
# Out:
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the RIGHT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the RIGHT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the RIGHT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# ([],
#  [(('q14', 10, '0100101001', 877),
#    [('q0', 0, '0100101001', 888),
#     ('q14', 0, '0100101001', 887),
#     ('q14', 1, '0100101001', 886),
#     ('q14', 2, '0100101001', 885),
#     ('q14', 3, '0100101001', 884),
#     ('q14', 4, '0100101001', 883),
#     ('q14', 5, '0100101001', 882),
#     ('q14', 6, '0100101001', 881),
#     ('q14', 7, '0100101001', 880),
#     ('q14', 8, '0100101001', 879),
#     ('q14', 9, '0100101001', 878)]),
#   (('q4', 17, '........P10010100Y', 858),
#    [('q0', 0, '0100101001', 888),
#     ('q14', 0, '0100101001', 887),
#     ('q14', 1, '0100101001', 886),
#     ('q14', 2, '0100101001', 885),
#     ('q14', 3, '0100101001', 884),
#     ('q14', 4, '0100101001', 883),
#     ('q14', 5, '0100101001', 882),
#     ('q14', 6, '0100101001', 881),
#     ('q14', 7, '0100101001', 880),
#     ('q14', 8, '0100101001', 879),
#     ('q14', 9, '0100101001', 878),
#     ('q2', 8, '010010100Y', 877),
#     ('q2', 7, '010010100Y', 876),
#     ('q2', 6, '010010100Y', 875),
#     ('q2', 5, '010010100Y', 874),
#     ('q2', 4, '010010100Y', 873),
#     ('q2', 3, '010010100Y', 872),
#     ('q2', 2, '010010100Y', 871),
#     ('q2', 1, '010010100Y', 870),
#     ('q2', 0, '010010100Y', 869),
#     ('q2', 7, '........010010100Y', 868),
#     ('q3', 8, '........010010100Y', 867),
#     ('q4', 9, '........P10010100Y', 866),
#     ('q4', 10, '........P10010100Y', 865),
#     ('q4', 11, '........P10010100Y', 864),
#     ('q4', 12, '........P10010100Y', 863),
#     ('q4', 13, '........P10010100Y', 862),
#     ('q4', 14, '........P10010100Y', 861),
#     ('q4', 15, '........P10010100Y', 860),
#     ('q4', 16, '........P10010100Y', 859)]),
#   (('q4', 18, '........PQP0101023........', 823),
#    [('q0', 0, '0100101001', 888),
#     ('q14', 0, '0100101001', 887),
#     ('q14', 1, '0100101001', 886),
#     ('q14', 2, '0100101001', 885),
#     ('q14', 3, '0100101001', 884),
#     ('q14', 4, '0100101001', 883),
#     ('q14', 5, '0100101001', 882),
#     ('q14', 6, '0100101001', 881),
#     ('q14', 7, '0100101001', 880),
#     ('q14', 8, '0100101001', 879),
#     ('q2', 7, '01001010X1', 878),
#     ('q2', 6, '01001010X1', 877),
#     ('q2', 5, '01001010X1', 876),
#     ('q2', 4, '01001010X1', 875),
#     ('q2', 3, '01001010X1', 874),
#     ('q2', 2, '01001010X1', 873),
#     ('q2', 1, '01001010X1', 872),
#     ('q2', 0, '01001010X1', 871),
#     ('q2', 7, '........01001010X1', 870),
#     ('q3', 8, '........01001010X1', 869),
#     ('q4', 9, '........P1001010X1', 868),
#     ('q4', 10, '........P1001010X1', 867),
#     ('q4', 11, '........P1001010X1', 866),
#     ('q4', 12, '........P1001010X1', 865),
#     ('q4', 13, '........P1001010X1', 864),
#     ('q4', 14, '........P1001010X1', 863),
#     ('q4', 15, '........P1001010X1', 862),
#     ('q4', 16, '........P1001010X1', 861),
#     ('q10', 17, '........P100101021', 860),
#     ('q8', 16, '........P10010102Y', 859),
#     ('q8', 15, '........P10010102Y', 858),
#     ('q8', 14, '........P10010102Y', 857),
#     ('q8', 13, '........P10010102Y', 856),
#     ('q8', 12, '........P10010102Y', 855),
#     ('q8', 11, '........P10010102Y', 854),
#     ('q8', 10, '........P10010102Y', 853),
#     ('q8', 9, '........P10010102Y', 852),
#     ('q8', 8, '........P10010102Y', 851),
#     ('q3', 9, '........P10010102Y', 850),
#     ('q5', 10, '........PQ0010102Y', 849),
#     ('q5', 11, '........PQ0010102Y', 848),
#     ('q5', 12, '........PQ0010102Y', 847),
#     ('q5', 13, '........PQ0010102Y', 846),
#     ('q5', 14, '........PQ0010102Y', 845),
#     ('q5', 15, '........PQ0010102Y', 844),
#     ('q5', 16, '........PQ0010102Y', 843),
#     ('q5', 17, '........PQ0010102Y', 842),
#     ('q11', 18, '........PQ00101023', 841),
#     ('q9', 17, '........PQ00101023........', 840),
#     ('q9', 16, '........PQ00101023........', 839),
#     ('q9', 15, '........PQ00101023........', 838),
#     ('q9', 14, '........PQ00101023........', 837),
#     ('q9', 13, '........PQ00101023........', 836),
#     ('q9', 12, '........PQ00101023........', 835),
#     ('q9', 11, '........PQ00101023........', 834),
#     ('q9', 10, '........PQ00101023........', 833),
#     ('q9', 9, '........PQ00101023........', 832),
#     ('q3', 10, '........PQ00101023........', 831),
#     ('q4', 11, '........PQP0101023........', 830),
#     ('q4', 12, '........PQP0101023........', 829),
#     ('q4', 13, '........PQP0101023........', 828),
#     ('q4', 14, '........PQP0101023........', 827),
#     ('q4', 15, '........PQP0101023........', 826),
#     ('q4', 16, '........PQP0101023........', 825),
#     ('q4', 17, '........PQP0101023........', 824)]),
#   (('q5', 16, '........PQ001012X1', 847),
#    [('q0', 0, '0100101001', 888),
#     ('q14', 0, '0100101001', 887),
#     ('q14', 1, '0100101001', 886),
#     ('q14', 2, '0100101001', 885),
#     ('q14', 3, '0100101001', 884),
#     ('q14', 4, '0100101001', 883),
#     ('q14', 5, '0100101001', 882),
#     ('q14', 6, '0100101001', 881),
#     ('q14', 7, '0100101001', 880),
#     ('q2', 6, '0100101X01', 879),
#     ('q2', 5, '0100101X01', 878),
#     ('q2', 4, '0100101X01', 877),
#     ('q2', 3, '0100101X01', 876),
#     ('q2', 2, '0100101X01', 875),
#     ('q2', 1, '0100101X01', 874),
#     ('q2', 0, '0100101X01', 873),
#     ('q2', 7, '........0100101X01', 872),
#     ('q3', 8, '........0100101X01', 871),
#     ('q4', 9, '........P100101X01', 870),
#     ('q4', 10, '........P100101X01', 869),
#     ('q4', 11, '........P100101X01', 868),
#     ('q4', 12, '........P100101X01', 867),
#     ('q4', 13, '........P100101X01', 866),
#     ('q4', 14, '........P100101X01', 865),
#     ('q4', 15, '........P100101X01', 864),
#     ('q10', 16, '........P100101201', 863),
#     ('q8', 15, '........P1001012X1', 862),
#     ('q8', 14, '........P1001012X1', 861),
#     ('q8', 13, '........P1001012X1', 860),
#     ('q8', 12, '........P1001012X1', 859),
#     ('q8', 11, '........P1001012X1', 858),
#     ('q8', 10, '........P1001012X1', 857),
#     ('q8', 9, '........P1001012X1', 856),
#     ('q8', 8, '........P1001012X1', 855),
#     ('q3', 9, '........P1001012X1', 854),
#     ('q5', 10, '........PQ001012X1', 853),
#     ('q5', 11, '........PQ001012X1', 852),
#     ('q5', 12, '........PQ001012X1', 851),
#     ('q5', 13, '........PQ001012X1', 850),
#     ('q5', 14, '........PQ001012X1', 849),
#     ('q5', 15, '........PQ001012X1', 848)]),
#   (('q4', 14, '........P10010Y001', 867),
#    [('q0', 0, '0100101001', 888),
#     ('q14', 0, '0100101001', 887),
#     ('q14', 1, '0100101001', 886),
#     ('q14', 2, '0100101001', 885),
#     ('q14', 3, '0100101001', 884),
#     ('q14', 4, '0100101001', 883),
#     ('q14', 5, '0100101001', 882),
#     ('q14', 6, '0100101001', 881),
#     ('q2', 5, '010010Y001', 880),
#     ('q2', 4, '010010Y001', 879),
#     ('q2', 3, '010010Y001', 878),
#     ('q2', 2, '010010Y001', 877),
#     ('q2', 1, '010010Y001', 876),
#     ('q2', 0, '010010Y001', 875),
#     ('q2', 7, '........010010Y001', 874),
#     ('q3', 8, '........010010Y001', 873),
#     ('q4', 9, '........P10010Y001', 872),
#     ('q4', 10, '........P10010Y001', 871),
#     ('q4', 11, '........P10010Y001', 870),
#     ('q4', 12, '........P10010Y001', 869),
#     ('q4', 13, '........P10010Y001', 868)]),
#   (('q13', 19, '........PQPPQ23223........', 804),
#    [('q0', 0, '0100101001', 888),
#     ('q14', 0, '0100101001', 887),
#     ('q14', 1, '0100101001', 886),
#     ('q14', 2, '0100101001', 885),
#     ('q14', 3, '0100101001', 884),
#     ('q14', 4, '0100101001', 883),
#     ('q14', 5, '0100101001', 882),
#     ('q2', 4, '01001X1001', 881),
#     ('q2', 3, '01001X1001', 880),
#     ('q2', 2, '01001X1001', 879),
#     ('q2', 1, '01001X1001', 878),
#     ('q2', 0, '01001X1001', 877),
#     ('q2', 7, '........01001X1001', 876),
#     ('q3', 8, '........01001X1001', 875),
#     ('q4', 9, '........P1001X1001', 874),
#     ('q4', 10, '........P1001X1001', 873),
#     ('q4', 11, '........P1001X1001', 872),
#     ('q4', 12, '........P1001X1001', 871),
#     ('q4', 13, '........P1001X1001', 870),
#     ('q10', 14, '........P100121001', 869),
#     ('q8', 13, '........P10012Y001', 868),
#     ('q8', 12, '........P10012Y001', 867),
#     ('q8', 11, '........P10012Y001', 866),
#     ('q8', 10, '........P10012Y001', 865),
#     ('q8', 9, '........P10012Y001', 864),
#     ('q8', 8, '........P10012Y001', 863),
#     ('q3', 9, '........P10012Y001', 862),
#     ('q5', 10, '........PQ0012Y001', 861),
#     ('q5', 11, '........PQ0012Y001', 860),
#     ('q5', 12, '........PQ0012Y001', 859),
#     ('q5', 13, '........PQ0012Y001', 858),
#     ('q5', 14, '........PQ0012Y001', 857),
#     ('q11', 15, '........PQ00123001', 856),
#     ('q9', 14, '........PQ00123X01', 855),
#     ('q9', 13, '........PQ00123X01', 854),
#     ('q9', 12, '........PQ00123X01', 853),
#     ('q9', 11, '........PQ00123X01', 852),
#     ('q9', 10, '........PQ00123X01', 851),
#     ('q9', 9, '........PQ00123X01', 850),
#     ('q3', 10, '........PQ00123X01', 849),
#     ('q4', 11, '........PQP0123X01', 848),
#     ('q4', 12, '........PQP0123X01', 847),
#     ('q4', 13, '........PQP0123X01', 846),
#     ('q4', 14, '........PQP0123X01', 845),
#     ('q4', 15, '........PQP0123X01', 844),
#     ('q10', 16, '........PQP0123201', 843),
#     ('q8', 15, '........PQP01232X1', 842),
#     ('q8', 14, '........PQP01232X1', 841),
#     ('q8', 13, '........PQP01232X1', 840),
#     ('q8', 12, '........PQP01232X1', 839),
#     ('q8', 11, '........PQP01232X1', 838),
#     ('q8', 10, '........PQP01232X1', 837),
#     ('q3', 11, '........PQP01232X1', 836),
#     ('q4', 12, '........PQPP1232X1', 835),
#     ('q4', 13, '........PQPP1232X1', 834),
#     ('q4', 14, '........PQPP1232X1', 833),
#     ('q4', 15, '........PQPP1232X1', 832),
#     ('q4', 16, '........PQPP1232X1', 831),
#     ('q10', 17, '........PQPP123221', 830),
#     ('q8', 16, '........PQPP12322Y', 829),
#     ('q8', 15, '........PQPP12322Y', 828),
#     ('q8', 14, '........PQPP12322Y', 827),
#     ('q8', 13, '........PQPP12322Y', 826),
#     ('q8', 12, '........PQPP12322Y', 825),
#     ('q8', 11, '........PQPP12322Y', 824),
#     ('q3', 12, '........PQPP12322Y', 823),
#     ('q5', 13, '........PQPPQ2322Y', 822),
#     ('q5', 14, '........PQPPQ2322Y', 821),
#     ('q5', 15, '........PQPPQ2322Y', 820),
#     ('q5', 16, '........PQPPQ2322Y', 819),
#     ('q5', 17, '........PQPPQ2322Y', 818),
#     ('q11', 18, '........PQPPQ23223', 817),
#     ('q9', 17, '........PQPPQ23223........', 816),
#     ('q9', 16, '........PQPPQ23223........', 815),
#     ('q9', 15, '........PQPPQ23223........', 814),
#     ('q9', 14, '........PQPPQ23223........', 813),
#     ('q9', 13, '........PQPPQ23223........', 812),
#     ('q9', 12, '........PQPPQ23223........', 811),
#     ('q3', 13, '........PQPPQ23223........', 810),
#     ('q12', 14, '........PQPPQ23223........', 809),
#     ('q12', 15, '........PQPPQ23223........', 808),
#     ('q12', 16, '........PQPPQ23223........', 807),
#     ('q12', 17, '........PQPPQ23223........', 806),
#     ('q12', 18, '........PQPPQ23223........', 805)]),
#   (('q4', 12, '........P100Y01001', 873),
#    [('q0', 0, '0100101001', 888),
#     ('q14', 0, '0100101001', 887),
#     ('q14', 1, '0100101001', 886),
#     ('q14', 2, '0100101001', 885),
#     ('q14', 3, '0100101001', 884),
#     ('q14', 4, '0100101001', 883),
#     ('q2', 3, '0100Y01001', 882),
#     ('q2', 2, '0100Y01001', 881),
#     ('q2', 1, '0100Y01001', 880),
#     ('q2', 0, '0100Y01001', 879),
#     ('q2', 7, '........0100Y01001', 878),
#     ('q3', 8, '........0100Y01001', 877),
#     ('q4', 9, '........P100Y01001', 876),
#     ('q4', 10, '........P100Y01001', 875),
#     ('q4', 11, '........P100Y01001', 874)]),
#   (('q12', 14, '........PQP232Y001', 849),
#    [('q0', 0, '0100101001', 888),
#     ('q14', 0, '0100101001', 887),
#     ('q14', 1, '0100101001', 886),
#     ('q14', 2, '0100101001', 885),
#     ('q14', 3, '0100101001', 884),
#     ('q2', 2, '010X101001', 883),
#     ('q2', 1, '010X101001', 882),
#     ('q2', 0, '010X101001', 881),
#     ('q2', 7, '........010X101001', 880),
#     ('q3', 8, '........010X101001', 879),
#     ('q4', 9, '........P10X101001', 878),
#     ('q4', 10, '........P10X101001', 877),
#     ('q4', 11, '........P10X101001', 876),
#     ('q10', 12, '........P102101001', 875),
#     ('q8', 11, '........P102Y01001', 874),
#     ('q8', 10, '........P102Y01001', 873),
#     ('q8', 9, '........P102Y01001', 872),
#     ('q8', 8, '........P102Y01001', 871),
#     ('q3', 9, '........P102Y01001', 870),
#     ('q5', 10, '........PQ02Y01001', 869),
#     ('q5', 11, '........PQ02Y01001', 868),
#     ('q5', 12, '........PQ02Y01001', 867),
#     ('q11', 13, '........PQ02301001', 866),
#     ('q9', 12, '........PQ023X1001', 865),
#     ('q9', 11, '........PQ023X1001', 864),
#     ('q9', 10, '........PQ023X1001', 863),
#     ('q9', 9, '........PQ023X1001', 862),
#     ('q3', 10, '........PQ023X1001', 861),
#     ('q4', 11, '........PQP23X1001', 860),
#     ('q4', 12, '........PQP23X1001', 859),
#     ('q4', 13, '........PQP23X1001', 858),
#     ('q10', 14, '........PQP2321001', 857),
#     ('q8', 13, '........PQP232Y001', 856),
#     ('q8', 12, '........PQP232Y001', 855),
#     ('q8', 11, '........PQP232Y001', 854),
#     ('q8', 10, '........PQP232Y001', 853),
#     ('q3', 11, '........PQP232Y001', 852),
#     ('q12', 12, '........PQP232Y001', 851),
#     ('q12', 13, '........PQP232Y001', 850)]),
#   (('q5', 11, '........PQ2X101001', 872),
#    [('q0', 0, '0100101001', 888),
#     ('q14', 0, '0100101001', 887),
#     ('q14', 1, '0100101001', 886),
#     ('q14', 2, '0100101001', 885),
#     ('q2', 1, '01X0101001', 884),
#     ('q2', 0, '01X0101001', 883),
#     ('q2', 7, '........01X0101001', 882),
#     ('q3', 8, '........01X0101001', 881),
#     ('q4', 9, '........P1X0101001', 880),
#     ('q4', 10, '........P1X0101001', 879),
#     ('q10', 11, '........P120101001', 878),
#     ('q8', 10, '........P12X101001', 877),
#     ('q8', 9, '........P12X101001', 876),
#     ('q8', 8, '........P12X101001', 875),
#     ('q3', 9, '........P12X101001', 874),
#     ('q5', 10, '........PQ2X101001', 873)]),
#   (('q4', 9, '........PY00101001', 882),
#    [('q0', 0, '0100101001', 888),
#     ('q14', 0, '0100101001', 887),
#     ('q14', 1, '0100101001', 886),
#     ('q2', 0, '0Y00101001', 885),
#     ('q2', 7, '........0Y00101001', 884),
#     ('q3', 8, '........0Y00101001', 883)]),
#   (('q6', 9, '........X100101001', 884),
#    [('q0', 0, '0100101001', 888),
#     ('q14', 0, '0100101001', 887),
#     ('q2', 7, '........X100101001', 886),
#     ('q3', 8, '........X100101001', 885)])])

# %%
explore_tm(wwndtm, "0100101001", 888)
# Out:
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the RIGHT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the RIGHT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the RIGHT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# Detailing the halted configs now.
# Rejected at  ('q14', 10, '0100101001', 877)
#  via ..
#  ->('q0', 0, '0100101001', 888)
#  ->('q14', 0, '0100101001', 887)
#  ->('q14', 1, '0100101001', 886)
#  ->('q14', 2, '0100101001', 885)
#  ->('q14', 3, '0100101001', 884)
#  ->('q14', 4, '0100101001', 883)
#  ->('q14', 5, '0100101001', 882)
#  ->('q14', 6, '0100101001', 881)
#  ->('q14', 7, '0100101001', 880)
#  ->('q14', 8, '0100101001', 879)
#  ->('q14', 9, '0100101001', 878)
#  ->('q14', 10, '0100101001', 877)
# Rejected at  ('q4', 17, '........P10010100Y', 858)
#  via ..
#  ->('q0', 0, '0100101001', 888)
#  ->('q14', 0, '0100101001', 887)
#  ->('q14', 1, '0100101001', 886)
#  ->('q14', 2, '0100101001', 885)
#  ->('q14', 3, '0100101001', 884)
#  ->('q14', 4, '0100101001', 883)
#  ->('q14', 5, '0100101001', 882)
#  ->('q14', 6, '0100101001', 881)
#  ->('q14', 7, '0100101001', 880)
#  ->('q14', 8, '0100101001', 879)
#  ->('q14', 9, '0100101001', 878)
#  ->('q2', 8, '010010100Y', 877)
#  ->('q2', 7, '010010100Y', 876)
#  ->('q2', 6, '010010100Y', 875)
#  ->('q2', 5, '010010100Y', 874)
#  ->('q2', 4, '010010100Y', 873)
#  ->('q2', 3, '010010100Y', 872)
#  ->('q2', 2, '010010100Y', 871)
#  ->('q2', 1, '010010100Y', 870)
#  ->('q2', 0, '010010100Y', 869)
#  ->('q2', 7, '........010010100Y', 868)
#  ->('q3', 8, '........010010100Y', 867)
#  ->('q4', 9, '........P10010100Y', 866)
#  ->('q4', 10, '........P10010100Y', 865)
#  ->('q4', 11, '........P10010100Y', 864)
#  ->('q4', 12, '........P10010100Y', 863)
#  ->('q4', 13, '........P10010100Y', 862)
#  ->('q4', 14, '........P10010100Y', 861)
#  ->('q4', 15, '........P10010100Y', 860)
#  ->('q4', 16, '........P10010100Y', 859)
#  ->('q4', 17, '........P10010100Y', 858)
# Rejected at  ('q4', 18, '........PQP0101023........', 823)
#  via ..
#  ->('q0', 0, '0100101001', 888)
#  ->('q14', 0, '0100101001', 887)
#  ->('q14', 1, '0100101001', 886)
#  ->('q14', 2, '0100101001', 885)
#  ->('q14', 3, '0100101001', 884)
#  ->('q14', 4, '0100101001', 883)
#  ->('q14', 5, '0100101001', 882)
#  ->('q14', 6, '0100101001', 881)
#  ->('q14', 7, '0100101001', 880)
#  ->('q14', 8, '0100101001', 879)
#  ->('q2', 7, '01001010X1', 878)
#  ->('q2', 6, '01001010X1', 877)
#  ->('q2', 5, '01001010X1', 876)
#  ->('q2', 4, '01001010X1', 875)
#  ->('q2', 3, '01001010X1', 874)
#  ->('q2', 2, '01001010X1', 873)
#  ->('q2', 1, '01001010X1', 872)
#  ->('q2', 0, '01001010X1', 871)
#  ->('q2', 7, '........01001010X1', 870)
#  ->('q3', 8, '........01001010X1', 869)
#  ->('q4', 9, '........P1001010X1', 868)
#  ->('q4', 10, '........P1001010X1', 867)
#  ->('q4', 11, '........P1001010X1', 866)
#  ->('q4', 12, '........P1001010X1', 865)
#  ->('q4', 13, '........P1001010X1', 864)
#  ->('q4', 14, '........P1001010X1', 863)
#  ->('q4', 15, '........P1001010X1', 862)
#  ->('q4', 16, '........P1001010X1', 861)
#  ->('q10', 17, '........P100101021', 860)
#  ->('q8', 16, '........P10010102Y', 859)
#  ->('q8', 15, '........P10010102Y', 858)
#  ->('q8', 14, '........P10010102Y', 857)
#  ->('q8', 13, '........P10010102Y', 856)
#  ->('q8', 12, '........P10010102Y', 855)
#  ->('q8', 11, '........P10010102Y', 854)
#  ->('q8', 10, '........P10010102Y', 853)
#  ->('q8', 9, '........P10010102Y', 852)
#  ->('q8', 8, '........P10010102Y', 851)
#  ->('q3', 9, '........P10010102Y', 850)
#  ->('q5', 10, '........PQ0010102Y', 849)
#  ->('q5', 11, '........PQ0010102Y', 848)
#  ->('q5', 12, '........PQ0010102Y', 847)
#  ->('q5', 13, '........PQ0010102Y', 846)
#  ->('q5', 14, '........PQ0010102Y', 845)
#  ->('q5', 15, '........PQ0010102Y', 844)
#  ->('q5', 16, '........PQ0010102Y', 843)
#  ->('q5', 17, '........PQ0010102Y', 842)
#  ->('q11', 18, '........PQ00101023', 841)
#  ->('q9', 17, '........PQ00101023........', 840)
#  ->('q9', 16, '........PQ00101023........', 839)
#  ->('q9', 15, '........PQ00101023........', 838)
#  ->('q9', 14, '........PQ00101023........', 837)
#  ->('q9', 13, '........PQ00101023........', 836)
#  ->('q9', 12, '........PQ00101023........', 835)
#  ->('q9', 11, '........PQ00101023........', 834)
#  ->('q9', 10, '........PQ00101023........', 833)
#  ->('q9', 9, '........PQ00101023........', 832)
#  ->('q3', 10, '........PQ00101023........', 831)
#  ->('q4', 11, '........PQP0101023........', 830)
#  ->('q4', 12, '........PQP0101023........', 829)
#  ->('q4', 13, '........PQP0101023........', 828)
#  ->('q4', 14, '........PQP0101023........', 827)
#  ->('q4', 15, '........PQP0101023........', 826)
#  ->('q4', 16, '........PQP0101023........', 825)
#  ->('q4', 17, '........PQP0101023........', 824)
#  ->('q4', 18, '........PQP0101023........', 823)
# Rejected at  ('q5', 16, '........PQ001012X1', 847)
#  via ..
#  ->('q0', 0, '0100101001', 888)
#  ->('q14', 0, '0100101001', 887)
#  ->('q14', 1, '0100101001', 886)
#  ->('q14', 2, '0100101001', 885)
#  ->('q14', 3, '0100101001', 884)
#  ->('q14', 4, '0100101001', 883)
#  ->('q14', 5, '0100101001', 882)
#  ->('q14', 6, '0100101001', 881)
#  ->('q14', 7, '0100101001', 880)
#  ->('q2', 6, '0100101X01', 879)
#  ->('q2', 5, '0100101X01', 878)
#  ->('q2', 4, '0100101X01', 877)
#  ->('q2', 3, '0100101X01', 876)
#  ->('q2', 2, '0100101X01', 875)
#  ->('q2', 1, '0100101X01', 874)
#  ->('q2', 0, '0100101X01', 873)
#  ->('q2', 7, '........0100101X01', 872)
#  ->('q3', 8, '........0100101X01', 871)
#  ->('q4', 9, '........P100101X01', 870)
#  ->('q4', 10, '........P100101X01', 869)
#  ->('q4', 11, '........P100101X01', 868)
#  ->('q4', 12, '........P100101X01', 867)
#  ->('q4', 13, '........P100101X01', 866)
#  ->('q4', 14, '........P100101X01', 865)
#  ->('q4', 15, '........P100101X01', 864)
#  ->('q10', 16, '........P100101201', 863)
#  ->('q8', 15, '........P1001012X1', 862)
#  ->('q8', 14, '........P1001012X1', 861)
#  ->('q8', 13, '........P1001012X1', 860)
#  ->('q8', 12, '........P1001012X1', 859)
#  ->('q8', 11, '........P1001012X1', 858)
#  ->('q8', 10, '........P1001012X1', 857)
#  ->('q8', 9, '........P1001012X1', 856)
#  ->('q8', 8, '........P1001012X1', 855)
#  ->('q3', 9, '........P1001012X1', 854)
#  ->('q5', 10, '........PQ001012X1', 853)
#  ->('q5', 11, '........PQ001012X1', 852)
#  ->('q5', 12, '........PQ001012X1', 851)
#  ->('q5', 13, '........PQ001012X1', 850)
#  ->('q5', 14, '........PQ001012X1', 849)
#  ->('q5', 15, '........PQ001012X1', 848)
#  ->('q5', 16, '........PQ001012X1', 847)
# Rejected at  ('q4', 14, '........P10010Y001', 867)
#  via ..
#  ->('q0', 0, '0100101001', 888)
#  ->('q14', 0, '0100101001', 887)
#  ->('q14', 1, '0100101001', 886)
#  ->('q14', 2, '0100101001', 885)
#  ->('q14', 3, '0100101001', 884)
#  ->('q14', 4, '0100101001', 883)
#  ->('q14', 5, '0100101001', 882)
#  ->('q14', 6, '0100101001', 881)
#  ->('q2', 5, '010010Y001', 880)
#  ->('q2', 4, '010010Y001', 879)
#  ->('q2', 3, '010010Y001', 878)
#  ->('q2', 2, '010010Y001', 877)
#  ->('q2', 1, '010010Y001', 876)
#  ->('q2', 0, '010010Y001', 875)
#  ->('q2', 7, '........010010Y001', 874)
#  ->('q3', 8, '........010010Y001', 873)
#  ->('q4', 9, '........P10010Y001', 872)
#  ->('q4', 10, '........P10010Y001', 871)
#  ->('q4', 11, '........P10010Y001', 870)
#  ->('q4', 12, '........P10010Y001', 869)
#  ->('q4', 13, '........P10010Y001', 868)
#  ->('q4', 14, '........P10010Y001', 867)
# Accepted at  ('q13', 19, '........PQPPQ23223........', 804)
#  via ..
#  ->('q0', 0, '0100101001', 888)
#  ->('q14', 0, '0100101001', 887)
#  ->('q14', 1, '0100101001', 886)
#  ->('q14', 2, '0100101001', 885)
#  ->('q14', 3, '0100101001', 884)
#  ->('q14', 4, '0100101001', 883)
#  ->('q14', 5, '0100101001', 882)
#  ->('q2', 4, '01001X1001', 881)
#  ->('q2', 3, '01001X1001', 880)
#  ->('q2', 2, '01001X1001', 879)
#  ->('q2', 1, '01001X1001', 878)
#  ->('q2', 0, '01001X1001', 877)
#  ->('q2', 7, '........01001X1001', 876)
#  ->('q3', 8, '........01001X1001', 875)
#  ->('q4', 9, '........P1001X1001', 874)
#  ->('q4', 10, '........P1001X1001', 873)
#  ->('q4', 11, '........P1001X1001', 872)
#  ->('q4', 12, '........P1001X1001', 871)
#  ->('q4', 13, '........P1001X1001', 870)
#  ->('q10', 14, '........P100121001', 869)
#  ->('q8', 13, '........P10012Y001', 868)
#  ->('q8', 12, '........P10012Y001', 867)
#  ->('q8', 11, '........P10012Y001', 866)
#  ->('q8', 10, '........P10012Y001', 865)
#  ->('q8', 9, '........P10012Y001', 864)
#  ->('q8', 8, '........P10012Y001', 863)
#  ->('q3', 9, '........P10012Y001', 862)
#  ->('q5', 10, '........PQ0012Y001', 861)
#  ->('q5', 11, '........PQ0012Y001', 860)
#  ->('q5', 12, '........PQ0012Y001', 859)
#  ->('q5', 13, '........PQ0012Y001', 858)
#  ->('q5', 14, '........PQ0012Y001', 857)
#  ->('q11', 15, '........PQ00123001', 856)
#  ->('q9', 14, '........PQ00123X01', 855)
#  ->('q9', 13, '........PQ00123X01', 854)
#  ->('q9', 12, '........PQ00123X01', 853)
#  ->('q9', 11, '........PQ00123X01', 852)
#  ->('q9', 10, '........PQ00123X01', 851)
#  ->('q9', 9, '........PQ00123X01', 850)
#  ->('q3', 10, '........PQ00123X01', 849)
#  ->('q4', 11, '........PQP0123X01', 848)
#  ->('q4', 12, '........PQP0123X01', 847)
#  ->('q4', 13, '........PQP0123X01', 846)
#  ->('q4', 14, '........PQP0123X01', 845)
#  ->('q4', 15, '........PQP0123X01', 844)
#  ->('q10', 16, '........PQP0123201', 843)
#  ->('q8', 15, '........PQP01232X1', 842)
#  ->('q8', 14, '........PQP01232X1', 841)
#  ->('q8', 13, '........PQP01232X1', 840)
#  ->('q8', 12, '........PQP01232X1', 839)
#  ->('q8', 11, '........PQP01232X1', 838)
#  ->('q8', 10, '........PQP01232X1', 837)
#  ->('q3', 11, '........PQP01232X1', 836)
#  ->('q4', 12, '........PQPP1232X1', 835)
#  ->('q4', 13, '........PQPP1232X1', 834)
#  ->('q4', 14, '........PQPP1232X1', 833)
#  ->('q4', 15, '........PQPP1232X1', 832)
#  ->('q4', 16, '........PQPP1232X1', 831)
#  ->('q10', 17, '........PQPP123221', 830)
#  ->('q8', 16, '........PQPP12322Y', 829)
#  ->('q8', 15, '........PQPP12322Y', 828)
#  ->('q8', 14, '........PQPP12322Y', 827)
#  ->('q8', 13, '........PQPP12322Y', 826)
#  ->('q8', 12, '........PQPP12322Y', 825)
#  ->('q8', 11, '........PQPP12322Y', 824)
#  ->('q3', 12, '........PQPP12322Y', 823)
#  ->('q5', 13, '........PQPPQ2322Y', 822)
#  ->('q5', 14, '........PQPPQ2322Y', 821)
#  ->('q5', 15, '........PQPPQ2322Y', 820)
#  ->('q5', 16, '........PQPPQ2322Y', 819)
#  ->('q5', 17, '........PQPPQ2322Y', 818)
#  ->('q11', 18, '........PQPPQ23223', 817)
#  ->('q9', 17, '........PQPPQ23223........', 816)
#  ->('q9', 16, '........PQPPQ23223........', 815)
#  ->('q9', 15, '........PQPPQ23223........', 814)
#  ->('q9', 14, '........PQPPQ23223........', 813)
#  ->('q9', 13, '........PQPPQ23223........', 812)
#  ->('q9', 12, '........PQPPQ23223........', 811)
#  ->('q3', 13, '........PQPPQ23223........', 810)
#  ->('q12', 14, '........PQPPQ23223........', 809)
#  ->('q12', 15, '........PQPPQ23223........', 808)
#  ->('q12', 16, '........PQPPQ23223........', 807)
#  ->('q12', 17, '........PQPPQ23223........', 806)
#  ->('q12', 18, '........PQPPQ23223........', 805)
#  ->('q13', 19, '........PQPPQ23223........', 804)
# Rejected at  ('q4', 12, '........P100Y01001', 873)
#  via ..
#  ->('q0', 0, '0100101001', 888)
#  ->('q14', 0, '0100101001', 887)
#  ->('q14', 1, '0100101001', 886)
#  ->('q14', 2, '0100101001', 885)
#  ->('q14', 3, '0100101001', 884)
#  ->('q14', 4, '0100101001', 883)
#  ->('q2', 3, '0100Y01001', 882)
#  ->('q2', 2, '0100Y01001', 881)
#  ->('q2', 1, '0100Y01001', 880)
#  ->('q2', 0, '0100Y01001', 879)
#  ->('q2', 7, '........0100Y01001', 878)
#  ->('q3', 8, '........0100Y01001', 877)
#  ->('q4', 9, '........P100Y01001', 876)
#  ->('q4', 10, '........P100Y01001', 875)
#  ->('q4', 11, '........P100Y01001', 874)
#  ->('q4', 12, '........P100Y01001', 873)
# Rejected at  ('q12', 14, '........PQP232Y001', 849)
#  via ..
#  ->('q0', 0, '0100101001', 888)
#  ->('q14', 0, '0100101001', 887)
#  ->('q14', 1, '0100101001', 886)
#  ->('q14', 2, '0100101001', 885)
#  ->('q14', 3, '0100101001', 884)
#  ->('q2', 2, '010X101001', 883)
#  ->('q2', 1, '010X101001', 882)
#  ->('q2', 0, '010X101001', 881)
#  ->('q2', 7, '........010X101001', 880)
#  ->('q3', 8, '........010X101001', 879)
#  ->('q4', 9, '........P10X101001', 878)
#  ->('q4', 10, '........P10X101001', 877)
#  ->('q4', 11, '........P10X101001', 876)
#  ->('q10', 12, '........P102101001', 875)
#  ->('q8', 11, '........P102Y01001', 874)
#  ->('q8', 10, '........P102Y01001', 873)
#  ->('q8', 9, '........P102Y01001', 872)
#  ->('q8', 8, '........P102Y01001', 871)
#  ->('q3', 9, '........P102Y01001', 870)
#  ->('q5', 10, '........PQ02Y01001', 869)
#  ->('q5', 11, '........PQ02Y01001', 868)
#  ->('q5', 12, '........PQ02Y01001', 867)
#  ->('q11', 13, '........PQ02301001', 866)
#  ->('q9', 12, '........PQ023X1001', 865)
#  ->('q9', 11, '........PQ023X1001', 864)
#  ->('q9', 10, '........PQ023X1001', 863)
#  ->('q9', 9, '........PQ023X1001', 862)
#  ->('q3', 10, '........PQ023X1001', 861)
#  ->('q4', 11, '........PQP23X1001', 860)
#  ->('q4', 12, '........PQP23X1001', 859)
#  ->('q4', 13, '........PQP23X1001', 858)
#  ->('q10', 14, '........PQP2321001', 857)
#  ->('q8', 13, '........PQP232Y001', 856)
#  ->('q8', 12, '........PQP232Y001', 855)
#  ->('q8', 11, '........PQP232Y001', 854)
#  ->('q8', 10, '........PQP232Y001', 853)
#  ->('q3', 11, '........PQP232Y001', 852)
#  ->('q12', 12, '........PQP232Y001', 851)
#  ->('q12', 13, '........PQP232Y001', 850)
#  ->('q12', 14, '........PQP232Y001', 849)
# Rejected at  ('q5', 11, '........PQ2X101001', 872)
#  via ..
#  ->('q0', 0, '0100101001', 888)
#  ->('q14', 0, '0100101001', 887)
#  ->('q14', 1, '0100101001', 886)
#  ->('q14', 2, '0100101001', 885)
#  ->('q2', 1, '01X0101001', 884)
#  ->('q2', 0, '01X0101001', 883)
#  ->('q2', 7, '........01X0101001', 882)
#  ->('q3', 8, '........01X0101001', 881)
#  ->('q4', 9, '........P1X0101001', 880)
#  ->('q4', 10, '........P1X0101001', 879)
#  ->('q10', 11, '........P120101001', 878)
#  ->('q8', 10, '........P12X101001', 877)
#  ->('q8', 9, '........P12X101001', 876)
#  ->('q8', 8, '........P12X101001', 875)
#  ->('q3', 9, '........P12X101001', 874)
#  ->('q5', 10, '........PQ2X101001', 873)
#  ->('q5', 11, '........PQ2X101001', 872)
# Rejected at  ('q4', 9, '........PY00101001', 882)
#  via ..
#  ->('q0', 0, '0100101001', 888)
#  ->('q14', 0, '0100101001', 887)
#  ->('q14', 1, '0100101001', 886)
#  ->('q2', 0, '0Y00101001', 885)
#  ->('q2', 7, '........0Y00101001', 884)
#  ->('q3', 8, '........0Y00101001', 883)
#  ->('q4', 9, '........PY00101001', 882)
# Rejected at  ('q6', 9, '........X100101001', 884)
#  via ..
#  ->('q0', 0, '0100101001', 888)
#  ->('q14', 0, '0100101001', 887)
#  ->('q2', 7, '........X100101001', 886)
#  ->('q3', 8, '........X100101001', 885)
#  ->('q6', 9, '........X100101001', 884)

# %%
explore_tm(wpw, "010#010", 44)
# Out:
# Allocating  8  tape cells to the RIGHT!
# Detailing the halted configs now.
# Accepted at  ('q6', 8, 'XYX#XYX........', 12)
#  via ..
#  ->('q0', 0, '010#010', 44)
#  ->('q1', 1, 'X10#010', 43)
#  ->('q1', 2, 'X10#010', 42)
#  ->('q1', 3, 'X10#010', 41)
#  ->('q2', 4, 'X10#010', 40)
#  ->('q3', 3, 'X10#X10', 39)
#  ->('q4', 2, 'X10#X10', 38)
#  ->('q4', 1, 'X10#X10', 37)
#  ->('q4', 0, 'X10#X10', 36)
#  ->('q0', 1, 'X10#X10', 35)
#  ->('q7', 2, 'XY0#X10', 34)
#  ->('q7', 3, 'XY0#X10', 33)
#  ->('q8', 4, 'XY0#X10', 32)
#  ->('q8', 5, 'XY0#X10', 31)
#  ->('q9', 4, 'XY0#XY0', 30)
#  ->('q9', 3, 'XY0#XY0', 29)
#  ->('q10', 2, 'XY0#XY0', 28)
#  ->('q10', 1, 'XY0#XY0', 27)
#  ->('q0', 2, 'XY0#XY0', 26)
#  ->('q1', 3, 'XYX#XY0', 25)
#  ->('q2', 4, 'XYX#XY0', 24)
#  ->('q2', 5, 'XYX#XY0', 23)
#  ->('q2', 6, 'XYX#XY0', 22)
#  ->('q3', 5, 'XYX#XYX', 21)
#  ->('q3', 4, 'XYX#XYX', 20)
#  ->('q3', 3, 'XYX#XYX', 19)
#  ->('q4', 2, 'XYX#XYX', 18)
#  ->('q0', 3, 'XYX#XYX', 17)
#  ->('q5', 4, 'XYX#XYX', 16)
#  ->('q5', 5, 'XYX#XYX', 15)
#  ->('q5', 6, 'XYX#XYX', 14)
#  ->('q5', 7, 'XYX#XYX', 13)
#  ->('q6', 8, 'XYX#XYX........', 12)

# %%
explore_tm(wpw, "010#011", 33)
# Out:
# Detailing the halted configs now.
# Rejected at  ('q2', 6, 'XYX#XY1', 11)
#  via ..
#  ->('q0', 0, '010#011', 33)
#  ->('q1', 1, 'X10#011', 32)
#  ->('q1', 2, 'X10#011', 31)
#  ->('q1', 3, 'X10#011', 30)
#  ->('q2', 4, 'X10#011', 29)
#  ->('q3', 3, 'X10#X11', 28)
#  ->('q4', 2, 'X10#X11', 27)
#  ->('q4', 1, 'X10#X11', 26)
#  ->('q4', 0, 'X10#X11', 25)
#  ->('q0', 1, 'X10#X11', 24)
#  ->('q7', 2, 'XY0#X11', 23)
#  ->('q7', 3, 'XY0#X11', 22)
#  ->('q8', 4, 'XY0#X11', 21)
#  ->('q8', 5, 'XY0#X11', 20)
#  ->('q9', 4, 'XY0#XY1', 19)
#  ->('q9', 3, 'XY0#XY1', 18)
#  ->('q10', 2, 'XY0#XY1', 17)
#  ->('q10', 1, 'XY0#XY1', 16)
#  ->('q0', 2, 'XY0#XY1', 15)
#  ->('q1', 3, 'XYX#XY1', 14)
#  ->('q2', 4, 'XYX#XY1', 13)
#  ->('q2', 5, 'XYX#XY1', 12)
#  ->('q2', 6, 'XYX#XY1', 11)

# %%
explore_tm(wpw, "1#1", 54)
# Out:
# Allocating  8  tape cells to the RIGHT!
# Detailing the halted configs now.
# Accepted at  ('q6', 4, 'Y#Y........', 46)
#  via ..
#  ->('q0', 0, '1#1', 54)
#  ->('q7', 1, 'Y#1', 53)
#  ->('q8', 2, 'Y#1', 52)
#  ->('q9', 1, 'Y#Y', 51)
#  ->('q10', 0, 'Y#Y', 50)
#  ->('q0', 1, 'Y#Y', 49)
#  ->('q5', 2, 'Y#Y', 48)
#  ->('q5', 3, 'Y#Y', 47)
#  ->('q6', 4, 'Y#Y........', 46)

# %%
explore_tm(wpw, "01#01", 18)
#run_tm(wpw, "01#01", 18)
# Out:
# Allocating  8  tape cells to the RIGHT!
# TM hasn't halted.
# The truncated paths so far are as follows.
# [('q0', 0, '01#01', 18), ('q1', 1, 'X1#01', 17), ('q1', 2, 'X1#01', 16), ('q2', 3, 'X1#01', 15), ('q3', 2, 'X1#X1', 14), ('q4', 1, 'X1#X1', 13), ('q4', 0, 'X1#X1', 12), ('q0', 1, 'X1#X1', 11), ('q7', 2, 'XY#X1', 10), ('q8', 3, 'XY#X1', 9), ('q8', 4, 'XY#X1', 8), ('q9', 3, 'XY#XY', 7), ('q9', 2, 'XY#XY', 6), ('q10', 1, 'XY#XY', 5), ('q0', 2, 'XY#XY', 4), ('q5', 3, 'XY#XY', 3), ('q5', 4, 'XY#XY', 2), ('q5', 5, 'XY#XY', 1)]

# %%
explore_tm(wpw, "010001101#010001101", 300)
# Out:
# Allocating  8  tape cells to the RIGHT!
# Detailing the halted configs now.
# Accepted at  ('q6', 20, 'XYXXXYYXY#XYXXXYYXY........', 100)
#  via ..
#  ->('q0', 0, '010001101#010001101', 300)
#  ->('q1', 1, 'X10001101#010001101', 299)
#  ->('q1', 2, 'X10001101#010001101', 298)
#  ->('q1', 3, 'X10001101#010001101', 297)
#  ->('q1', 4, 'X10001101#010001101', 296)
#  ->('q1', 5, 'X10001101#010001101', 295)
#  ->('q1', 6, 'X10001101#010001101', 294)
#  ->('q1', 7, 'X10001101#010001101', 293)
#  ->('q1', 8, 'X10001101#010001101', 292)
#  ->('q1', 9, 'X10001101#010001101', 291)
#  ->('q2', 10, 'X10001101#010001101', 290)
#  ->('q3', 9, 'X10001101#X10001101', 289)
#  ->('q4', 8, 'X10001101#X10001101', 288)
#  ->('q4', 7, 'X10001101#X10001101', 287)
#  ->('q4', 6, 'X10001101#X10001101', 286)
#  ->('q4', 5, 'X10001101#X10001101', 285)
#  ->('q4', 4, 'X10001101#X10001101', 284)
#  ->('q4', 3, 'X10001101#X10001101', 283)
#  ->('q4', 2, 'X10001101#X10001101', 282)
#  ->('q4', 1, 'X10001101#X10001101', 281)
#  ->('q4', 0, 'X10001101#X10001101', 280)
#  ->('q0', 1, 'X10001101#X10001101', 279)
#  ->('q7', 2, 'XY0001101#X10001101', 278)
#  ->('q7', 3, 'XY0001101#X10001101', 277)
#  ->('q7', 4, 'XY0001101#X10001101', 276)
#  ->('q7', 5, 'XY0001101#X10001101', 275)
#  ->('q7', 6, 'XY0001101#X10001101', 274)
#  ->('q7', 7, 'XY0001101#X10001101', 273)
#  ->('q7', 8, 'XY0001101#X10001101', 272)
#  ->('q7', 9, 'XY0001101#X10001101', 271)
#  ->('q8', 10, 'XY0001101#X10001101', 270)
#  ->('q8', 11, 'XY0001101#X10001101', 269)
#  ->('q9', 10, 'XY0001101#XY0001101', 268)
#  ->('q9', 9, 'XY0001101#XY0001101', 267)
#  ->('q10', 8, 'XY0001101#XY0001101', 266)
#  ->('q10', 7, 'XY0001101#XY0001101', 265)
#  ->('q10', 6, 'XY0001101#XY0001101', 264)
#  ->('q10', 5, 'XY0001101#XY0001101', 263)
#  ->('q10', 4, 'XY0001101#XY0001101', 262)
#  ->('q10', 3, 'XY0001101#XY0001101', 261)
#  ->('q10', 2, 'XY0001101#XY0001101', 260)
#  ->('q10', 1, 'XY0001101#XY0001101', 259)
#  ->('q0', 2, 'XY0001101#XY0001101', 258)
#  ->('q1', 3, 'XYX001101#XY0001101', 257)
#  ->('q1', 4, 'XYX001101#XY0001101', 256)
#  ->('q1', 5, 'XYX001101#XY0001101', 255)
#  ->('q1', 6, 'XYX001101#XY0001101', 254)
#  ->('q1', 7, 'XYX001101#XY0001101', 253)
#  ->('q1', 8, 'XYX001101#XY0001101', 252)
#  ->('q1', 9, 'XYX001101#XY0001101', 251)
#  ->('q2', 10, 'XYX001101#XY0001101', 250)
#  ->('q2', 11, 'XYX001101#XY0001101', 249)
#  ->('q2', 12, 'XYX001101#XY0001101', 248)
#  ->('q3', 11, 'XYX001101#XYX001101', 247)
#  ->('q3', 10, 'XYX001101#XYX001101', 246)
#  ->('q3', 9, 'XYX001101#XYX001101', 245)
#  ->('q4', 8, 'XYX001101#XYX001101', 244)
#  ->('q4', 7, 'XYX001101#XYX001101', 243)
#  ->('q4', 6, 'XYX001101#XYX001101', 242)
#  ->('q4', 5, 'XYX001101#XYX001101', 241)
#  ->('q4', 4, 'XYX001101#XYX001101', 240)
#  ->('q4', 3, 'XYX001101#XYX001101', 239)
#  ->('q4', 2, 'XYX001101#XYX001101', 238)
#  ->('q0', 3, 'XYX001101#XYX001101', 237)
#  ->('q1', 4, 'XYXX01101#XYX001101', 236)
#  ->('q1', 5, 'XYXX01101#XYX001101', 235)
#  ->('q1', 6, 'XYXX01101#XYX001101', 234)
#  ->('q1', 7, 'XYXX01101#XYX001101', 233)
#  ->('q1', 8, 'XYXX01101#XYX001101', 232)
#  ->('q1', 9, 'XYXX01101#XYX001101', 231)
#  ->('q2', 10, 'XYXX01101#XYX001101', 230)
#  ->('q2', 11, 'XYXX01101#XYX001101', 229)
#  ->('q2', 12, 'XYXX01101#XYX001101', 228)
#  ->('q2', 13, 'XYXX01101#XYX001101', 227)
#  ->('q3', 12, 'XYXX01101#XYXX01101', 226)
#  ->('q3', 11, 'XYXX01101#XYXX01101', 225)
#  ->('q3', 10, 'XYXX01101#XYXX01101', 224)
#  ->('q3', 9, 'XYXX01101#XYXX01101', 223)
#  ->('q4', 8, 'XYXX01101#XYXX01101', 222)
#  ->('q4', 7, 'XYXX01101#XYXX01101', 221)
#  ->('q4', 6, 'XYXX01101#XYXX01101', 220)
#  ->('q4', 5, 'XYXX01101#XYXX01101', 219)
#  ->('q4', 4, 'XYXX01101#XYXX01101', 218)
#  ->('q4', 3, 'XYXX01101#XYXX01101', 217)
#  ->('q0', 4, 'XYXX01101#XYXX01101', 216)
#  ->('q1', 5, 'XYXXX1101#XYXX01101', 215)
#  ->('q1', 6, 'XYXXX1101#XYXX01101', 214)
#  ->('q1', 7, 'XYXXX1101#XYXX01101', 213)
#  ->('q1', 8, 'XYXXX1101#XYXX01101', 212)
#  ->('q1', 9, 'XYXXX1101#XYXX01101', 211)
#  ->('q2', 10, 'XYXXX1101#XYXX01101', 210)
#  ->('q2', 11, 'XYXXX1101#XYXX01101', 209)
#  ->('q2', 12, 'XYXXX1101#XYXX01101', 208)
#  ->('q2', 13, 'XYXXX1101#XYXX01101', 207)
#  ->('q2', 14, 'XYXXX1101#XYXX01101', 206)
#  ->('q3', 13, 'XYXXX1101#XYXXX1101', 205)
#  ->('q3', 12, 'XYXXX1101#XYXXX1101', 204)
#  ->('q3', 11, 'XYXXX1101#XYXXX1101', 203)
#  ->('q3', 10, 'XYXXX1101#XYXXX1101', 202)
#  ->('q3', 9, 'XYXXX1101#XYXXX1101', 201)
#  ->('q4', 8, 'XYXXX1101#XYXXX1101', 200)
#  ->('q4', 7, 'XYXXX1101#XYXXX1101', 199)
#  ->('q4', 6, 'XYXXX1101#XYXXX1101', 198)
#  ->('q4', 5, 'XYXXX1101#XYXXX1101', 197)
#  ->('q4', 4, 'XYXXX1101#XYXXX1101', 196)
#  ->('q0', 5, 'XYXXX1101#XYXXX1101', 195)
#  ->('q7', 6, 'XYXXXY101#XYXXX1101', 194)
#  ->('q7', 7, 'XYXXXY101#XYXXX1101', 193)
#  ->('q7', 8, 'XYXXXY101#XYXXX1101', 192)
#  ->('q7', 9, 'XYXXXY101#XYXXX1101', 191)
#  ->('q8', 10, 'XYXXXY101#XYXXX1101', 190)
#  ->('q8', 11, 'XYXXXY101#XYXXX1101', 189)
#  ->('q8', 12, 'XYXXXY101#XYXXX1101', 188)
#  ->('q8', 13, 'XYXXXY101#XYXXX1101', 187)
#  ->('q8', 14, 'XYXXXY101#XYXXX1101', 186)
#  ->('q8', 15, 'XYXXXY101#XYXXX1101', 185)
#  ->('q9', 14, 'XYXXXY101#XYXXXY101', 184)
#  ->('q9', 13, 'XYXXXY101#XYXXXY101', 183)
#  ->('q9', 12, 'XYXXXY101#XYXXXY101', 182)
#  ->('q9', 11, 'XYXXXY101#XYXXXY101', 181)
#  ->('q9', 10, 'XYXXXY101#XYXXXY101', 180)
#  ->('q9', 9, 'XYXXXY101#XYXXXY101', 179)
#  ->('q10', 8, 'XYXXXY101#XYXXXY101', 178)
#  ->('q10', 7, 'XYXXXY101#XYXXXY101', 177)
#  ->('q10', 6, 'XYXXXY101#XYXXXY101', 176)
#  ->('q10', 5, 'XYXXXY101#XYXXXY101', 175)
#  ->('q0', 6, 'XYXXXY101#XYXXXY101', 174)
#  ->('q7', 7, 'XYXXXYY01#XYXXXY101', 173)
#  ->('q7', 8, 'XYXXXYY01#XYXXXY101', 172)
#  ->('q7', 9, 'XYXXXYY01#XYXXXY101', 171)
#  ->('q8', 10, 'XYXXXYY01#XYXXXY101', 170)
#  ->('q8', 11, 'XYXXXYY01#XYXXXY101', 169)
#  ->('q8', 12, 'XYXXXYY01#XYXXXY101', 168)
#  ->('q8', 13, 'XYXXXYY01#XYXXXY101', 167)
#  ->('q8', 14, 'XYXXXYY01#XYXXXY101', 166)
#  ->('q8', 15, 'XYXXXYY01#XYXXXY101', 165)
#  ->('q8', 16, 'XYXXXYY01#XYXXXY101', 164)
#  ->('q9', 15, 'XYXXXYY01#XYXXXYY01', 163)
#  ->('q9', 14, 'XYXXXYY01#XYXXXYY01', 162)
#  ->('q9', 13, 'XYXXXYY01#XYXXXYY01', 161)
#  ->('q9', 12, 'XYXXXYY01#XYXXXYY01', 160)
#  ->('q9', 11, 'XYXXXYY01#XYXXXYY01', 159)
#  ->('q9', 10, 'XYXXXYY01#XYXXXYY01', 158)
#  ->('q9', 9, 'XYXXXYY01#XYXXXYY01', 157)
#  ->('q10', 8, 'XYXXXYY01#XYXXXYY01', 156)
#  ->('q10', 7, 'XYXXXYY01#XYXXXYY01', 155)
#  ->('q10', 6, 'XYXXXYY01#XYXXXYY01', 154)
#  ->('q0', 7, 'XYXXXYY01#XYXXXYY01', 153)
#  ->('q1', 8, 'XYXXXYYX1#XYXXXYY01', 152)
#  ->('q1', 9, 'XYXXXYYX1#XYXXXYY01', 151)
#  ->('q2', 10, 'XYXXXYYX1#XYXXXYY01', 150)
#  ->('q2', 11, 'XYXXXYYX1#XYXXXYY01', 149)
#  ->('q2', 12, 'XYXXXYYX1#XYXXXYY01', 148)
#  ->('q2', 13, 'XYXXXYYX1#XYXXXYY01', 147)
#  ->('q2', 14, 'XYXXXYYX1#XYXXXYY01', 146)
#  ->('q2', 15, 'XYXXXYYX1#XYXXXYY01', 145)
#  ->('q2', 16, 'XYXXXYYX1#XYXXXYY01', 144)
#  ->('q2', 17, 'XYXXXYYX1#XYXXXYY01', 143)
#  ->('q3', 16, 'XYXXXYYX1#XYXXXYYX1', 142)
#  ->('q3', 15, 'XYXXXYYX1#XYXXXYYX1', 141)
#  ->('q3', 14, 'XYXXXYYX1#XYXXXYYX1', 140)
#  ->('q3', 13, 'XYXXXYYX1#XYXXXYYX1', 139)
#  ->('q3', 12, 'XYXXXYYX1#XYXXXYYX1', 138)
#  ->('q3', 11, 'XYXXXYYX1#XYXXXYYX1', 137)
#  ->('q3', 10, 'XYXXXYYX1#XYXXXYYX1', 136)
#  ->('q3', 9, 'XYXXXYYX1#XYXXXYYX1', 135)
#  ->('q4', 8, 'XYXXXYYX1#XYXXXYYX1', 134)
#  ->('q4', 7, 'XYXXXYYX1#XYXXXYYX1', 133)
#  ->('q0', 8, 'XYXXXYYX1#XYXXXYYX1', 132)
#  ->('q7', 9, 'XYXXXYYXY#XYXXXYYX1', 131)
#  ->('q8', 10, 'XYXXXYYXY#XYXXXYYX1', 130)
#  ->('q8', 11, 'XYXXXYYXY#XYXXXYYX1', 129)
#  ->('q8', 12, 'XYXXXYYXY#XYXXXYYX1', 128)
#  ->('q8', 13, 'XYXXXYYXY#XYXXXYYX1', 127)
#  ->('q8', 14, 'XYXXXYYXY#XYXXXYYX1', 126)
#  ->('q8', 15, 'XYXXXYYXY#XYXXXYYX1', 125)
#  ->('q8', 16, 'XYXXXYYXY#XYXXXYYX1', 124)
#  ->('q8', 17, 'XYXXXYYXY#XYXXXYYX1', 123)
#  ->('q8', 18, 'XYXXXYYXY#XYXXXYYX1', 122)
#  ->('q9', 17, 'XYXXXYYXY#XYXXXYYXY', 121)
#  ->('q9', 16, 'XYXXXYYXY#XYXXXYYXY', 120)
#  ->('q9', 15, 'XYXXXYYXY#XYXXXYYXY', 119)
#  ->('q9', 14, 'XYXXXYYXY#XYXXXYYXY', 118)
#  ->('q9', 13, 'XYXXXYYXY#XYXXXYYXY', 117)
#  ->('q9', 12, 'XYXXXYYXY#XYXXXYYXY', 116)
#  ->('q9', 11, 'XYXXXYYXY#XYXXXYYXY', 115)
#  ->('q9', 10, 'XYXXXYYXY#XYXXXYYXY', 114)
#  ->('q9', 9, 'XYXXXYYXY#XYXXXYYXY', 113)
#  ->('q10', 8, 'XYXXXYYXY#XYXXXYYXY', 112)
#  ->('q0', 9, 'XYXXXYYXY#XYXXXYYXY', 111)
#  ->('q5', 10, 'XYXXXYYXY#XYXXXYYXY', 110)
#  ->('q5', 11, 'XYXXXYYXY#XYXXXYYXY', 109)
#  ->('q5', 12, 'XYXXXYYXY#XYXXXYYXY', 108)
#  ->('q5', 13, 'XYXXXYYXY#XYXXXYYXY', 107)
#  ->('q5', 14, 'XYXXXYYXY#XYXXXYYXY', 106)
#  ->('q5', 15, 'XYXXXYYXY#XYXXXYYXY', 105)
#  ->('q5', 16, 'XYXXXYYXY#XYXXXYYXY', 104)
#  ->('q5', 17, 'XYXXXYYXY#XYXXXYYXY', 103)
#  ->('q5', 18, 'XYXXXYYXY#XYXXXYYXY', 102)
#  ->('q5', 19, 'XYXXXYYXY#XYXXXYYXY', 101)
#  ->('q6', 20, 'XYXXXYYXY#XYXXXYYXY........', 100)

# %%
wwndtm
# Out:
# {'B': '.',
#  'Delta': {('q0', '.'): {('q1', '.', 'R')},
#   ('q0', '0'): {('q14', '0', 'S')},
#   ('q0', '1'): {('q14', '1', 'S')},
#   ('q10', '.'): {('q8', '.', 'L')},
#   ('q10', '0'): {('q8', 'X', 'L')},
#   ('q10', '1'): {('q8', 'Y', 'L')},
#   ('q11', '.'): {('q9', '.', 'L')},
#   ('q11', '0'): {('q9', 'X', 'L')},
#   ('q11', '1'): {('q9', 'Y', 'L')},
#   ('q12', '.'): {('q13', '.', 'R')},
#   ('q12', '2'): {('q12', '2', 'R')},
#   ('q12', '3'): {('q12', '3', 'R')},
#   ('q14', '0'): {('q14', '0', 'R'), ('q2', 'X', 'L')},
#   ('q14', '1'): {('q14', '1', 'R'), ('q2', 'Y', 'L')},
#   ('q2', '.'): {('q3', '.', 'R')},
#   ('q2', '0'): {('q2', '0', 'L')},
#   ('q2', '1'): {('q2', '1', 'L')},
#   ('q3', '0'): {('q4', 'P', 'R')},
#   ('q3', '1'): {('q5', 'Q', 'R')},
#   ('q3', '2'): {('q12', '2', 'R')},
#   ('q3', '3'): {('q12', '3', 'R')},
#   ('q3', 'X'): {('q6', 'X', 'R')},
#   ('q3', 'Y'): {('q7', 'Y', 'R')},
#   ('q4', '0'): {('q4', '0', 'R')},
#   ('q4', '1'): {('q4', '1', 'R')},
#   ('q4', '2'): {('q4', '2', 'R')},
#   ('q4', '3'): {('q4', '3', 'R')},
#   ('q4', 'X'): {('q10', '2', 'R')},
#   ('q5', '0'): {('q5', '0', 'R')},
#   ('q5', '1'): {('q5', '1', 'R')},
#   ('q5', '2'): {('q5', '2', 'R')},
#   ('q5', '3'): {('q5', '3', 'R')},
#   ('q5', 'Y'): {('q11', '3', 'R')},
#   ('q8', '0'): {('q8', '0', 'L')},
#   ('q8', '1'): {('q8', '1', 'L')},
#   ('q8', '2'): {('q8', '2', 'L')},
#   ('q8', '3'): {('q8', '3', 'L')},
#   ('q8', 'P'): {('q3', 'P', 'R')},
#   ('q9', '0'): {('q9', '0', 'L')},
#   ('q9', '1'): {('q9', '1', 'L')},
#   ('q9', '2'): {('q9', '2', 'L')},
#   ('q9', '3'): {('q9', '3', 'L')},
#   ('q9', 'Q'): {('q3', 'Q', 'R')}},
#  'F': {'q1', 'q13'},
#  'Gamma': {'.', '0', '1', '2', '3', 'P', 'Q', 'X', 'Y'},
#  'Q': {'q0',
#   'q1',
#   'q10',
#   'q11',
#   'q12',
#   'q13',
#   'q14',
#   'q2',
#   'q3',
#   'q4',
#   'q5',
#   'q6',
#   'q7',
#   'q8',
#   'q9'},
#  'Sigma': {'0', '1'},
#  'q0': 'q0'}

# %%
dotObj_tm(wwndtm)

# %%
dotObj_tm(wwndtm, True)

# %%
wwndtmobj = dotObj_tm(wwndtm)

# %%
explore_tm(wwndtm, "010010", 88)
# Out:
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the RIGHT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the RIGHT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the RIGHT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# Detailing the halted configs now.
# Rejected at  ('q14', 6, '010010', 81)
#  via ..
#  ->('q0', 0, '010010', 88)
#  ->('q14', 0, '010010', 87)
#  ->('q14', 1, '010010', 86)
#  ->('q14', 2, '010010', 85)
#  ->('q14', 3, '010010', 84)
#  ->('q14', 4, '010010', 83)
#  ->('q14', 5, '010010', 82)
#  ->('q14', 6, '010010', 81)
# Rejected at  ('q5', 14, '........PQ0012........', 57)
#  via ..
#  ->('q0', 0, '010010', 88)
#  ->('q14', 0, '010010', 87)
#  ->('q14', 1, '010010', 86)
#  ->('q14', 2, '010010', 85)
#  ->('q14', 3, '010010', 84)
#  ->('q14', 4, '010010', 83)
#  ->('q14', 5, '010010', 82)
#  ->('q2', 4, '01001X', 81)
#  ->('q2', 3, '01001X', 80)
#  ->('q2', 2, '01001X', 79)
#  ->('q2', 1, '01001X', 78)
#  ->('q2', 0, '01001X', 77)
#  ->('q2', 7, '........01001X', 76)
#  ->('q3', 8, '........01001X', 75)
#  ->('q4', 9, '........P1001X', 74)
#  ->('q4', 10, '........P1001X', 73)
#  ->('q4', 11, '........P1001X', 72)
#  ->('q4', 12, '........P1001X', 71)
#  ->('q4', 13, '........P1001X', 70)
#  ->('q10', 14, '........P10012', 69)
#  ->('q8', 13, '........P10012........', 68)
#  ->('q8', 12, '........P10012........', 67)
#  ->('q8', 11, '........P10012........', 66)
#  ->('q8', 10, '........P10012........', 65)
#  ->('q8', 9, '........P10012........', 64)
#  ->('q8', 8, '........P10012........', 63)
#  ->('q3', 9, '........P10012........', 62)
#  ->('q5', 10, '........PQ0012........', 61)
#  ->('q5', 11, '........PQ0012........', 60)
#  ->('q5', 12, '........PQ0012........', 59)
#  ->('q5', 13, '........PQ0012........', 58)
#  ->('q5', 14, '........PQ0012........', 57)
# Rejected at  ('q4', 12, '........P100Y0', 73)
#  via ..
#  ->('q0', 0, '010010', 88)
#  ->('q14', 0, '010010', 87)
#  ->('q14', 1, '010010', 86)
#  ->('q14', 2, '010010', 85)
#  ->('q14', 3, '010010', 84)
#  ->('q14', 4, '010010', 83)
#  ->('q2', 3, '0100Y0', 82)
#  ->('q2', 2, '0100Y0', 81)
#  ->('q2', 1, '0100Y0', 80)
#  ->('q2', 0, '0100Y0', 79)
#  ->('q2', 7, '........0100Y0', 78)
#  ->('q3', 8, '........0100Y0', 77)
#  ->('q4', 9, '........P100Y0', 76)
#  ->('q4', 10, '........P100Y0', 75)
#  ->('q4', 11, '........P100Y0', 74)
#  ->('q4', 12, '........P100Y0', 73)
# Accepted at  ('q13', 15, '........PQP232........', 48)
#  via ..
#  ->('q0', 0, '010010', 88)
#  ->('q14', 0, '010010', 87)
#  ->('q14', 1, '010010', 86)
#  ->('q14', 2, '010010', 85)
#  ->('q14', 3, '010010', 84)
#  ->('q2', 2, '010X10', 83)
#  ->('q2', 1, '010X10', 82)
#  ->('q2', 0, '010X10', 81)
#  ->('q2', 7, '........010X10', 80)
#  ->('q3', 8, '........010X10', 79)
#  ->('q4', 9, '........P10X10', 78)
#  ->('q4', 10, '........P10X10', 77)
#  ->('q4', 11, '........P10X10', 76)
#  ->('q10', 12, '........P10210', 75)
#  ->('q8', 11, '........P102Y0', 74)
#  ->('q8', 10, '........P102Y0', 73)
#  ->('q8', 9, '........P102Y0', 72)
#  ->('q8', 8, '........P102Y0', 71)
#  ->('q3', 9, '........P102Y0', 70)
#  ->('q5', 10, '........PQ02Y0', 69)
#  ->('q5', 11, '........PQ02Y0', 68)
#  ->('q5', 12, '........PQ02Y0', 67)
#  ->('q11', 13, '........PQ0230', 66)
#  ->('q9', 12, '........PQ023X', 65)
#  ->('q9', 11, '........PQ023X', 64)
#  ->('q9', 10, '........PQ023X', 63)
#  ->('q9', 9, '........PQ023X', 62)
#  ->('q3', 10, '........PQ023X', 61)
#  ->('q4', 11, '........PQP23X', 60)
#  ->('q4', 12, '........PQP23X', 59)
#  ->('q4', 13, '........PQP23X', 58)
#  ->('q10', 14, '........PQP232', 57)
#  ->('q8', 13, '........PQP232........', 56)
#  ->('q8', 12, '........PQP232........', 55)
#  ->('q8', 11, '........PQP232........', 54)
#  ->('q8', 10, '........PQP232........', 53)
#  ->('q3', 11, '........PQP232........', 52)
#  ->('q12', 12, '........PQP232........', 51)
#  ->('q12', 13, '........PQP232........', 50)
#  ->('q12', 14, '........PQP232........', 49)
#  ->('q13', 15, '........PQP232........', 48)
# Rejected at  ('q5', 11, '........PQ2X10', 72)
#  via ..
#  ->('q0', 0, '010010', 88)
#  ->('q14', 0, '010010', 87)
#  ->('q14', 1, '010010', 86)
#  ->('q14', 2, '010010', 85)
#  ->('q2', 1, '01X010', 84)
#  ->('q2', 0, '01X010', 83)
#  ->('q2', 7, '........01X010', 82)
#  ->('q3', 8, '........01X010', 81)
#  ->('q4', 9, '........P1X010', 80)
#  ->('q4', 10, '........P1X010', 79)
#  ->('q10', 11, '........P12010', 78)
#  ->('q8', 10, '........P12X10', 77)
#  ->('q8', 9, '........P12X10', 76)
#  ->('q8', 8, '........P12X10', 75)
#  ->('q3', 9, '........P12X10', 74)
#  ->('q5', 10, '........PQ2X10', 73)
#  ->('q5', 11, '........PQ2X10', 72)
# Rejected at  ('q4', 9, '........PY0010', 82)
#  via ..
#  ->('q0', 0, '010010', 88)
#  ->('q14', 0, '010010', 87)
#  ->('q14', 1, '010010', 86)
#  ->('q2', 0, '0Y0010', 85)
#  ->('q2', 7, '........0Y0010', 84)
#  ->('q3', 8, '........0Y0010', 83)
#  ->('q4', 9, '........PY0010', 82)
# Rejected at  ('q6', 9, '........X10010', 84)
#  via ..
#  ->('q0', 0, '010010', 88)
#  ->('q14', 0, '010010', 87)
#  ->('q2', 7, '........X10010', 86)
#  ->('q3', 8, '........X10010', 85)
#  ->('q6', 9, '........X10010', 84)

# %%
explore_tm(wwndtm, "0101", 45)
# Out:
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the RIGHT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the RIGHT!
# Allocating  8  tape cells to the LEFT!
# Detailing the halted configs now.
# Rejected at  ('q14', 4, '0101', 40)
#  via ..
#  ->('q0', 0, '0101', 45)
#  ->('q14', 0, '0101', 44)
#  ->('q14', 1, '0101', 43)
#  ->('q14', 2, '0101', 42)
#  ->('q14', 3, '0101', 41)
#  ->('q14', 4, '0101', 40)
# Rejected at  ('q4', 11, '........P10Y', 33)
#  via ..
#  ->('q0', 0, '0101', 45)
#  ->('q14', 0, '0101', 44)
#  ->('q14', 1, '0101', 43)
#  ->('q14', 2, '0101', 42)
#  ->('q14', 3, '0101', 41)
#  ->('q2', 2, '010Y', 40)
#  ->('q2', 1, '010Y', 39)
#  ->('q2', 0, '010Y', 38)
#  ->('q2', 7, '........010Y', 37)
#  ->('q3', 8, '........010Y', 36)
#  ->('q4', 9, '........P10Y', 35)
#  ->('q4', 10, '........P10Y', 34)
#  ->('q4', 11, '........P10Y', 33)
# Accepted at  ('q13', 13, '........PQ23........', 21)
#  via ..
#  ->('q0', 0, '0101', 45)
#  ->('q14', 0, '0101', 44)
#  ->('q14', 1, '0101', 43)
#  ->('q14', 2, '0101', 42)
#  ->('q2', 1, '01X1', 41)
#  ->('q2', 0, '01X1', 40)
#  ->('q2', 7, '........01X1', 39)
#  ->('q3', 8, '........01X1', 38)
#  ->('q4', 9, '........P1X1', 37)
#  ->('q4', 10, '........P1X1', 36)
#  ->('q10', 11, '........P121', 35)
#  ->('q8', 10, '........P12Y', 34)
#  ->('q8', 9, '........P12Y', 33)
#  ->('q8', 8, '........P12Y', 32)
#  ->('q3', 9, '........P12Y', 31)
#  ->('q5', 10, '........PQ2Y', 30)
#  ->('q5', 11, '........PQ2Y', 29)
#  ->('q11', 12, '........PQ23', 28)
#  ->('q9', 11, '........PQ23........', 27)
#  ->('q9', 10, '........PQ23........', 26)
#  ->('q9', 9, '........PQ23........', 25)
#  ->('q3', 10, '........PQ23........', 24)
#  ->('q12', 11, '........PQ23........', 23)
#  ->('q12', 12, '........PQ23........', 22)
#  ->('q13', 13, '........PQ23........', 21)
# Rejected at  ('q4', 9, '........PY01', 39)
#  via ..
#  ->('q0', 0, '0101', 45)
#  ->('q14', 0, '0101', 44)
#  ->('q14', 1, '0101', 43)
#  ->('q2', 0, '0Y01', 42)
#  ->('q2', 7, '........0Y01', 41)
#  ->('q3', 8, '........0Y01', 40)
#  ->('q4', 9, '........PY01', 39)
# Rejected at  ('q6', 9, '........X101', 41)
#  via ..
#  ->('q0', 0, '0101', 45)
#  ->('q14', 0, '0101', 44)
#  ->('q2', 7, '........X101', 43)
#  ->('q3', 8, '........X101', 42)
#  ->('q6', 9, '........X101', 41)

# %%
explore_tm(wwndtm, "0100101001", 666)
# Out:
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the RIGHT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the RIGHT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the RIGHT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# Detailing the halted configs now.
# Rejected at  ('q14', 10, '0100101001', 655)
#  via ..
#  ->('q0', 0, '0100101001', 666)
#  ->('q14', 0, '0100101001', 665)
#  ->('q14', 1, '0100101001', 664)
#  ->('q14', 2, '0100101001', 663)
#  ->('q14', 3, '0100101001', 662)
#  ->('q14', 4, '0100101001', 661)
#  ->('q14', 5, '0100101001', 660)
#  ->('q14', 6, '0100101001', 659)
#  ->('q14', 7, '0100101001', 658)
#  ->('q14', 8, '0100101001', 657)
#  ->('q14', 9, '0100101001', 656)
#  ->('q14', 10, '0100101001', 655)
# Rejected at  ('q4', 17, '........P10010100Y', 636)
#  via ..
#  ->('q0', 0, '0100101001', 666)
#  ->('q14', 0, '0100101001', 665)
#  ->('q14', 1, '0100101001', 664)
#  ->('q14', 2, '0100101001', 663)
#  ->('q14', 3, '0100101001', 662)
#  ->('q14', 4, '0100101001', 661)
#  ->('q14', 5, '0100101001', 660)
#  ->('q14', 6, '0100101001', 659)
#  ->('q14', 7, '0100101001', 658)
#  ->('q14', 8, '0100101001', 657)
#  ->('q14', 9, '0100101001', 656)
#  ->('q2', 8, '010010100Y', 655)
#  ->('q2', 7, '010010100Y', 654)
#  ->('q2', 6, '010010100Y', 653)
#  ->('q2', 5, '010010100Y', 652)
#  ->('q2', 4, '010010100Y', 651)
#  ->('q2', 3, '010010100Y', 650)
#  ->('q2', 2, '010010100Y', 649)
#  ->('q2', 1, '010010100Y', 648)
#  ->('q2', 0, '010010100Y', 647)
#  ->('q2', 7, '........010010100Y', 646)
#  ->('q3', 8, '........010010100Y', 645)
#  ->('q4', 9, '........P10010100Y', 644)
#  ->('q4', 10, '........P10010100Y', 643)
#  ->('q4', 11, '........P10010100Y', 642)
#  ->('q4', 12, '........P10010100Y', 641)
#  ->('q4', 13, '........P10010100Y', 640)
#  ->('q4', 14, '........P10010100Y', 639)
#  ->('q4', 15, '........P10010100Y', 638)
#  ->('q4', 16, '........P10010100Y', 637)
#  ->('q4', 17, '........P10010100Y', 636)
# Rejected at  ('q4', 18, '........PQP0101023........', 601)
#  via ..
#  ->('q0', 0, '0100101001', 666)
#  ->('q14', 0, '0100101001', 665)
#  ->('q14', 1, '0100101001', 664)
#  ->('q14', 2, '0100101001', 663)
#  ->('q14', 3, '0100101001', 662)
#  ->('q14', 4, '0100101001', 661)
#  ->('q14', 5, '0100101001', 660)
#  ->('q14', 6, '0100101001', 659)
#  ->('q14', 7, '0100101001', 658)
#  ->('q14', 8, '0100101001', 657)
#  ->('q2', 7, '01001010X1', 656)
#  ->('q2', 6, '01001010X1', 655)
#  ->('q2', 5, '01001010X1', 654)
#  ->('q2', 4, '01001010X1', 653)
#  ->('q2', 3, '01001010X1', 652)
#  ->('q2', 2, '01001010X1', 651)
#  ->('q2', 1, '01001010X1', 650)
#  ->('q2', 0, '01001010X1', 649)
#  ->('q2', 7, '........01001010X1', 648)
#  ->('q3', 8, '........01001010X1', 647)
#  ->('q4', 9, '........P1001010X1', 646)
#  ->('q4', 10, '........P1001010X1', 645)
#  ->('q4', 11, '........P1001010X1', 644)
#  ->('q4', 12, '........P1001010X1', 643)
#  ->('q4', 13, '........P1001010X1', 642)
#  ->('q4', 14, '........P1001010X1', 641)
#  ->('q4', 15, '........P1001010X1', 640)
#  ->('q4', 16, '........P1001010X1', 639)
#  ->('q10', 17, '........P100101021', 638)
#  ->('q8', 16, '........P10010102Y', 637)
#  ->('q8', 15, '........P10010102Y', 636)
#  ->('q8', 14, '........P10010102Y', 635)
#  ->('q8', 13, '........P10010102Y', 634)
#  ->('q8', 12, '........P10010102Y', 633)
#  ->('q8', 11, '........P10010102Y', 632)
#  ->('q8', 10, '........P10010102Y', 631)
#  ->('q8', 9, '........P10010102Y', 630)
#  ->('q8', 8, '........P10010102Y', 629)
#  ->('q3', 9, '........P10010102Y', 628)
#  ->('q5', 10, '........PQ0010102Y', 627)
#  ->('q5', 11, '........PQ0010102Y', 626)
#  ->('q5', 12, '........PQ0010102Y', 625)
#  ->('q5', 13, '........PQ0010102Y', 624)
#  ->('q5', 14, '........PQ0010102Y', 623)
#  ->('q5', 15, '........PQ0010102Y', 622)
#  ->('q5', 16, '........PQ0010102Y', 621)
#  ->('q5', 17, '........PQ0010102Y', 620)
#  ->('q11', 18, '........PQ00101023', 619)
#  ->('q9', 17, '........PQ00101023........', 618)
#  ->('q9', 16, '........PQ00101023........', 617)
#  ->('q9', 15, '........PQ00101023........', 616)
#  ->('q9', 14, '........PQ00101023........', 615)
#  ->('q9', 13, '........PQ00101023........', 614)
#  ->('q9', 12, '........PQ00101023........', 613)
#  ->('q9', 11, '........PQ00101023........', 612)
#  ->('q9', 10, '........PQ00101023........', 611)
#  ->('q9', 9, '........PQ00101023........', 610)
#  ->('q3', 10, '........PQ00101023........', 609)
#  ->('q4', 11, '........PQP0101023........', 608)
#  ->('q4', 12, '........PQP0101023........', 607)
#  ->('q4', 13, '........PQP0101023........', 606)
#  ->('q4', 14, '........PQP0101023........', 605)
#  ->('q4', 15, '........PQP0101023........', 604)
#  ->('q4', 16, '........PQP0101023........', 603)
#  ->('q4', 17, '........PQP0101023........', 602)
#  ->('q4', 18, '........PQP0101023........', 601)
# Rejected at  ('q5', 16, '........PQ001012X1', 625)
#  via ..
#  ->('q0', 0, '0100101001', 666)
#  ->('q14', 0, '0100101001', 665)
#  ->('q14', 1, '0100101001', 664)
#  ->('q14', 2, '0100101001', 663)
#  ->('q14', 3, '0100101001', 662)
#  ->('q14', 4, '0100101001', 661)
#  ->('q14', 5, '0100101001', 660)
#  ->('q14', 6, '0100101001', 659)
#  ->('q14', 7, '0100101001', 658)
#  ->('q2', 6, '0100101X01', 657)
#  ->('q2', 5, '0100101X01', 656)
#  ->('q2', 4, '0100101X01', 655)
#  ->('q2', 3, '0100101X01', 654)
#  ->('q2', 2, '0100101X01', 653)
#  ->('q2', 1, '0100101X01', 652)
#  ->('q2', 0, '0100101X01', 651)
#  ->('q2', 7, '........0100101X01', 650)
#  ->('q3', 8, '........0100101X01', 649)
#  ->('q4', 9, '........P100101X01', 648)
#  ->('q4', 10, '........P100101X01', 647)
#  ->('q4', 11, '........P100101X01', 646)
#  ->('q4', 12, '........P100101X01', 645)
#  ->('q4', 13, '........P100101X01', 644)
#  ->('q4', 14, '........P100101X01', 643)
#  ->('q4', 15, '........P100101X01', 642)
#  ->('q10', 16, '........P100101201', 641)
#  ->('q8', 15, '........P1001012X1', 640)
#  ->('q8', 14, '........P1001012X1', 639)
#  ->('q8', 13, '........P1001012X1', 638)
#  ->('q8', 12, '........P1001012X1', 637)
#  ->('q8', 11, '........P1001012X1', 636)
#  ->('q8', 10, '........P1001012X1', 635)
#  ->('q8', 9, '........P1001012X1', 634)
#  ->('q8', 8, '........P1001012X1', 633)
#  ->('q3', 9, '........P1001012X1', 632)
#  ->('q5', 10, '........PQ001012X1', 631)
#  ->('q5', 11, '........PQ001012X1', 630)
#  ->('q5', 12, '........PQ001012X1', 629)
#  ->('q5', 13, '........PQ001012X1', 628)
#  ->('q5', 14, '........PQ001012X1', 627)
#  ->('q5', 15, '........PQ001012X1', 626)
#  ->('q5', 16, '........PQ001012X1', 625)
# Rejected at  ('q4', 14, '........P10010Y001', 645)
#  via ..
#  ->('q0', 0, '0100101001', 666)
#  ->('q14', 0, '0100101001', 665)
#  ->('q14', 1, '0100101001', 664)
#  ->('q14', 2, '0100101001', 663)
#  ->('q14', 3, '0100101001', 662)
#  ->('q14', 4, '0100101001', 661)
#  ->('q14', 5, '0100101001', 660)
#  ->('q14', 6, '0100101001', 659)
#  ->('q2', 5, '010010Y001', 658)
#  ->('q2', 4, '010010Y001', 657)
#  ->('q2', 3, '010010Y001', 656)
#  ->('q2', 2, '010010Y001', 655)
#  ->('q2', 1, '010010Y001', 654)
#  ->('q2', 0, '010010Y001', 653)
#  ->('q2', 7, '........010010Y001', 652)
#  ->('q3', 8, '........010010Y001', 651)
#  ->('q4', 9, '........P10010Y001', 650)
#  ->('q4', 10, '........P10010Y001', 649)
#  ->('q4', 11, '........P10010Y001', 648)
#  ->('q4', 12, '........P10010Y001', 647)
#  ->('q4', 13, '........P10010Y001', 646)
#  ->('q4', 14, '........P10010Y001', 645)
# Accepted at  ('q13', 19, '........PQPPQ23223........', 582)
#  via ..
#  ->('q0', 0, '0100101001', 666)
#  ->('q14', 0, '0100101001', 665)
#  ->('q14', 1, '0100101001', 664)
#  ->('q14', 2, '0100101001', 663)
#  ->('q14', 3, '0100101001', 662)
#  ->('q14', 4, '0100101001', 661)
#  ->('q14', 5, '0100101001', 660)
#  ->('q2', 4, '01001X1001', 659)
#  ->('q2', 3, '01001X1001', 658)
#  ->('q2', 2, '01001X1001', 657)
#  ->('q2', 1, '01001X1001', 656)
#  ->('q2', 0, '01001X1001', 655)
#  ->('q2', 7, '........01001X1001', 654)
#  ->('q3', 8, '........01001X1001', 653)
#  ->('q4', 9, '........P1001X1001', 652)
#  ->('q4', 10, '........P1001X1001', 651)
#  ->('q4', 11, '........P1001X1001', 650)
#  ->('q4', 12, '........P1001X1001', 649)
#  ->('q4', 13, '........P1001X1001', 648)
#  ->('q10', 14, '........P100121001', 647)
#  ->('q8', 13, '........P10012Y001', 646)
#  ->('q8', 12, '........P10012Y001', 645)
#  ->('q8', 11, '........P10012Y001', 644)
#  ->('q8', 10, '........P10012Y001', 643)
#  ->('q8', 9, '........P10012Y001', 642)
#  ->('q8', 8, '........P10012Y001', 641)
#  ->('q3', 9, '........P10012Y001', 640)
#  ->('q5', 10, '........PQ0012Y001', 639)
#  ->('q5', 11, '........PQ0012Y001', 638)
#  ->('q5', 12, '........PQ0012Y001', 637)
#  ->('q5', 13, '........PQ0012Y001', 636)
#  ->('q5', 14, '........PQ0012Y001', 635)
#  ->('q11', 15, '........PQ00123001', 634)
#  ->('q9', 14, '........PQ00123X01', 633)
#  ->('q9', 13, '........PQ00123X01', 632)
#  ->('q9', 12, '........PQ00123X01', 631)
#  ->('q9', 11, '........PQ00123X01', 630)
#  ->('q9', 10, '........PQ00123X01', 629)
#  ->('q9', 9, '........PQ00123X01', 628)
#  ->('q3', 10, '........PQ00123X01', 627)
#  ->('q4', 11, '........PQP0123X01', 626)
#  ->('q4', 12, '........PQP0123X01', 625)
#  ->('q4', 13, '........PQP0123X01', 624)
#  ->('q4', 14, '........PQP0123X01', 623)
#  ->('q4', 15, '........PQP0123X01', 622)
#  ->('q10', 16, '........PQP0123201', 621)
#  ->('q8', 15, '........PQP01232X1', 620)
#  ->('q8', 14, '........PQP01232X1', 619)
#  ->('q8', 13, '........PQP01232X1', 618)
#  ->('q8', 12, '........PQP01232X1', 617)
#  ->('q8', 11, '........PQP01232X1', 616)
#  ->('q8', 10, '........PQP01232X1', 615)
#  ->('q3', 11, '........PQP01232X1', 614)
#  ->('q4', 12, '........PQPP1232X1', 613)
#  ->('q4', 13, '........PQPP1232X1', 612)
#  ->('q4', 14, '........PQPP1232X1', 611)
#  ->('q4', 15, '........PQPP1232X1', 610)
#  ->('q4', 16, '........PQPP1232X1', 609)
#  ->('q10', 17, '........PQPP123221', 608)
#  ->('q8', 16, '........PQPP12322Y', 607)
#  ->('q8', 15, '........PQPP12322Y', 606)
#  ->('q8', 14, '........PQPP12322Y', 605)
#  ->('q8', 13, '........PQPP12322Y', 604)
#  ->('q8', 12, '........PQPP12322Y', 603)
#  ->('q8', 11, '........PQPP12322Y', 602)
#  ->('q3', 12, '........PQPP12322Y', 601)
#  ->('q5', 13, '........PQPPQ2322Y', 600)
#  ->('q5', 14, '........PQPPQ2322Y', 599)
#  ->('q5', 15, '........PQPPQ2322Y', 598)
#  ->('q5', 16, '........PQPPQ2322Y', 597)
#  ->('q5', 17, '........PQPPQ2322Y', 596)
#  ->('q11', 18, '........PQPPQ23223', 595)
#  ->('q9', 17, '........PQPPQ23223........', 594)
#  ->('q9', 16, '........PQPPQ23223........', 593)
#  ->('q9', 15, '........PQPPQ23223........', 592)
#  ->('q9', 14, '........PQPPQ23223........', 591)
#  ->('q9', 13, '........PQPPQ23223........', 590)
#  ->('q9', 12, '........PQPPQ23223........', 589)
#  ->('q3', 13, '........PQPPQ23223........', 588)
#  ->('q12', 14, '........PQPPQ23223........', 587)
#  ->('q12', 15, '........PQPPQ23223........', 586)
#  ->('q12', 16, '........PQPPQ23223........', 585)
#  ->('q12', 17, '........PQPPQ23223........', 584)
#  ->('q12', 18, '........PQPPQ23223........', 583)
#  ->('q13', 19, '........PQPPQ23223........', 582)
# Rejected at  ('q4', 12, '........P100Y01001', 651)
#  via ..
#  ->('q0', 0, '0100101001', 666)
#  ->('q14', 0, '0100101001', 665)
#  ->('q14', 1, '0100101001', 664)
#  ->('q14', 2, '0100101001', 663)
#  ->('q14', 3, '0100101001', 662)
#  ->('q14', 4, '0100101001', 661)
#  ->('q2', 3, '0100Y01001', 660)
#  ->('q2', 2, '0100Y01001', 659)
#  ->('q2', 1, '0100Y01001', 658)
#  ->('q2', 0, '0100Y01001', 657)
#  ->('q2', 7, '........0100Y01001', 656)
#  ->('q3', 8, '........0100Y01001', 655)
#  ->('q4', 9, '........P100Y01001', 654)
#  ->('q4', 10, '........P100Y01001', 653)
#  ->('q4', 11, '........P100Y01001', 652)
#  ->('q4', 12, '........P100Y01001', 651)
# Rejected at  ('q12', 14, '........PQP232Y001', 627)
#  via ..
#  ->('q0', 0, '0100101001', 666)
#  ->('q14', 0, '0100101001', 665)
#  ->('q14', 1, '0100101001', 664)
#  ->('q14', 2, '0100101001', 663)
#  ->('q14', 3, '0100101001', 662)
#  ->('q2', 2, '010X101001', 661)
#  ->('q2', 1, '010X101001', 660)
#  ->('q2', 0, '010X101001', 659)
#  ->('q2', 7, '........010X101001', 658)
#  ->('q3', 8, '........010X101001', 657)
#  ->('q4', 9, '........P10X101001', 656)
#  ->('q4', 10, '........P10X101001', 655)
#  ->('q4', 11, '........P10X101001', 654)
#  ->('q10', 12, '........P102101001', 653)
#  ->('q8', 11, '........P102Y01001', 652)
#  ->('q8', 10, '........P102Y01001', 651)
#  ->('q8', 9, '........P102Y01001', 650)
#  ->('q8', 8, '........P102Y01001', 649)
#  ->('q3', 9, '........P102Y01001', 648)
#  ->('q5', 10, '........PQ02Y01001', 647)
#  ->('q5', 11, '........PQ02Y01001', 646)
#  ->('q5', 12, '........PQ02Y01001', 645)
#  ->('q11', 13, '........PQ02301001', 644)
#  ->('q9', 12, '........PQ023X1001', 643)
#  ->('q9', 11, '........PQ023X1001', 642)
#  ->('q9', 10, '........PQ023X1001', 641)
#  ->('q9', 9, '........PQ023X1001', 640)
#  ->('q3', 10, '........PQ023X1001', 639)
#  ->('q4', 11, '........PQP23X1001', 638)
#  ->('q4', 12, '........PQP23X1001', 637)
#  ->('q4', 13, '........PQP23X1001', 636)
#  ->('q10', 14, '........PQP2321001', 635)
#  ->('q8', 13, '........PQP232Y001', 634)
#  ->('q8', 12, '........PQP232Y001', 633)
#  ->('q8', 11, '........PQP232Y001', 632)
#  ->('q8', 10, '........PQP232Y001', 631)
#  ->('q3', 11, '........PQP232Y001', 630)
#  ->('q12', 12, '........PQP232Y001', 629)
#  ->('q12', 13, '........PQP232Y001', 628)
#  ->('q12', 14, '........PQP232Y001', 627)
# Rejected at  ('q5', 11, '........PQ2X101001', 650)
#  via ..
#  ->('q0', 0, '0100101001', 666)
#  ->('q14', 0, '0100101001', 665)
#  ->('q14', 1, '0100101001', 664)
#  ->('q14', 2, '0100101001', 663)
#  ->('q2', 1, '01X0101001', 662)
#  ->('q2', 0, '01X0101001', 661)
#  ->('q2', 7, '........01X0101001', 660)
#  ->('q3', 8, '........01X0101001', 659)
#  ->('q4', 9, '........P1X0101001', 658)
#  ->('q4', 10, '........P1X0101001', 657)
#  ->('q10', 11, '........P120101001', 656)
#  ->('q8', 10, '........P12X101001', 655)
#  ->('q8', 9, '........P12X101001', 654)
#  ->('q8', 8, '........P12X101001', 653)
#  ->('q3', 9, '........P12X101001', 652)
#  ->('q5', 10, '........PQ2X101001', 651)
#  ->('q5', 11, '........PQ2X101001', 650)
# Rejected at  ('q4', 9, '........PY00101001', 660)
#  via ..
#  ->('q0', 0, '0100101001', 666)
#  ->('q14', 0, '0100101001', 665)
#  ->('q14', 1, '0100101001', 664)
#  ->('q2', 0, '0Y00101001', 663)
#  ->('q2', 7, '........0Y00101001', 662)
#  ->('q3', 8, '........0Y00101001', 661)
#  ->('q4', 9, '........PY00101001', 660)
# Rejected at  ('q6', 9, '........X100101001', 662)
#  via ..
#  ->('q0', 0, '0100101001', 666)
#  ->('q14', 0, '0100101001', 665)
#  ->('q2', 7, '........X100101001', 664)
#  ->('q3', 8, '........X100101001', 663)
#  ->('q6', 9, '........X100101001', 662)

# %%
explore_tm(wwndtm, "0100101001", 666)
# Out:
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the RIGHT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the RIGHT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the RIGHT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# Detailing the halted configs now.
# Rejected at  ('q14', 10, '0100101001', 655)
#  via ..
#  ->('q0', 0, '0100101001', 666)
#  ->('q14', 0, '0100101001', 665)
#  ->('q14', 1, '0100101001', 664)
#  ->('q14', 2, '0100101001', 663)
#  ->('q14', 3, '0100101001', 662)
#  ->('q14', 4, '0100101001', 661)
#  ->('q14', 5, '0100101001', 660)
#  ->('q14', 6, '0100101001', 659)
#  ->('q14', 7, '0100101001', 658)
#  ->('q14', 8, '0100101001', 657)
#  ->('q14', 9, '0100101001', 656)
#  ->('q14', 10, '0100101001', 655)
# Rejected at  ('q4', 17, '........P10010100Y', 636)
#  via ..
#  ->('q0', 0, '0100101001', 666)
#  ->('q14', 0, '0100101001', 665)
#  ->('q14', 1, '0100101001', 664)
#  ->('q14', 2, '0100101001', 663)
#  ->('q14', 3, '0100101001', 662)
#  ->('q14', 4, '0100101001', 661)
#  ->('q14', 5, '0100101001', 660)
#  ->('q14', 6, '0100101001', 659)
#  ->('q14', 7, '0100101001', 658)
#  ->('q14', 8, '0100101001', 657)
#  ->('q14', 9, '0100101001', 656)
#  ->('q2', 8, '010010100Y', 655)
#  ->('q2', 7, '010010100Y', 654)
#  ->('q2', 6, '010010100Y', 653)
#  ->('q2', 5, '010010100Y', 652)
#  ->('q2', 4, '010010100Y', 651)
#  ->('q2', 3, '010010100Y', 650)
#  ->('q2', 2, '010010100Y', 649)
#  ->('q2', 1, '010010100Y', 648)
#  ->('q2', 0, '010010100Y', 647)
#  ->('q2', 7, '........010010100Y', 646)
#  ->('q3', 8, '........010010100Y', 645)
#  ->('q4', 9, '........P10010100Y', 644)
#  ->('q4', 10, '........P10010100Y', 643)
#  ->('q4', 11, '........P10010100Y', 642)
#  ->('q4', 12, '........P10010100Y', 641)
#  ->('q4', 13, '........P10010100Y', 640)
#  ->('q4', 14, '........P10010100Y', 639)
#  ->('q4', 15, '........P10010100Y', 638)
#  ->('q4', 16, '........P10010100Y', 637)
#  ->('q4', 17, '........P10010100Y', 636)
# Rejected at  ('q4', 18, '........PQP0101023........', 601)
#  via ..
#  ->('q0', 0, '0100101001', 666)
#  ->('q14', 0, '0100101001', 665)
#  ->('q14', 1, '0100101001', 664)
#  ->('q14', 2, '0100101001', 663)
#  ->('q14', 3, '0100101001', 662)
#  ->('q14', 4, '0100101001', 661)
#  ->('q14', 5, '0100101001', 660)
#  ->('q14', 6, '0100101001', 659)
#  ->('q14', 7, '0100101001', 658)
#  ->('q14', 8, '0100101001', 657)
#  ->('q2', 7, '01001010X1', 656)
#  ->('q2', 6, '01001010X1', 655)
#  ->('q2', 5, '01001010X1', 654)
#  ->('q2', 4, '01001010X1', 653)
#  ->('q2', 3, '01001010X1', 652)
#  ->('q2', 2, '01001010X1', 651)
#  ->('q2', 1, '01001010X1', 650)
#  ->('q2', 0, '01001010X1', 649)
#  ->('q2', 7, '........01001010X1', 648)
#  ->('q3', 8, '........01001010X1', 647)
#  ->('q4', 9, '........P1001010X1', 646)
#  ->('q4', 10, '........P1001010X1', 645)
#  ->('q4', 11, '........P1001010X1', 644)
#  ->('q4', 12, '........P1001010X1', 643)
#  ->('q4', 13, '........P1001010X1', 642)
#  ->('q4', 14, '........P1001010X1', 641)
#  ->('q4', 15, '........P1001010X1', 640)
#  ->('q4', 16, '........P1001010X1', 639)
#  ->('q10', 17, '........P100101021', 638)
#  ->('q8', 16, '........P10010102Y', 637)
#  ->('q8', 15, '........P10010102Y', 636)
#  ->('q8', 14, '........P10010102Y', 635)
#  ->('q8', 13, '........P10010102Y', 634)
#  ->('q8', 12, '........P10010102Y', 633)
#  ->('q8', 11, '........P10010102Y', 632)
#  ->('q8', 10, '........P10010102Y', 631)
#  ->('q8', 9, '........P10010102Y', 630)
#  ->('q8', 8, '........P10010102Y', 629)
#  ->('q3', 9, '........P10010102Y', 628)
#  ->('q5', 10, '........PQ0010102Y', 627)
#  ->('q5', 11, '........PQ0010102Y', 626)
#  ->('q5', 12, '........PQ0010102Y', 625)
#  ->('q5', 13, '........PQ0010102Y', 624)
#  ->('q5', 14, '........PQ0010102Y', 623)
#  ->('q5', 15, '........PQ0010102Y', 622)
#  ->('q5', 16, '........PQ0010102Y', 621)
#  ->('q5', 17, '........PQ0010102Y', 620)
#  ->('q11', 18, '........PQ00101023', 619)
#  ->('q9', 17, '........PQ00101023........', 618)
#  ->('q9', 16, '........PQ00101023........', 617)
#  ->('q9', 15, '........PQ00101023........', 616)
#  ->('q9', 14, '........PQ00101023........', 615)
#  ->('q9', 13, '........PQ00101023........', 614)
#  ->('q9', 12, '........PQ00101023........', 613)
#  ->('q9', 11, '........PQ00101023........', 612)
#  ->('q9', 10, '........PQ00101023........', 611)
#  ->('q9', 9, '........PQ00101023........', 610)
#  ->('q3', 10, '........PQ00101023........', 609)
#  ->('q4', 11, '........PQP0101023........', 608)
#  ->('q4', 12, '........PQP0101023........', 607)
#  ->('q4', 13, '........PQP0101023........', 606)
#  ->('q4', 14, '........PQP0101023........', 605)
#  ->('q4', 15, '........PQP0101023........', 604)
#  ->('q4', 16, '........PQP0101023........', 603)
#  ->('q4', 17, '........PQP0101023........', 602)
#  ->('q4', 18, '........PQP0101023........', 601)
# Rejected at  ('q5', 16, '........PQ001012X1', 625)
#  via ..
#  ->('q0', 0, '0100101001', 666)
#  ->('q14', 0, '0100101001', 665)
#  ->('q14', 1, '0100101001', 664)
#  ->('q14', 2, '0100101001', 663)
#  ->('q14', 3, '0100101001', 662)
#  ->('q14', 4, '0100101001', 661)
#  ->('q14', 5, '0100101001', 660)
#  ->('q14', 6, '0100101001', 659)
#  ->('q14', 7, '0100101001', 658)
#  ->('q2', 6, '0100101X01', 657)
#  ->('q2', 5, '0100101X01', 656)
#  ->('q2', 4, '0100101X01', 655)
#  ->('q2', 3, '0100101X01', 654)
#  ->('q2', 2, '0100101X01', 653)
#  ->('q2', 1, '0100101X01', 652)
#  ->('q2', 0, '0100101X01', 651)
#  ->('q2', 7, '........0100101X01', 650)
#  ->('q3', 8, '........0100101X01', 649)
#  ->('q4', 9, '........P100101X01', 648)
#  ->('q4', 10, '........P100101X01', 647)
#  ->('q4', 11, '........P100101X01', 646)
#  ->('q4', 12, '........P100101X01', 645)
#  ->('q4', 13, '........P100101X01', 644)
#  ->('q4', 14, '........P100101X01', 643)
#  ->('q4', 15, '........P100101X01', 642)
#  ->('q10', 16, '........P100101201', 641)
#  ->('q8', 15, '........P1001012X1', 640)
#  ->('q8', 14, '........P1001012X1', 639)
#  ->('q8', 13, '........P1001012X1', 638)
#  ->('q8', 12, '........P1001012X1', 637)
#  ->('q8', 11, '........P1001012X1', 636)
#  ->('q8', 10, '........P1001012X1', 635)
#  ->('q8', 9, '........P1001012X1', 634)
#  ->('q8', 8, '........P1001012X1', 633)
#  ->('q3', 9, '........P1001012X1', 632)
#  ->('q5', 10, '........PQ001012X1', 631)
#  ->('q5', 11, '........PQ001012X1', 630)
#  ->('q5', 12, '........PQ001012X1', 629)
#  ->('q5', 13, '........PQ001012X1', 628)
#  ->('q5', 14, '........PQ001012X1', 627)
#  ->('q5', 15, '........PQ001012X1', 626)
#  ->('q5', 16, '........PQ001012X1', 625)
# Rejected at  ('q4', 14, '........P10010Y001', 645)
#  via ..
#  ->('q0', 0, '0100101001', 666)
#  ->('q14', 0, '0100101001', 665)
#  ->('q14', 1, '0100101001', 664)
#  ->('q14', 2, '0100101001', 663)
#  ->('q14', 3, '0100101001', 662)
#  ->('q14', 4, '0100101001', 661)
#  ->('q14', 5, '0100101001', 660)
#  ->('q14', 6, '0100101001', 659)
#  ->('q2', 5, '010010Y001', 658)
#  ->('q2', 4, '010010Y001', 657)
#  ->('q2', 3, '010010Y001', 656)
#  ->('q2', 2, '010010Y001', 655)
#  ->('q2', 1, '010010Y001', 654)
#  ->('q2', 0, '010010Y001', 653)
#  ->('q2', 7, '........010010Y001', 652)
#  ->('q3', 8, '........010010Y001', 651)
#  ->('q4', 9, '........P10010Y001', 650)
#  ->('q4', 10, '........P10010Y001', 649)
#  ->('q4', 11, '........P10010Y001', 648)
#  ->('q4', 12, '........P10010Y001', 647)
#  ->('q4', 13, '........P10010Y001', 646)
#  ->('q4', 14, '........P10010Y001', 645)
# Accepted at  ('q13', 19, '........PQPPQ23223........', 582)
#  via ..
#  ->('q0', 0, '0100101001', 666)
#  ->('q14', 0, '0100101001', 665)
#  ->('q14', 1, '0100101001', 664)
#  ->('q14', 2, '0100101001', 663)
#  ->('q14', 3, '0100101001', 662)
#  ->('q14', 4, '0100101001', 661)
#  ->('q14', 5, '0100101001', 660)
#  ->('q2', 4, '01001X1001', 659)
#  ->('q2', 3, '01001X1001', 658)
#  ->('q2', 2, '01001X1001', 657)
#  ->('q2', 1, '01001X1001', 656)
#  ->('q2', 0, '01001X1001', 655)
#  ->('q2', 7, '........01001X1001', 654)
#  ->('q3', 8, '........01001X1001', 653)
#  ->('q4', 9, '........P1001X1001', 652)
#  ->('q4', 10, '........P1001X1001', 651)
#  ->('q4', 11, '........P1001X1001', 650)
#  ->('q4', 12, '........P1001X1001', 649)
#  ->('q4', 13, '........P1001X1001', 648)
#  ->('q10', 14, '........P100121001', 647)
#  ->('q8', 13, '........P10012Y001', 646)
#  ->('q8', 12, '........P10012Y001', 645)
#  ->('q8', 11, '........P10012Y001', 644)
#  ->('q8', 10, '........P10012Y001', 643)
#  ->('q8', 9, '........P10012Y001', 642)
#  ->('q8', 8, '........P10012Y001', 641)
#  ->('q3', 9, '........P10012Y001', 640)
#  ->('q5', 10, '........PQ0012Y001', 639)
#  ->('q5', 11, '........PQ0012Y001', 638)
#  ->('q5', 12, '........PQ0012Y001', 637)
#  ->('q5', 13, '........PQ0012Y001', 636)
#  ->('q5', 14, '........PQ0012Y001', 635)
#  ->('q11', 15, '........PQ00123001', 634)
#  ->('q9', 14, '........PQ00123X01', 633)
#  ->('q9', 13, '........PQ00123X01', 632)
#  ->('q9', 12, '........PQ00123X01', 631)
#  ->('q9', 11, '........PQ00123X01', 630)
#  ->('q9', 10, '........PQ00123X01', 629)
#  ->('q9', 9, '........PQ00123X01', 628)
#  ->('q3', 10, '........PQ00123X01', 627)
#  ->('q4', 11, '........PQP0123X01', 626)
#  ->('q4', 12, '........PQP0123X01', 625)
#  ->('q4', 13, '........PQP0123X01', 624)
#  ->('q4', 14, '........PQP0123X01', 623)
#  ->('q4', 15, '........PQP0123X01', 622)
#  ->('q10', 16, '........PQP0123201', 621)
#  ->('q8', 15, '........PQP01232X1', 620)
#  ->('q8', 14, '........PQP01232X1', 619)
#  ->('q8', 13, '........PQP01232X1', 618)
#  ->('q8', 12, '........PQP01232X1', 617)
#  ->('q8', 11, '........PQP01232X1', 616)
#  ->('q8', 10, '........PQP01232X1', 615)
#  ->('q3', 11, '........PQP01232X1', 614)
#  ->('q4', 12, '........PQPP1232X1', 613)
#  ->('q4', 13, '........PQPP1232X1', 612)
#  ->('q4', 14, '........PQPP1232X1', 611)
#  ->('q4', 15, '........PQPP1232X1', 610)
#  ->('q4', 16, '........PQPP1232X1', 609)
#  ->('q10', 17, '........PQPP123221', 608)
#  ->('q8', 16, '........PQPP12322Y', 607)
#  ->('q8', 15, '........PQPP12322Y', 606)
#  ->('q8', 14, '........PQPP12322Y', 605)
#  ->('q8', 13, '........PQPP12322Y', 604)
#  ->('q8', 12, '........PQPP12322Y', 603)
#  ->('q8', 11, '........PQPP12322Y', 602)
#  ->('q3', 12, '........PQPP12322Y', 601)
#  ->('q5', 13, '........PQPPQ2322Y', 600)
#  ->('q5', 14, '........PQPPQ2322Y', 599)
#  ->('q5', 15, '........PQPPQ2322Y', 598)
#  ->('q5', 16, '........PQPPQ2322Y', 597)
#  ->('q5', 17, '........PQPPQ2322Y', 596)
#  ->('q11', 18, '........PQPPQ23223', 595)
#  ->('q9', 17, '........PQPPQ23223........', 594)
#  ->('q9', 16, '........PQPPQ23223........', 593)
#  ->('q9', 15, '........PQPPQ23223........', 592)
#  ->('q9', 14, '........PQPPQ23223........', 591)
#  ->('q9', 13, '........PQPPQ23223........', 590)
#  ->('q9', 12, '........PQPPQ23223........', 589)
#  ->('q3', 13, '........PQPPQ23223........', 588)
#  ->('q12', 14, '........PQPPQ23223........', 587)
#  ->('q12', 15, '........PQPPQ23223........', 586)
#  ->('q12', 16, '........PQPPQ23223........', 585)
#  ->('q12', 17, '........PQPPQ23223........', 584)
#  ->('q12', 18, '........PQPPQ23223........', 583)
#  ->('q13', 19, '........PQPPQ23223........', 582)
# Rejected at  ('q4', 12, '........P100Y01001', 651)
#  via ..
#  ->('q0', 0, '0100101001', 666)
#  ->('q14', 0, '0100101001', 665)
#  ->('q14', 1, '0100101001', 664)
#  ->('q14', 2, '0100101001', 663)
#  ->('q14', 3, '0100101001', 662)
#  ->('q14', 4, '0100101001', 661)
#  ->('q2', 3, '0100Y01001', 660)
#  ->('q2', 2, '0100Y01001', 659)
#  ->('q2', 1, '0100Y01001', 658)
#  ->('q2', 0, '0100Y01001', 657)
#  ->('q2', 7, '........0100Y01001', 656)
#  ->('q3', 8, '........0100Y01001', 655)
#  ->('q4', 9, '........P100Y01001', 654)
#  ->('q4', 10, '........P100Y01001', 653)
#  ->('q4', 11, '........P100Y01001', 652)
#  ->('q4', 12, '........P100Y01001', 651)
# Rejected at  ('q12', 14, '........PQP232Y001', 627)
#  via ..
#  ->('q0', 0, '0100101001', 666)
#  ->('q14', 0, '0100101001', 665)
#  ->('q14', 1, '0100101001', 664)
#  ->('q14', 2, '0100101001', 663)
#  ->('q14', 3, '0100101001', 662)
#  ->('q2', 2, '010X101001', 661)
#  ->('q2', 1, '010X101001', 660)
#  ->('q2', 0, '010X101001', 659)
#  ->('q2', 7, '........010X101001', 658)
#  ->('q3', 8, '........010X101001', 657)
#  ->('q4', 9, '........P10X101001', 656)
#  ->('q4', 10, '........P10X101001', 655)
#  ->('q4', 11, '........P10X101001', 654)
#  ->('q10', 12, '........P102101001', 653)
#  ->('q8', 11, '........P102Y01001', 652)
#  ->('q8', 10, '........P102Y01001', 651)
#  ->('q8', 9, '........P102Y01001', 650)
#  ->('q8', 8, '........P102Y01001', 649)
#  ->('q3', 9, '........P102Y01001', 648)
#  ->('q5', 10, '........PQ02Y01001', 647)
#  ->('q5', 11, '........PQ02Y01001', 646)
#  ->('q5', 12, '........PQ02Y01001', 645)
#  ->('q11', 13, '........PQ02301001', 644)
#  ->('q9', 12, '........PQ023X1001', 643)
#  ->('q9', 11, '........PQ023X1001', 642)
#  ->('q9', 10, '........PQ023X1001', 641)
#  ->('q9', 9, '........PQ023X1001', 640)
#  ->('q3', 10, '........PQ023X1001', 639)
#  ->('q4', 11, '........PQP23X1001', 638)
#  ->('q4', 12, '........PQP23X1001', 637)
#  ->('q4', 13, '........PQP23X1001', 636)
#  ->('q10', 14, '........PQP2321001', 635)
#  ->('q8', 13, '........PQP232Y001', 634)
#  ->('q8', 12, '........PQP232Y001', 633)
#  ->('q8', 11, '........PQP232Y001', 632)
#  ->('q8', 10, '........PQP232Y001', 631)
#  ->('q3', 11, '........PQP232Y001', 630)
#  ->('q12', 12, '........PQP232Y001', 629)
#  ->('q12', 13, '........PQP232Y001', 628)
#  ->('q12', 14, '........PQP232Y001', 627)
# Rejected at  ('q5', 11, '........PQ2X101001', 650)
#  via ..
#  ->('q0', 0, '0100101001', 666)
#  ->('q14', 0, '0100101001', 665)
#  ->('q14', 1, '0100101001', 664)
#  ->('q14', 2, '0100101001', 663)
#  ->('q2', 1, '01X0101001', 662)
#  ->('q2', 0, '01X0101001', 661)
#  ->('q2', 7, '........01X0101001', 660)
#  ->('q3', 8, '........01X0101001', 659)
#  ->('q4', 9, '........P1X0101001', 658)
#  ->('q4', 10, '........P1X0101001', 657)
#  ->('q10', 11, '........P120101001', 656)
#  ->('q8', 10, '........P12X101001', 655)
#  ->('q8', 9, '........P12X101001', 654)
#  ->('q8', 8, '........P12X101001', 653)
#  ->('q3', 9, '........P12X101001', 652)
#  ->('q5', 10, '........PQ2X101001', 651)
#  ->('q5', 11, '........PQ2X101001', 650)
# Rejected at  ('q4', 9, '........PY00101001', 660)
#  via ..
#  ->('q0', 0, '0100101001', 666)
#  ->('q14', 0, '0100101001', 665)
#  ->('q14', 1, '0100101001', 664)
#  ->('q2', 0, '0Y00101001', 663)
#  ->('q2', 7, '........0Y00101001', 662)
#  ->('q3', 8, '........0Y00101001', 661)
#  ->('q4', 9, '........PY00101001', 660)
# Rejected at  ('q6', 9, '........X100101001', 662)
#  via ..
#  ->('q0', 0, '0100101001', 666)
#  ->('q14', 0, '0100101001', 665)
#  ->('q2', 7, '........X100101001', 664)
#  ->('q3', 8, '........X100101001', 663)
#  ->('q6', 9, '........X100101001', 662)

# %%
explore_tm(wwndtm, "0100101001", 66)
# Out:
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the RIGHT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the RIGHT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# Allocating  8  tape cells to the LEFT!
# There are still  1 truncated paths.
# Detailing the halted configs now.
# Rejected at  ('q14', 10, '0100101001', 55)
#  via ..
#  ->('q0', 0, '0100101001', 66)
#  ->('q14', 0, '0100101001', 65)
#  ->('q14', 1, '0100101001', 64)
#  ->('q14', 2, '0100101001', 63)
#  ->('q14', 3, '0100101001', 62)
#  ->('q14', 4, '0100101001', 61)
#  ->('q14', 5, '0100101001', 60)
#  ->('q14', 6, '0100101001', 59)
#  ->('q14', 7, '0100101001', 58)
#  ->('q14', 8, '0100101001', 57)
#  ->('q14', 9, '0100101001', 56)
#  ->('q14', 10, '0100101001', 55)
# Rejected at  ('q4', 17, '........P10010100Y', 36)
#  via ..
#  ->('q0', 0, '0100101001', 66)
#  ->('q14', 0, '0100101001', 65)
#  ->('q14', 1, '0100101001', 64)
#  ->('q14', 2, '0100101001', 63)
#  ->('q14', 3, '0100101001', 62)
#  ->('q14', 4, '0100101001', 61)
#  ->('q14', 5, '0100101001', 60)
#  ->('q14', 6, '0100101001', 59)
#  ->('q14', 7, '0100101001', 58)
#  ->('q14', 8, '0100101001', 57)
#  ->('q14', 9, '0100101001', 56)
#  ->('q2', 8, '010010100Y', 55)
#  ->('q2', 7, '010010100Y', 54)
#  ->('q2', 6, '010010100Y', 53)
#  ->('q2', 5, '010010100Y', 52)
#  ->('q2', 4, '010010100Y', 51)
#  ->('q2', 3, '010010100Y', 50)
#  ->('q2', 2, '010010100Y', 49)
#  ->('q2', 1, '010010100Y', 48)
#  ->('q2', 0, '010010100Y', 47)
#  ->('q2', 7, '........010010100Y', 46)
#  ->('q3', 8, '........010010100Y', 45)
#  ->('q4', 9, '........P10010100Y', 44)
#  ->('q4', 10, '........P10010100Y', 43)
#  ->('q4', 11, '........P10010100Y', 42)
#  ->('q4', 12, '........P10010100Y', 41)
#  ->('q4', 13, '........P10010100Y', 40)
#  ->('q4', 14, '........P10010100Y', 39)
#  ->('q4', 15, '........P10010100Y', 38)
#  ->('q4', 16, '........P10010100Y', 37)
#  ->('q4', 17, '........P10010100Y', 36)
# Rejected at  ('q4', 18, '........PQP0101023........', 1)
#  via ..
#  ->('q0', 0, '0100101001', 66)
#  ->('q14', 0, '0100101001', 65)
#  ->('q14', 1, '0100101001', 64)
#  ->('q14', 2, '0100101001', 63)
#  ->('q14', 3, '0100101001', 62)
#  ->('q14', 4, '0100101001', 61)
#  ->('q14', 5, '0100101001', 60)
#  ->('q14', 6, '0100101001', 59)
#  ->('q14', 7, '0100101001', 58)
#  ->('q14', 8, '0100101001', 57)
#  ->('q2', 7, '01001010X1', 56)
#  ->('q2', 6, '01001010X1', 55)
#  ->('q2', 5, '01001010X1', 54)
#  ->('q2', 4, '01001010X1', 53)
#  ->('q2', 3, '01001010X1', 52)
#  ->('q2', 2, '01001010X1', 51)
#  ->('q2', 1, '01001010X1', 50)
#  ->('q2', 0, '01001010X1', 49)
#  ->('q2', 7, '........01001010X1', 48)
#  ->('q3', 8, '........01001010X1', 47)
#  ->('q4', 9, '........P1001010X1', 46)
#  ->('q4', 10, '........P1001010X1', 45)
#  ->('q4', 11, '........P1001010X1', 44)
#  ->('q4', 12, '........P1001010X1', 43)
#  ->('q4', 13, '........P1001010X1', 42)
#  ->('q4', 14, '........P1001010X1', 41)
#  ->('q4', 15, '........P1001010X1', 40)
#  ->('q4', 16, '........P1001010X1', 39)
#  ->('q10', 17, '........P100101021', 38)
#  ->('q8', 16, '........P10010102Y', 37)
#  ->('q8', 15, '........P10010102Y', 36)
#  ->('q8', 14, '........P10010102Y', 35)
#  ->('q8', 13, '........P10010102Y', 34)
#  ->('q8', 12, '........P10010102Y', 33)
#  ->('q8', 11, '........P10010102Y', 32)
#  ->('q8', 10, '........P10010102Y', 31)
#  ->('q8', 9, '........P10010102Y', 30)
#  ->('q8', 8, '........P10010102Y', 29)
#  ->('q3', 9, '........P10010102Y', 28)
#  ->('q5', 10, '........PQ0010102Y', 27)
#  ->('q5', 11, '........PQ0010102Y', 26)
#  ->('q5', 12, '........PQ0010102Y', 25)
#  ->('q5', 13, '........PQ0010102Y', 24)
#  ->('q5', 14, '........PQ0010102Y', 23)
#  ->('q5', 15, '........PQ0010102Y', 22)
#  ->('q5', 16, '........PQ0010102Y', 21)
#  ->('q5', 17, '........PQ0010102Y', 20)
#  ->('q11', 18, '........PQ00101023', 19)
#  ->('q9', 17, '........PQ00101023........', 18)
#  ->('q9', 16, '........PQ00101023........', 17)
#  ->('q9', 15, '........PQ00101023........', 16)
#  ->('q9', 14, '........PQ00101023........', 15)
#  ->('q9', 13, '........PQ00101023........', 14)
#  ->('q9', 12, '........PQ00101023........', 13)
#  ->('q9', 11, '........PQ00101023........', 12)
#  ->('q9', 10, '........PQ00101023........', 11)
#  ->('q9', 9, '........PQ00101023........', 10)
#  ->('q3', 10, '........PQ00101023........', 9)
#  ->('q4', 11, '........PQP0101023........', 8)
#  ->('q4', 12, '........PQP0101023........', 7)
#  ->('q4', 13, '........PQP0101023........', 6)
#  ->('q4', 14, '........PQP0101023........', 5)
#  ->('q4', 15, '........PQP0101023........', 4)
#  ->('q4', 16, '........PQP0101023........', 3)
#  ->('q4', 17, '........PQP0101023........', 2)
#  ->('q4', 18, '........PQP0101023........', 1)
# Rejected at  ('q5', 16, '........PQ001012X1', 25)
#  via ..
#  ->('q0', 0, '0100101001', 66)
#  ->('q14', 0, '0100101001', 65)
#  ->('q14', 1, '0100101001', 64)
#  ->('q14', 2, '0100101001', 63)
#  ->('q14', 3, '0100101001', 62)
#  ->('q14', 4, '0100101001', 61)
#  ->('q14', 5, '0100101001', 60)
#  ->('q14', 6, '0100101001', 59)
#  ->('q14', 7, '0100101001', 58)
#  ->('q2', 6, '0100101X01', 57)
#  ->('q2', 5, '0100101X01', 56)
#  ->('q2', 4, '0100101X01', 55)
#  ->('q2', 3, '0100101X01', 54)
#  ->('q2', 2, '0100101X01', 53)
#  ->('q2', 1, '0100101X01', 52)
#  ->('q2', 0, '0100101X01', 51)
#  ->('q2', 7, '........0100101X01', 50)
#  ->('q3', 8, '........0100101X01', 49)
#  ->('q4', 9, '........P100101X01', 48)
#  ->('q4', 10, '........P100101X01', 47)
#  ->('q4', 11, '........P100101X01', 46)
#  ->('q4', 12, '........P100101X01', 45)
#  ->('q4', 13, '........P100101X01', 44)
#  ->('q4', 14, '........P100101X01', 43)
#  ->('q4', 15, '........P100101X01', 42)
#  ->('q10', 16, '........P100101201', 41)
#  ->('q8', 15, '........P1001012X1', 40)
#  ->('q8', 14, '........P1001012X1', 39)
#  ->('q8', 13, '........P1001012X1', 38)
#  ->('q8', 12, '........P1001012X1', 37)
#  ->('q8', 11, '........P1001012X1', 36)
#  ->('q8', 10, '........P1001012X1', 35)
#  ->('q8', 9, '........P1001012X1', 34)
#  ->('q8', 8, '........P1001012X1', 33)
#  ->('q3', 9, '........P1001012X1', 32)
#  ->('q5', 10, '........PQ001012X1', 31)
#  ->('q5', 11, '........PQ001012X1', 30)
#  ->('q5', 12, '........PQ001012X1', 29)
#  ->('q5', 13, '........PQ001012X1', 28)
#  ->('q5', 14, '........PQ001012X1', 27)
#  ->('q5', 15, '........PQ001012X1', 26)
#  ->('q5', 16, '........PQ001012X1', 25)
# Rejected at  ('q4', 14, '........P10010Y001', 45)
#  via ..
#  ->('q0', 0, '0100101001', 66)
#  ->('q14', 0, '0100101001', 65)
#  ->('q14', 1, '0100101001', 64)
#  ->('q14', 2, '0100101001', 63)
#  ->('q14', 3, '0100101001', 62)
#  ->('q14', 4, '0100101001', 61)
#  ->('q14', 5, '0100101001', 60)
#  ->('q14', 6, '0100101001', 59)
#  ->('q2', 5, '010010Y001', 58)
#  ->('q2', 4, '010010Y001', 57)
#  ->('q2', 3, '010010Y001', 56)
#  ->('q2', 2, '010010Y001', 55)
#  ->('q2', 1, '010010Y001', 54)
#  ->('q2', 0, '010010Y001', 53)
#  ->('q2', 7, '........010010Y001', 52)
#  ->('q3', 8, '........010010Y001', 51)
#  ->('q4', 9, '........P10010Y001', 50)
#  ->('q4', 10, '........P10010Y001', 49)
#  ->('q4', 11, '........P10010Y001', 48)
#  ->('q4', 12, '........P10010Y001', 47)
#  ->('q4', 13, '........P10010Y001', 46)
#  ->('q4', 14, '........P10010Y001', 45)
# Rejected at  ('q4', 12, '........P100Y01001', 51)
#  via ..
#  ->('q0', 0, '0100101001', 66)
#  ->('q14', 0, '0100101001', 65)
#  ->('q14', 1, '0100101001', 64)
#  ->('q14', 2, '0100101001', 63)
#  ->('q14', 3, '0100101001', 62)
#  ->('q14', 4, '0100101001', 61)
#  ->('q2', 3, '0100Y01001', 60)
#  ->('q2', 2, '0100Y01001', 59)
#  ->('q2', 1, '0100Y01001', 58)
#  ->('q2', 0, '0100Y01001', 57)
#  ->('q2', 7, '........0100Y01001', 56)
#  ->('q3', 8, '........0100Y01001', 55)
#  ->('q4', 9, '........P100Y01001', 54)
#  ->('q4', 10, '........P100Y01001', 53)
#  ->('q4', 11, '........P100Y01001', 52)
#  ->('q4', 12, '........P100Y01001', 51)
# Rejected at  ('q12', 14, '........PQP232Y001', 27)
#  via ..
#  ->('q0', 0, '0100101001', 66)
#  ->('q14', 0, '0100101001', 65)
#  ->('q14', 1, '0100101001', 64)
#  ->('q14', 2, '0100101001', 63)
#  ->('q14', 3, '0100101001', 62)
#  ->('q2', 2, '010X101001', 61)
#  ->('q2', 1, '010X101001', 60)
#  ->('q2', 0, '010X101001', 59)
#  ->('q2', 7, '........010X101001', 58)
#  ->('q3', 8, '........010X101001', 57)
#  ->('q4', 9, '........P10X101001', 56)
#  ->('q4', 10, '........P10X101001', 55)
#  ->('q4', 11, '........P10X101001', 54)
#  ->('q10', 12, '........P102101001', 53)
#  ->('q8', 11, '........P102Y01001', 52)
#  ->('q8', 10, '........P102Y01001', 51)
#  ->('q8', 9, '........P102Y01001', 50)
#  ->('q8', 8, '........P102Y01001', 49)
#  ->('q3', 9, '........P102Y01001', 48)
#  ->('q5', 10, '........PQ02Y01001', 47)
#  ->('q5', 11, '........PQ02Y01001', 46)
#  ->('q5', 12, '........PQ02Y01001', 45)
#  ->('q11', 13, '........PQ02301001', 44)
#  ->('q9', 12, '........PQ023X1001', 43)
#  ->('q9', 11, '........PQ023X1001', 42)
#  ->('q9', 10, '........PQ023X1001', 41)
#  ->('q9', 9, '........PQ023X1001', 40)
#  ->('q3', 10, '........PQ023X1001', 39)
#  ->('q4', 11, '........PQP23X1001', 38)
#  ->('q4', 12, '........PQP23X1001', 37)
#  ->('q4', 13, '........PQP23X1001', 36)
#  ->('q10', 14, '........PQP2321001', 35)
#  ->('q8', 13, '........PQP232Y001', 34)
#  ->('q8', 12, '........PQP232Y001', 33)
#  ->('q8', 11, '........PQP232Y001', 32)
#  ->('q8', 10, '........PQP232Y001', 31)
#  ->('q3', 11, '........PQP232Y001', 30)
#  ->('q12', 12, '........PQP232Y001', 29)
#  ->('q12', 13, '........PQP232Y001', 28)
#  ->('q12', 14, '........PQP232Y001', 27)
# Rejected at  ('q5', 11, '........PQ2X101001', 50)
#  via ..
#  ->('q0', 0, '0100101001', 66)
#  ->('q14', 0, '0100101001', 65)
#  ->('q14', 1, '0100101001', 64)
#  ->('q14', 2, '0100101001', 63)
#  ->('q2', 1, '01X0101001', 62)
#  ->('q2', 0, '01X0101001', 61)
#  ->('q2', 7, '........01X0101001', 60)
#  ->('q3', 8, '........01X0101001', 59)
#  ->('q4', 9, '........P1X0101001', 58)
#  ->('q4', 10, '........P1X0101001', 57)
#  ->('q10', 11, '........P120101001', 56)
#  ->('q8', 10, '........P12X101001', 55)
#  ->('q8', 9, '........P12X101001', 54)
#  ->('q8', 8, '........P12X101001', 53)
#  ->('q3', 9, '........P12X101001', 52)
#  ->('q5', 10, '........PQ2X101001', 51)
#  ->('q5', 11, '........PQ2X101001', 50)
# Rejected at  ('q4', 9, '........PY00101001', 60)
#  via ..
#  ->('q0', 0, '0100101001', 66)
#  ->('q14', 0, '0100101001', 65)
#  ->('q14', 1, '0100101001', 64)
#  ->('q2', 0, '0Y00101001', 63)
#  ->('q2', 7, '........0Y00101001', 62)
#  ->('q3', 8, '........0Y00101001', 61)
#  ->('q4', 9, '........PY00101001', 60)
# Rejected at  ('q6', 9, '........X100101001', 62)
#  via ..
#  ->('q0', 0, '0100101001', 66)
#  ->('q14', 0, '0100101001', 65)
#  ->('q2', 7, '........X100101001', 64)
#  ->('q3', 8, '........X100101001', 63)
#  ->('q6', 9, '........X100101001', 62)

# %%
addtm = {
    # This TM adds two numbers in base 2.
    #
    # Input: matches the regex "[01][01]*\+[01][01]*"
    #        Interpreted as a+b where a and b are unsigned integers in big-endian
    #          form
    # Output: Occurs on a halt in the "done" state.
    #         The sum of the numbers in big endian form.
    #         No other characters will be on the tape.
    #         There willbe no leading zeros on the answer.
    # Errors: The only errors that can occur are input errors which lead to
    #           a halt on the "error" state. This indicates the input does
    #           not conform to the input requirement.
    # Detail: There is no length maximums on the input.
    #         The numbers can be of different lengths.
    #         Leading zeros on inputs only cause a longer runtime.
    "Q": {
        # final states
        "done", "error",

        # input validation states
        "start",
        "check_a",
        "check_b_start",
        "check_b",

        # adder states
        "read_next_b_digit",
        "0_scan_to_a",
        "1_scan_to_a",
        "n_scan_to_a",
        "0_scan_to_a_digit",
        "1_scan_to_a_digit",
        "n_scan_to_a_digit",
        "0_scan_to_output",
        "1_scan_to_output",
        "c0_scan_to_output",
        "write_carry",
        "scan_to_b",
        "scan_to_b_digit",

        # answer formatting states
        "erase_until_sum",
        "find_end_of_sum",
        "read_msb_of_sum",
        "0_check_end_of_sum",
        "1_check_end_of_sum",
        "0_write_last_digit",
        "1_write_last_digit",
        "write_last_0",
        "write_last_1",
        "0_find_end_of_sum",
        "1_find_end_of_sum",
        "0_find_answer",
        "1_find_answer",
        "write_0",
        "write_1",
        "find_start_of_sum",
        "find_start_of_answer",
        "erase_leading_zeros",
    },

    "Sigma" : {'0', '1', '+'},

    "Gamma" : {'.',
               '0', '1', '+',
               'a', # right side marker for a input
               'b', # right side marker for b input
               'c', # carry indicator
               'X', # 0 used indicator
               'Y', # 1 used indicator
               's', # left side of answer space marker
               },

    "Delta" : {
        # Begin input validation
        ("start", '.') : { ("error", '.', 'S') },
        ("start", '+') : { ("error", '.', 'S') },
        ("start", '0') : { ("check_a", '0', 'R') },
        ("start", '1') : { ("check_a", '1', 'R') },
        #
        ("check_a", '0') : { ("check_a", '0', 'R') },
        ("check_a", '1') : { ("check_a", '1', 'R') },
        ("check_a", '.') : { ("error", '.', 'S') },
        ("check_a", '+') : { ("check_b_start", 'a', 'R') },
        #
        ("check_b_start", '0') : { ("check_b", '0', 'R') },
        ("check_b_start", '1') : { ("check_b", '1', 'R') },
        ("check_b_start", '.') : { ("error", '.', 'S') },
        ("check_b_start", '+') : { ("error", '+', 'S') },
        #
        ("check_b", '0') : { ("check_b", '0', 'R') },
        ("check_b", '1') : { ("check_b", '1', 'R') },
        ("check_b", '.') : { ("read_next_b_digit", 'b', 'L') },
        ("check_b", '+') : { ("error", '+', 'S') },
        # End input validation

        # Begin adder
        ("read_next_b_digit", '0') : { ("0_scan_to_a", 'X', 'L') },
        ("read_next_b_digit", '1') : { ("1_scan_to_a", 'Y', 'L') },
        #
        ("0_scan_to_a", '0') : { ("0_scan_to_a", '0', 'L') },
        ("0_scan_to_a", '1') : { ("0_scan_to_a", '1', 'L') },
        ("0_scan_to_a", 'a') : { ("0_scan_to_a_digit", 'a', 'L') },
        #
        ("1_scan_to_a", '0') : { ("1_scan_to_a", '0', 'L') },
        ("1_scan_to_a", '1') : { ("1_scan_to_a", '1', 'L') },
        ("1_scan_to_a", 'a') : { ("1_scan_to_a_digit", 'a', 'L') },
        #
        ("n_scan_to_a", '0') : { ("n_scan_to_a", '0', 'L') },
        ("n_scan_to_a", '1') : { ("n_scan_to_a", '1', 'L') },
        ("n_scan_to_a", 'a') : { ("n_scan_to_a_digit", 'a', 'L') },
        #
        ("0_scan_to_a_digit", 'X') : { ("0_scan_to_a_digit", 'X', 'L') },
        ("0_scan_to_a_digit", 'Y') : { ("0_scan_to_a_digit", 'Y', 'L') },
        ("0_scan_to_a_digit", '0') : { ("0_scan_to_output", 'X', 'R') },
        ("0_scan_to_a_digit", '1') : { ("1_scan_to_output", 'Y', 'R') },
        ("0_scan_to_a_digit", '.') : { ("0_scan_to_output", 's', 'R') },
        ("0_scan_to_a_digit", 's') : { ("0_scan_to_output", 's', 'R') },
        #
        ("1_scan_to_a_digit", 'X') : { ("1_scan_to_a_digit", 'X', 'L') },
        ("1_scan_to_a_digit", 'Y') : { ("1_scan_to_a_digit", 'Y', 'L') },
        ("1_scan_to_a_digit", '0') : { ("1_scan_to_output", 'X', 'R') },
        ("1_scan_to_a_digit", '1') : { ("c0_scan_to_output", 'Y', 'R') },
        ("1_scan_to_a_digit", '.') : { ("1_scan_to_output", 's', 'R') },
        ("1_scan_to_a_digit", 's') : { ("1_scan_to_output", 's', 'R') },
        #
        ("n_scan_to_a_digit", 'X') : { ("n_scan_to_a_digit", 'X', 'L') },
        ("n_scan_to_a_digit", 'Y') : { ("n_scan_to_a_digit", 'Y', 'L') },
        ("n_scan_to_a_digit", '0') : { ("0_scan_to_output", 'X', 'R') },
        ("n_scan_to_a_digit", '1') : { ("1_scan_to_output", 'Y', 'R') },
        ("n_scan_to_a_digit", '.') : { ("erase_until_sum", 's', 'R') },
        ("n_scan_to_a_digit", 's') : { ("erase_until_sum", 's', 'R') },
        #
        ("0_scan_to_output", '0') : { ("0_scan_to_output", '0', 'R') },
        ("0_scan_to_output", '1') : { ("0_scan_to_output", '1', 'R') },
        ("0_scan_to_output", 'X') : { ("0_scan_to_output", 'X', 'R') },
        ("0_scan_to_output", 'Y') : { ("0_scan_to_output", 'Y', 'R') },
        ("0_scan_to_output", 'a') : { ("0_scan_to_output", 'a', 'R') },
        ("0_scan_to_output", 'b') : { ("0_scan_to_output", 'b', 'R') },
        ("0_scan_to_output", '.') : { ("scan_to_b", '0', 'L') },
        ("0_scan_to_output", 'c') : { ("scan_to_b", '1', 'L') },
        #
        ("1_scan_to_output", '0') : { ("1_scan_to_output", '0', 'R') },
        ("1_scan_to_output", '1') : { ("1_scan_to_output", '1', 'R') },
        ("1_scan_to_output", 'X') : { ("1_scan_to_output", 'X', 'R') },
        ("1_scan_to_output", 'Y') : { ("1_scan_to_output", 'Y', 'R') },
        ("1_scan_to_output", 'a') : { ("1_scan_to_output", 'a', 'R') },
        ("1_scan_to_output", 'b') : { ("1_scan_to_output", 'b', 'R') },
        ("1_scan_to_output", '.') : { ("scan_to_b", '1', 'L') },
        ("1_scan_to_output", 'c') : { ("write_carry", '0', 'R') },
        #
        ("c0_scan_to_output", '0') : { ("c0_scan_to_output", '0', 'R') },
        ("c0_scan_to_output", '1') : { ("c0_scan_to_output", '1', 'R') },
        ("c0_scan_to_output", 'X') : { ("c0_scan_to_output", 'X', 'R') },
        ("c0_scan_to_output", 'Y') : { ("c0_scan_to_output", 'Y', 'R') },
        ("c0_scan_to_output", 'a') : { ("c0_scan_to_output", 'a', 'R') },
        ("c0_scan_to_output", 'b') : { ("c0_scan_to_output", 'b', 'R') },
        ("c0_scan_to_output", '.') : { ("write_carry", '0', 'R') },
        ("c0_scan_to_output", 'c') : { ("write_carry", '1', 'R') },
        #
        ("write_carry", '.') : { ("scan_to_b", 'c', 'L') },
        #
        ("scan_to_b", '0') : { ("scan_to_b", '0', 'L') },
        ("scan_to_b", '1') : { ("scan_to_b", '1', 'L') },
        ("scan_to_b", 'b') : { ("scan_to_b_digit", 'b', 'L') },
        #
        ("scan_to_b_digit", 'X') : { ("scan_to_b_digit", 'X', 'L') },
        ("scan_to_b_digit", 'Y') : { ("scan_to_b_digit", 'Y', 'L') },
        ("scan_to_b_digit", '0') : { ("read_next_b_digit", '0', 'S') },
        ("scan_to_b_digit", '1') : { ("read_next_b_digit", '1', 'S') },
        ("scan_to_b_digit", 'a') : { ("n_scan_to_a", 'a', 'S') },
        # End adder

        # Begin answer formatting
        ("erase_until_sum", '0') : { ("erase_until_sum", '.', 'R') },
        ("erase_until_sum", '1') : { ("erase_until_sum", '.', 'R') },
        ("erase_until_sum", 'X') : { ("erase_until_sum", '.', 'R') },
        ("erase_until_sum", 'Y') : { ("erase_until_sum", '.', 'R') },
        ("erase_until_sum", 'a') : { ("erase_until_sum", '.', 'R') },
        ("erase_until_sum", 'b') : { ("find_end_of_sum", '.', 'R') },
        #
        ("find_end_of_sum", '0') : { ("find_end_of_sum", '0', 'R') },
        ("find_end_of_sum", '1') : { ("find_end_of_sum", '1', 'R') },
        ("find_end_of_sum", 'c') : { ("read_msb_of_sum", '1', 'S') },
        ("find_end_of_sum", '.') : { ("read_msb_of_sum", '.', 'L') },
        #
        ("read_msb_of_sum", '0') : { ("0_check_end_of_sum", '.', 'L') },
        ("read_msb_of_sum", '1') : { ("1_check_end_of_sum", '.', 'L') },
        #
        ("0_check_end_of_sum", '0') : { ("0_find_end_of_sum", '0', 'L') },
        ("0_check_end_of_sum", '1') : { ("0_find_end_of_sum", '1', 'L') },
        ("0_check_end_of_sum", '.') : { ("0_write_last_digit", '.', 'L') },
        #
        ("1_check_end_of_sum", '0') : { ("1_find_end_of_sum", '0', 'L') },
        ("1_check_end_of_sum", '1') : { ("1_find_end_of_sum", '1', 'L') },
        ("1_check_end_of_sum", '.') : { ("1_write_last_digit", '.', 'L') },
        #
        ("0_write_last_digit", '.') : { ("0_write_last_digit", '.', 'L') },
        ("0_write_last_digit", '0') : { ("write_last_0", '0', 'R') },
        ("0_write_last_digit", '1') : { ("write_last_0", '1', 'R') },
        ("0_write_last_digit", 's') : { ("write_last_0", '.', 'R') },
        #
        ("1_write_last_digit", '.') : { ("1_write_last_digit", '.', 'L') },
        ("1_write_last_digit", '0') : { ("write_last_1", '0', 'R') },
        ("1_write_last_digit", '1') : { ("write_last_1", '1', 'R') },
        ("1_write_last_digit", 's') : { ("write_last_1", '.', 'R') },
        #
        ("write_last_0", '.') : { ("find_start_of_answer", '0', 'S') },
        #
        ("write_last_1", '.') : { ("find_start_of_answer", '1', 'S') },
        #
        ("0_find_end_of_sum", '0') : { ("0_find_end_of_sum", '0', 'L') },
        ("0_find_end_of_sum", '1') : { ("0_find_end_of_sum", '1', 'L') },
        ("0_find_end_of_sum", '.') : { ("0_find_answer", '.', 'L') },
        #
        ("1_find_end_of_sum", '0') : { ("1_find_end_of_sum", '0', 'L') },
        ("1_find_end_of_sum", '1') : { ("1_find_end_of_sum", '1', 'L') },
        ("1_find_end_of_sum", '.') : { ("1_find_answer", '.', 'L') },
        #
        ("0_find_answer", '.') : { ("0_find_answer", '.', 'L') },
        ("0_find_answer", '0') : { ("write_0", '0', 'R') },
        ("0_find_answer", '1') : { ("write_0", '1', 'R') },
        ("0_find_answer", 's') : { ("write_0", '.', 'R') },
        #
        ("1_find_answer", '.') : { ("1_find_answer", '.', 'L') },
        ("1_find_answer", '0') : { ("write_1", '0', 'R') },
        ("1_find_answer", '1') : { ("write_1", '1', 'R') },
        ("1_find_answer", 's') : { ("write_1", '.', 'R') },
        #
        ("write_0", '.') : { ("find_start_of_sum", '0', 'R') },
        #
        ("write_1", '.') : { ("find_start_of_sum", '1', 'R') },
        #
        ("find_start_of_sum", '.') : { ("find_start_of_sum", '.', 'R') },
        ("find_start_of_sum", '0') : { ("find_end_of_sum", '0', 'S') },
        ("find_start_of_sum", '1') : { ("find_end_of_sum", '1', 'S') },
        #
        ("find_start_of_answer", '0') : { ("find_start_of_answer", '0', 'L') },
        ("find_start_of_answer", '1') : { ("find_start_of_answer", '1', 'L') },
        ("find_start_of_answer", '.') : { ("erase_leading_zeros", '.', 'R') },
        #
        ("erase_leading_zeros", '0') : { ("erase_leading_zeros", '.', 'R') },
        ("erase_leading_zeros", '1') : { ("done", '1', 'S') },
        ("erase_leading_zeros", '.') : { ("done", '0', 'S') },
        # End answer formatting
    },

    "q0"    : "start",

    "B"     : '.',

    "F"     : {"done"}
}

# %%
dotObj_tm(addtm)

# %%
dotObj_tm(addtm, FuseEdges=True)

# %%
addtmobj = dotObj_tm(addtm)

# %%
explore_tm(addtm, "11111101+11111101", 735)
# Out:
# Allocating  8  tape cells to the RIGHT!
# Allocating  8  tape cells to the RIGHT!
# Allocating  8  tape cells to the LEFT!
# Detailing the halted configs now.
# Accepted at  ('done', 8, '........111111010........................', 2)
#  via ..
#  ->('start', 0, '11111101+11111101', 735)
#  ->('check_a', 1, '11111101+11111101', 734)
#  ->('check_a', 2, '11111101+11111101', 733)
#  ->('check_a', 3, '11111101+11111101', 732)
#  ->('check_a', 4, '11111101+11111101', 731)
#  ->('check_a', 5, '11111101+11111101', 730)
#  ->('check_a', 6, '11111101+11111101', 729)
#  ->('check_a', 7, '11111101+11111101', 728)
#  ->('check_a', 8, '11111101+11111101', 727)
#  ->('check_b_start', 9, '11111101a11111101', 726)
#  ->('check_b', 10, '11111101a11111101', 725)
#  ->('check_b', 11, '11111101a11111101', 724)
#  ->('check_b', 12, '11111101a11111101', 723)
#  ->('check_b', 13, '11111101a11111101', 722)
#  ->('check_b', 14, '11111101a11111101', 721)
#  ->('check_b', 15, '11111101a11111101', 720)
#  ->('check_b', 16, '11111101a11111101', 719)
#  ->('check_b', 17, '11111101a11111101', 718)
#  ->('read_next_b_digit', 16, '11111101a11111101b.......', 717)
#  ->('1_scan_to_a', 15, '11111101a1111110Yb.......', 716)
#  ->('1_scan_to_a', 14, '11111101a1111110Yb.......', 715)
#  ->('1_scan_to_a', 13, '11111101a1111110Yb.......', 714)
#  ->('1_scan_to_a', 12, '11111101a1111110Yb.......', 713)
#  ->('1_scan_to_a', 11, '11111101a1111110Yb.......', 712)
#  ->('1_scan_to_a', 10, '11111101a1111110Yb.......', 711)
#  ->('1_scan_to_a', 9, '11111101a1111110Yb.......', 710)
#  ->('1_scan_to_a', 8, '11111101a1111110Yb.......', 709)
#  ->('1_scan_to_a_digit', 7, '11111101a1111110Yb.......', 708)
#  ->('c0_scan_to_output', 8, '1111110Ya1111110Yb.......', 707)
#  ->('c0_scan_to_output', 9, '1111110Ya1111110Yb.......', 706)
#  ->('c0_scan_to_output', 10, '1111110Ya1111110Yb.......', 705)
#  ->('c0_scan_to_output', 11, '1111110Ya1111110Yb.......', 704)
#  ->('c0_scan_to_output', 12, '1111110Ya1111110Yb.......', 703)
#  ->('c0_scan_to_output', 13, '1111110Ya1111110Yb.......', 702)
#  ->('c0_scan_to_output', 14, '1111110Ya1111110Yb.......', 701)
#  ->('c0_scan_to_output', 15, '1111110Ya1111110Yb.......', 700)
#  ->('c0_scan_to_output', 16, '1111110Ya1111110Yb.......', 699)
#  ->('c0_scan_to_output', 17, '1111110Ya1111110Yb.......', 698)
#  ->('c0_scan_to_output', 18, '1111110Ya1111110Yb.......', 697)
#  ->('write_carry', 19, '1111110Ya1111110Yb0......', 696)
#  ->('scan_to_b', 18, '1111110Ya1111110Yb0c.....', 695)
#  ->('scan_to_b', 17, '1111110Ya1111110Yb0c.....', 694)
#  ->('scan_to_b_digit', 16, '1111110Ya1111110Yb0c.....', 693)
#  ->('scan_to_b_digit', 15, '1111110Ya1111110Yb0c.....', 692)
#  ->('read_next_b_digit', 15, '1111110Ya1111110Yb0c.....', 691)
#  ->('0_scan_to_a', 14, '1111110Ya111111XYb0c.....', 690)
#  ->('0_scan_to_a', 13, '1111110Ya111111XYb0c.....', 689)
#  ->('0_scan_to_a', 12, '1111110Ya111111XYb0c.....', 688)
#  ->('0_scan_to_a', 11, '1111110Ya111111XYb0c.....', 687)
#  ->('0_scan_to_a', 10, '1111110Ya111111XYb0c.....', 686)
#  ->('0_scan_to_a', 9, '1111110Ya111111XYb0c.....', 685)
#  ->('0_scan_to_a', 8, '1111110Ya111111XYb0c.....', 684)
#  ->('0_scan_to_a_digit', 7, '1111110Ya111111XYb0c.....', 683)
#  ->('0_scan_to_a_digit', 6, '1111110Ya111111XYb0c.....', 682)
#  ->('0_scan_to_output', 7, '111111XYa111111XYb0c.....', 681)
#  ->('0_scan_to_output', 8, '111111XYa111111XYb0c.....', 680)
#  ->('0_scan_to_output', 9, '111111XYa111111XYb0c.....', 679)
#  ->('0_scan_to_output', 10, '111111XYa111111XYb0c.....', 678)
#  ->('0_scan_to_output', 11, '111111XYa111111XYb0c.....', 677)
#  ->('0_scan_to_output', 12, '111111XYa111111XYb0c.....', 676)
#  ->('0_scan_to_output', 13, '111111XYa111111XYb0c.....', 675)
#  ->('0_scan_to_output', 14, '111111XYa111111XYb0c.....', 674)
#  ->('0_scan_to_output', 15, '111111XYa111111XYb0c.....', 673)
#  ->('0_scan_to_output', 16, '111111XYa111111XYb0c.....', 672)
#  ->('0_scan_to_output', 17, '111111XYa111111XYb0c.....', 671)
#  ->('0_scan_to_output', 18, '111111XYa111111XYb0c.....', 670)
#  ->('0_scan_to_output', 19, '111111XYa111111XYb0c.....', 669)
#  ->('scan_to_b', 18, '111111XYa111111XYb01.....', 668)
#  ->('scan_to_b', 17, '111111XYa111111XYb01.....', 667)
#  ->('scan_to_b_digit', 16, '111111XYa111111XYb01.....', 666)
#  ->('scan_to_b_digit', 15, '111111XYa111111XYb01.....', 665)
#  ->('scan_to_b_digit', 14, '111111XYa111111XYb01.....', 664)
#  ->('read_next_b_digit', 14, '111111XYa111111XYb01.....', 663)
#  ->('1_scan_to_a', 13, '111111XYa11111YXYb01.....', 662)
#  ->('1_scan_to_a', 12, '111111XYa11111YXYb01.....', 661)
#  ->('1_scan_to_a', 11, '111111XYa11111YXYb01.....', 660)
#  ->('1_scan_to_a', 10, '111111XYa11111YXYb01.....', 659)
#  ->('1_scan_to_a', 9, '111111XYa11111YXYb01.....', 658)
#  ->('1_scan_to_a', 8, '111111XYa11111YXYb01.....', 657)
#  ->('1_scan_to_a_digit', 7, '111111XYa11111YXYb01.....', 656)
#  ->('1_scan_to_a_digit', 6, '111111XYa11111YXYb01.....', 655)
#  ->('1_scan_to_a_digit', 5, '111111XYa11111YXYb01.....', 654)
#  ->('c0_scan_to_output', 6, '11111YXYa11111YXYb01.....', 653)
#  ->('c0_scan_to_output', 7, '11111YXYa11111YXYb01.....', 652)
#  ->('c0_scan_to_output', 8, '11111YXYa11111YXYb01.....', 651)
#  ->('c0_scan_to_output', 9, '11111YXYa11111YXYb01.....', 650)
#  ->('c0_scan_to_output', 10, '11111YXYa11111YXYb01.....', 649)
#  ->('c0_scan_to_output', 11, '11111YXYa11111YXYb01.....', 648)
#  ->('c0_scan_to_output', 12, '11111YXYa11111YXYb01.....', 647)
#  ->('c0_scan_to_output', 13, '11111YXYa11111YXYb01.....', 646)
#  ->('c0_scan_to_output', 14, '11111YXYa11111YXYb01.....', 645)
#  ->('c0_scan_to_output', 15, '11111YXYa11111YXYb01.....', 644)
#  ->('c0_scan_to_output', 16, '11111YXYa11111YXYb01.....', 643)
#  ->('c0_scan_to_output', 17, '11111YXYa11111YXYb01.....', 642)
#  ->('c0_scan_to_output', 18, '11111YXYa11111YXYb01.....', 641)
#  ->('c0_scan_to_output', 19, '11111YXYa11111YXYb01.....', 640)
#  ->('c0_scan_to_output', 20, '11111YXYa11111YXYb01.....', 639)
#  ->('write_carry', 21, '11111YXYa11111YXYb010....', 638)
#  ->('scan_to_b', 20, '11111YXYa11111YXYb010c...', 637)
#  ->('scan_to_b', 19, '11111YXYa11111YXYb010c...', 636)
#  ->('scan_to_b', 18, '11111YXYa11111YXYb010c...', 635)
#  ->('scan_to_b', 17, '11111YXYa11111YXYb010c...', 634)
#  ->('scan_to_b_digit', 16, '11111YXYa11111YXYb010c...', 633)
#  ->('scan_to_b_digit', 15, '11111YXYa11111YXYb010c...', 632)
#  ->('scan_to_b_digit', 14, '11111YXYa11111YXYb010c...', 631)
#  ->('scan_to_b_digit', 13, '11111YXYa11111YXYb010c...', 630)
#  ->('read_next_b_digit', 13, '11111YXYa11111YXYb010c...', 629)
#  ->('1_scan_to_a', 12, '11111YXYa1111YYXYb010c...', 628)
#  ->('1_scan_to_a', 11, '11111YXYa1111YYXYb010c...', 627)
#  ->('1_scan_to_a', 10, '11111YXYa1111YYXYb010c...', 626)
#  ->('1_scan_to_a', 9, '11111YXYa1111YYXYb010c...', 625)
#  ->('1_scan_to_a', 8, '11111YXYa1111YYXYb010c...', 624)
#  ->('1_scan_to_a_digit', 7, '11111YXYa1111YYXYb010c...', 623)
#  ->('1_scan_to_a_digit', 6, '11111YXYa1111YYXYb010c...', 622)
#  ->('1_scan_to_a_digit', 5, '11111YXYa1111YYXYb010c...', 621)
#  ->('1_scan_to_a_digit', 4, '11111YXYa1111YYXYb010c...', 620)
#  ->('c0_scan_to_output', 5, '1111YYXYa1111YYXYb010c...', 619)
#  ->('c0_scan_to_output', 6, '1111YYXYa1111YYXYb010c...', 618)
#  ->('c0_scan_to_output', 7, '1111YYXYa1111YYXYb010c...', 617)
#  ->('c0_scan_to_output', 8, '1111YYXYa1111YYXYb010c...', 616)
#  ->('c0_scan_to_output', 9, '1111YYXYa1111YYXYb010c...', 615)
#  ->('c0_scan_to_output', 10, '1111YYXYa1111YYXYb010c...', 614)
#  ->('c0_scan_to_output', 11, '1111YYXYa1111YYXYb010c...', 613)
#  ->('c0_scan_to_output', 12, '1111YYXYa1111YYXYb010c...', 612)
#  ->('c0_scan_to_output', 13, '1111YYXYa1111YYXYb010c...', 611)
#  ->('c0_scan_to_output', 14, '1111YYXYa1111YYXYb010c...', 610)
#  ->('c0_scan_to_output', 15, '1111YYXYa1111YYXYb010c...', 609)
#  ->('c0_scan_to_output', 16, '1111YYXYa1111YYXYb010c...', 608)
#  ->('c0_scan_to_output', 17, '1111YYXYa1111YYXYb010c...', 607)
#  ->('c0_scan_to_output', 18, '1111YYXYa1111YYXYb010c...', 606)
#  ->('c0_scan_to_output', 19, '1111YYXYa1111YYXYb010c...', 605)
#  ->('c0_scan_to_output', 20, '1111YYXYa1111YYXYb010c...', 604)
#  ->('c0_scan_to_output', 21, '1111YYXYa1111YYXYb010c...', 603)
#  ->('write_carry', 22, '1111YYXYa1111YYXYb0101...', 602)
#  ->('scan_to_b', 21, '1111YYXYa1111YYXYb0101c..', 601)
#  ->('scan_to_b', 20, '1111YYXYa1111YYXYb0101c..', 600)
#  ->('scan_to_b', 19, '1111YYXYa1111YYXYb0101c..', 599)
#  ->('scan_to_b', 18, '1111YYXYa1111YYXYb0101c..', 598)
#  ->('scan_to_b', 17, '1111YYXYa1111YYXYb0101c..', 597)
#  ->('scan_to_b_digit', 16, '1111YYXYa1111YYXYb0101c..', 596)
#  ->('scan_to_b_digit', 15, '1111YYXYa1111YYXYb0101c..', 595)
#  ->('scan_to_b_digit', 14, '1111YYXYa1111YYXYb0101c..', 594)
#  ->('scan_to_b_digit', 13, '1111YYXYa1111YYXYb0101c..', 593)
#  ->('scan_to_b_digit', 12, '1111YYXYa1111YYXYb0101c..', 592)
#  ->('read_next_b_digit', 12, '1111YYXYa1111YYXYb0101c..', 591)
#  ->('1_scan_to_a', 11, '1111YYXYa111YYYXYb0101c..', 590)
#  ->('1_scan_to_a', 10, '1111YYXYa111YYYXYb0101c..', 589)
#  ->('1_scan_to_a', 9, '1111YYXYa111YYYXYb0101c..', 588)
#  ->('1_scan_to_a', 8, '1111YYXYa111YYYXYb0101c..', 587)
#  ->('1_scan_to_a_digit', 7, '1111YYXYa111YYYXYb0101c..', 586)
#  ->('1_scan_to_a_digit', 6, '1111YYXYa111YYYXYb0101c..', 585)
#  ->('1_scan_to_a_digit', 5, '1111YYXYa111YYYXYb0101c..', 584)
#  ->('1_scan_to_a_digit', 4, '1111YYXYa111YYYXYb0101c..', 583)
#  ->('1_scan_to_a_digit', 3, '1111YYXYa111YYYXYb0101c..', 582)
#  ->('c0_scan_to_output', 4, '111YYYXYa111YYYXYb0101c..', 581)
#  ->('c0_scan_to_output', 5, '111YYYXYa111YYYXYb0101c..', 580)
#  ->('c0_scan_to_output', 6, '111YYYXYa111YYYXYb0101c..', 579)
#  ->('c0_scan_to_output', 7, '111YYYXYa111YYYXYb0101c..', 578)
#  ->('c0_scan_to_output', 8, '111YYYXYa111YYYXYb0101c..', 577)
#  ->('c0_scan_to_output', 9, '111YYYXYa111YYYXYb0101c..', 576)
#  ->('c0_scan_to_output', 10, '111YYYXYa111YYYXYb0101c..', 575)
#  ->('c0_scan_to_output', 11, '111YYYXYa111YYYXYb0101c..', 574)
#  ->('c0_scan_to_output', 12, '111YYYXYa111YYYXYb0101c..', 573)
#  ->('c0_scan_to_output', 13, '111YYYXYa111YYYXYb0101c..', 572)
#  ->('c0_scan_to_output', 14, '111YYYXYa111YYYXYb0101c..', 571)
#  ->('c0_scan_to_output', 15, '111YYYXYa111YYYXYb0101c..', 570)
#  ->('c0_scan_to_output', 16, '111YYYXYa111YYYXYb0101c..', 569)
#  ->('c0_scan_to_output', 17, '111YYYXYa111YYYXYb0101c..', 568)
#  ->('c0_scan_to_output', 18, '111YYYXYa111YYYXYb0101c..', 567)
#  ->('c0_scan_to_output', 19, '111YYYXYa111YYYXYb0101c..', 566)
#  ->('c0_scan_to_output', 20, '111YYYXYa111YYYXYb0101c..', 565)
#  ->('c0_scan_to_output', 21, '111YYYXYa111YYYXYb0101c..', 564)
#  ->('c0_scan_to_output', 22, '111YYYXYa111YYYXYb0101c..', 563)
#  ->('write_carry', 23, '111YYYXYa111YYYXYb01011..', 562)
#  ->('scan_to_b', 22, '111YYYXYa111YYYXYb01011c.', 561)
#  ->('scan_to_b', 21, '111YYYXYa111YYYXYb01011c.', 560)
#  ->('scan_to_b', 20, '111YYYXYa111YYYXYb01011c.', 559)
#  ->('scan_to_b', 19, '111YYYXYa111YYYXYb01011c.', 558)
#  ->('scan_to_b', 18, '111YYYXYa111YYYXYb01011c.', 557)
#  ->('scan_to_b', 17, '111YYYXYa111YYYXYb01011c.', 556)
#  ->('scan_to_b_digit', 16, '111YYYXYa111YYYXYb01011c.', 555)
#  ->('scan_to_b_digit', 15, '111YYYXYa111YYYXYb01011c.', 554)
#  ->('scan_to_b_digit', 14, '111YYYXYa111YYYXYb01011c.', 553)
#  ->('scan_to_b_digit', 13, '111YYYXYa111YYYXYb01011c.', 552)
#  ->('scan_to_b_digit', 12, '111YYYXYa111YYYXYb01011c.', 551)
#  ->('scan_to_b_digit', 11, '111YYYXYa111YYYXYb01011c.', 550)
#  ->('read_next_b_digit', 11, '111YYYXYa111YYYXYb01011c.', 549)
#  ->('1_scan_to_a', 10, '111YYYXYa11YYYYXYb01011c.', 548)
#  ->('1_scan_to_a', 9, '111YYYXYa11YYYYXYb01011c.', 547)
#  ->('1_scan_to_a', 8, '111YYYXYa11YYYYXYb01011c.', 546)
#  ->('1_scan_to_a_digit', 7, '111YYYXYa11YYYYXYb01011c.', 545)
#  ->('1_scan_to_a_digit', 6, '111YYYXYa11YYYYXYb01011c.', 544)
#  ->('1_scan_to_a_digit', 5, '111YYYXYa11YYYYXYb01011c.', 543)
#  ->('1_scan_to_a_digit', 4, '111YYYXYa11YYYYXYb01011c.', 542)
#  ->('1_scan_to_a_digit', 3, '111YYYXYa11YYYYXYb01011c.', 541)
#  ->('1_scan_to_a_digit', 2, '111YYYXYa11YYYYXYb01011c.', 540)
#  ->('c0_scan_to_output', 3, '11YYYYXYa11YYYYXYb01011c.', 539)
#  ->('c0_scan_to_output', 4, '11YYYYXYa11YYYYXYb01011c.', 538)
#  ->('c0_scan_to_output', 5, '11YYYYXYa11YYYYXYb01011c.', 537)
#  ->('c0_scan_to_output', 6, '11YYYYXYa11YYYYXYb01011c.', 536)
#  ->('c0_scan_to_output', 7, '11YYYYXYa11YYYYXYb01011c.', 535)
#  ->('c0_scan_to_output', 8, '11YYYYXYa11YYYYXYb01011c.', 534)
#  ->('c0_scan_to_output', 9, '11YYYYXYa11YYYYXYb01011c.', 533)
#  ->('c0_scan_to_output', 10, '11YYYYXYa11YYYYXYb01011c.', 532)
#  ->('c0_scan_to_output', 11, '11YYYYXYa11YYYYXYb01011c.', 531)
#  ->('c0_scan_to_output', 12, '11YYYYXYa11YYYYXYb01011c.', 530)
#  ->('c0_scan_to_output', 13, '11YYYYXYa11YYYYXYb01011c.', 529)
#  ->('c0_scan_to_output', 14, '11YYYYXYa11YYYYXYb01011c.', 528)
#  ->('c0_scan_to_output', 15, '11YYYYXYa11YYYYXYb01011c.', 527)
#  ->('c0_scan_to_output', 16, '11YYYYXYa11YYYYXYb01011c.', 526)
#  ->('c0_scan_to_output', 17, '11YYYYXYa11YYYYXYb01011c.', 525)
#  ->('c0_scan_to_output', 18, '11YYYYXYa11YYYYXYb01011c.', 524)
#  ->('c0_scan_to_output', 19, '11YYYYXYa11YYYYXYb01011c.', 523)
#  ->('c0_scan_to_output', 20, '11YYYYXYa11YYYYXYb01011c.', 522)
#  ->('c0_scan_to_output', 21, '11YYYYXYa11YYYYXYb01011c.', 521)
#  ->('c0_scan_to_output', 22, '11YYYYXYa11YYYYXYb01011c.', 520)
#  ->('c0_scan_to_output', 23, '11YYYYXYa11YYYYXYb01011c.', 519)
#  ->('write_carry', 24, '11YYYYXYa11YYYYXYb010111.', 518)
#  ->('scan_to_b', 23, '11YYYYXYa11YYYYXYb010111c', 517)
#  ->('scan_to_b', 22, '11YYYYXYa11YYYYXYb010111c', 516)
#  ->('scan_to_b', 21, '11YYYYXYa11YYYYXYb010111c', 515)
#  ->('scan_to_b', 20, '11YYYYXYa11YYYYXYb010111c', 514)
#  ->('scan_to_b', 19, '11YYYYXYa11YYYYXYb010111c', 513)
#  ->('scan_to_b', 18, '11YYYYXYa11YYYYXYb010111c', 512)
#  ->('scan_to_b', 17, '11YYYYXYa11YYYYXYb010111c', 511)
#  ->('scan_to_b_digit', 16, '11YYYYXYa11YYYYXYb010111c', 510)
#  ->('scan_to_b_digit', 15, '11YYYYXYa11YYYYXYb010111c', 509)
#  ->('scan_to_b_digit', 14, '11YYYYXYa11YYYYXYb010111c', 508)
#  ->('scan_to_b_digit', 13, '11YYYYXYa11YYYYXYb010111c', 507)
#  ->('scan_to_b_digit', 12, '11YYYYXYa11YYYYXYb010111c', 506)
#  ->('scan_to_b_digit', 11, '11YYYYXYa11YYYYXYb010111c', 505)
#  ->('scan_to_b_digit', 10, '11YYYYXYa11YYYYXYb010111c', 504)
#  ->('read_next_b_digit', 10, '11YYYYXYa11YYYYXYb010111c', 503)
#  ->('1_scan_to_a', 9, '11YYYYXYa1YYYYYXYb010111c', 502)
#  ->('1_scan_to_a', 8, '11YYYYXYa1YYYYYXYb010111c', 501)
#  ->('1_scan_to_a_digit', 7, '11YYYYXYa1YYYYYXYb010111c', 500)
#  ->('1_scan_to_a_digit', 6, '11YYYYXYa1YYYYYXYb010111c', 499)
#  ->('1_scan_to_a_digit', 5, '11YYYYXYa1YYYYYXYb010111c', 498)
#  ->('1_scan_to_a_digit', 4, '11YYYYXYa1YYYYYXYb010111c', 497)
#  ->('1_scan_to_a_digit', 3, '11YYYYXYa1YYYYYXYb010111c', 496)
#  ->('1_scan_to_a_digit', 2, '11YYYYXYa1YYYYYXYb010111c', 495)
#  ->('1_scan_to_a_digit', 1, '11YYYYXYa1YYYYYXYb010111c', 494)
#  ->('c0_scan_to_output', 2, '1YYYYYXYa1YYYYYXYb010111c', 493)
#  ->('c0_scan_to_output', 3, '1YYYYYXYa1YYYYYXYb010111c', 492)
#  ->('c0_scan_to_output', 4, '1YYYYYXYa1YYYYYXYb010111c', 491)
#  ->('c0_scan_to_output', 5, '1YYYYYXYa1YYYYYXYb010111c', 490)
#  ->('c0_scan_to_output', 6, '1YYYYYXYa1YYYYYXYb010111c', 489)
#  ->('c0_scan_to_output', 7, '1YYYYYXYa1YYYYYXYb010111c', 488)
#  ->('c0_scan_to_output', 8, '1YYYYYXYa1YYYYYXYb010111c', 487)
#  ->('c0_scan_to_output', 9, '1YYYYYXYa1YYYYYXYb010111c', 486)
#  ->('c0_scan_to_output', 10, '1YYYYYXYa1YYYYYXYb010111c', 485)
#  ->('c0_scan_to_output', 11, '1YYYYYXYa1YYYYYXYb010111c', 484)
#  ->('c0_scan_to_output', 12, '1YYYYYXYa1YYYYYXYb010111c', 483)
#  ->('c0_scan_to_output', 13, '1YYYYYXYa1YYYYYXYb010111c', 482)
#  ->('c0_scan_to_output', 14, '1YYYYYXYa1YYYYYXYb010111c', 481)
#  ->('c0_scan_to_output', 15, '1YYYYYXYa1YYYYYXYb010111c', 480)
#  ->('c0_scan_to_output', 16, '1YYYYYXYa1YYYYYXYb010111c', 479)
#  ->('c0_scan_to_output', 17, '1YYYYYXYa1YYYYYXYb010111c', 478)
#  ->('c0_scan_to_output', 18, '1YYYYYXYa1YYYYYXYb010111c', 477)
#  ->('c0_scan_to_output', 19, '1YYYYYXYa1YYYYYXYb010111c', 476)
#  ->('c0_scan_to_output', 20, '1YYYYYXYa1YYYYYXYb010111c', 475)
#  ->('c0_scan_to_output', 21, '1YYYYYXYa1YYYYYXYb010111c', 474)
#  ->('c0_scan_to_output', 22, '1YYYYYXYa1YYYYYXYb010111c', 473)
#  ->('c0_scan_to_output', 23, '1YYYYYXYa1YYYYYXYb010111c', 472)
#  ->('c0_scan_to_output', 24, '1YYYYYXYa1YYYYYXYb010111c', 471)
#  ->('write_carry', 25, '1YYYYYXYa1YYYYYXYb0101111', 470)
#  ->('scan_to_b', 24, '1YYYYYXYa1YYYYYXYb0101111c.......', 469)
#  ->('scan_to_b', 23, '1YYYYYXYa1YYYYYXYb0101111c.......', 468)
#  ->('scan_to_b', 22, '1YYYYYXYa1YYYYYXYb0101111c.......', 467)
#  ->('scan_to_b', 21, '1YYYYYXYa1YYYYYXYb0101111c.......', 466)
#  ->('scan_to_b', 20, '1YYYYYXYa1YYYYYXYb0101111c.......', 465)
#  ->('scan_to_b', 19, '1YYYYYXYa1YYYYYXYb0101111c.......', 464)
#  ->('scan_to_b', 18, '1YYYYYXYa1YYYYYXYb0101111c.......', 463)
#  ->('scan_to_b', 17, '1YYYYYXYa1YYYYYXYb0101111c.......', 462)
#  ->('scan_to_b_digit', 16, '1YYYYYXYa1YYYYYXYb0101111c.......', 461)
#  ->('scan_to_b_digit', 15, '1YYYYYXYa1YYYYYXYb0101111c.......', 460)
#  ->('scan_to_b_digit', 14, '1YYYYYXYa1YYYYYXYb0101111c.......', 459)
#  ->('scan_to_b_digit', 13, '1YYYYYXYa1YYYYYXYb0101111c.......', 458)
#  ->('scan_to_b_digit', 12, '1YYYYYXYa1YYYYYXYb0101111c.......', 457)
#  ->('scan_to_b_digit', 11, '1YYYYYXYa1YYYYYXYb0101111c.......', 456)
#  ->('scan_to_b_digit', 10, '1YYYYYXYa1YYYYYXYb0101111c.......', 455)
#  ->('scan_to_b_digit', 9, '1YYYYYXYa1YYYYYXYb0101111c.......', 454)
#  ->('read_next_b_digit', 9, '1YYYYYXYa1YYYYYXYb0101111c.......', 453)
#  ->('1_scan_to_a', 8, '1YYYYYXYaYYYYYYXYb0101111c.......', 452)
#  ->('1_scan_to_a_digit', 7, '1YYYYYXYaYYYYYYXYb0101111c.......', 451)
#  ->('1_scan_to_a_digit', 6, '1YYYYYXYaYYYYYYXYb0101111c.......', 450)
#  ->('1_scan_to_a_digit', 5, '1YYYYYXYaYYYYYYXYb0101111c.......', 449)
#  ->('1_scan_to_a_digit', 4, '1YYYYYXYaYYYYYYXYb0101111c.......', 448)
#  ->('1_scan_to_a_digit', 3, '1YYYYYXYaYYYYYYXYb0101111c.......', 447)
#  ->('1_scan_to_a_digit', 2, '1YYYYYXYaYYYYYYXYb0101111c.......', 446)
#  ->('1_scan_to_a_digit', 1, '1YYYYYXYaYYYYYYXYb0101111c.......', 445)
#  ->('1_scan_to_a_digit', 0, '1YYYYYXYaYYYYYYXYb0101111c.......', 444)
#  ->('c0_scan_to_output', 1, 'YYYYYYXYaYYYYYYXYb0101111c.......', 443)
#  ->('c0_scan_to_output', 2, 'YYYYYYXYaYYYYYYXYb0101111c.......', 442)
#  ->('c0_scan_to_output', 3, 'YYYYYYXYaYYYYYYXYb0101111c.......', 441)
#  ->('c0_scan_to_output', 4, 'YYYYYYXYaYYYYYYXYb0101111c.......', 440)
#  ->('c0_scan_to_output', 5, 'YYYYYYXYaYYYYYYXYb0101111c.......', 439)
#  ->('c0_scan_to_output', 6, 'YYYYYYXYaYYYYYYXYb0101111c.......', 438)
#  ->('c0_scan_to_output', 7, 'YYYYYYXYaYYYYYYXYb0101111c.......', 437)
#  ->('c0_scan_to_output', 8, 'YYYYYYXYaYYYYYYXYb0101111c.......', 436)
#  ->('c0_scan_to_output', 9, 'YYYYYYXYaYYYYYYXYb0101111c.......', 435)
#  ->('c0_scan_to_output', 10, 'YYYYYYXYaYYYYYYXYb0101111c.......', 434)
#  ->('c0_scan_to_output', 11, 'YYYYYYXYaYYYYYYXYb0101111c.......', 433)
#  ->('c0_scan_to_output', 12, 'YYYYYYXYaYYYYYYXYb0101111c.......', 432)
#  ->('c0_scan_to_output', 13, 'YYYYYYXYaYYYYYYXYb0101111c.......', 431)
#  ->('c0_scan_to_output', 14, 'YYYYYYXYaYYYYYYXYb0101111c.......', 430)
#  ->('c0_scan_to_output', 15, 'YYYYYYXYaYYYYYYXYb0101111c.......', 429)
#  ->('c0_scan_to_output', 16, 'YYYYYYXYaYYYYYYXYb0101111c.......', 428)
#  ->('c0_scan_to_output', 17, 'YYYYYYXYaYYYYYYXYb0101111c.......', 427)
#  ->('c0_scan_to_output', 18, 'YYYYYYXYaYYYYYYXYb0101111c.......', 426)
#  ->('c0_scan_to_output', 19, 'YYYYYYXYaYYYYYYXYb0101111c.......', 425)
#  ->('c0_scan_to_output', 20, 'YYYYYYXYaYYYYYYXYb0101111c.......', 424)
#  ->('c0_scan_to_output', 21, 'YYYYYYXYaYYYYYYXYb0101111c.......', 423)
#  ->('c0_scan_to_output', 22, 'YYYYYYXYaYYYYYYXYb0101111c.......', 422)
#  ->('c0_scan_to_output', 23, 'YYYYYYXYaYYYYYYXYb0101111c.......', 421)
#  ->('c0_scan_to_output', 24, 'YYYYYYXYaYYYYYYXYb0101111c.......', 420)
#  ->('c0_scan_to_output', 25, 'YYYYYYXYaYYYYYYXYb0101111c.......', 419)
#  ->('write_carry', 26, 'YYYYYYXYaYYYYYYXYb01011111.......', 418)
#  ->('scan_to_b', 25, 'YYYYYYXYaYYYYYYXYb01011111c......', 417)
#  ->('scan_to_b', 24, 'YYYYYYXYaYYYYYYXYb01011111c......', 416)
#  ->('scan_to_b', 23, 'YYYYYYXYaYYYYYYXYb01011111c......', 415)
#  ->('scan_to_b', 22, 'YYYYYYXYaYYYYYYXYb01011111c......', 414)
#  ->('scan_to_b', 21, 'YYYYYYXYaYYYYYYXYb01011111c......', 413)
#  ->('scan_to_b', 20, 'YYYYYYXYaYYYYYYXYb01011111c......', 412)
#  ->('scan_to_b', 19, 'YYYYYYXYaYYYYYYXYb01011111c......', 411)
#  ->('scan_to_b', 18, 'YYYYYYXYaYYYYYYXYb01011111c......', 410)
#  ->('scan_to_b', 17, 'YYYYYYXYaYYYYYYXYb01011111c......', 409)
#  ->('scan_to_b_digit', 16, 'YYYYYYXYaYYYYYYXYb01011111c......', 408)
#  ->('scan_to_b_digit', 15, 'YYYYYYXYaYYYYYYXYb01011111c......', 407)
#  ->('scan_to_b_digit', 14, 'YYYYYYXYaYYYYYYXYb01011111c......', 406)
#  ->('scan_to_b_digit', 13, 'YYYYYYXYaYYYYYYXYb01011111c......', 405)
#  ->('scan_to_b_digit', 12, 'YYYYYYXYaYYYYYYXYb01011111c......', 404)
#  ->('scan_to_b_digit', 11, 'YYYYYYXYaYYYYYYXYb01011111c......', 403)
#  ->('scan_to_b_digit', 10, 'YYYYYYXYaYYYYYYXYb01011111c......', 402)
#  ->('scan_to_b_digit', 9, 'YYYYYYXYaYYYYYYXYb01011111c......', 401)
#  ->('scan_to_b_digit', 8, 'YYYYYYXYaYYYYYYXYb01011111c......', 400)
#  ->('n_scan_to_a', 8, 'YYYYYYXYaYYYYYYXYb01011111c......', 399)
#  ->('n_scan_to_a_digit', 7, 'YYYYYYXYaYYYYYYXYb01011111c......', 398)
#  ->('n_scan_to_a_digit', 6, 'YYYYYYXYaYYYYYYXYb01011111c......', 397)
#  ->('n_scan_to_a_digit', 5, 'YYYYYYXYaYYYYYYXYb01011111c......', 396)
#  ->('n_scan_to_a_digit', 4, 'YYYYYYXYaYYYYYYXYb01011111c......', 395)
#  ->('n_scan_to_a_digit', 3, 'YYYYYYXYaYYYYYYXYb01011111c......', 394)
#  ->('n_scan_to_a_digit', 2, 'YYYYYYXYaYYYYYYXYb01011111c......', 393)
#  ->('n_scan_to_a_digit', 1, 'YYYYYYXYaYYYYYYXYb01011111c......', 392)
#  ->('n_scan_to_a_digit', 0, 'YYYYYYXYaYYYYYYXYb01011111c......', 391)
#  ->('n_scan_to_a_digit', 7, '........YYYYYYXYaYYYYYYXYb01011111c......', 390)
#  ->('erase_until_sum', 8, '.......sYYYYYYXYaYYYYYYXYb01011111c......', 389)
#  ->('erase_until_sum', 9, '.......s.YYYYYXYaYYYYYYXYb01011111c......', 388)
#  ->('erase_until_sum', 10, '.......s..YYYYXYaYYYYYYXYb01011111c......', 387)
#  ->('erase_until_sum', 11, '.......s...YYYXYaYYYYYYXYb01011111c......', 386)
#  ->('erase_until_sum', 12, '.......s....YYXYaYYYYYYXYb01011111c......', 385)
#  ->('erase_until_sum', 13, '.......s.....YXYaYYYYYYXYb01011111c......', 384)
#  ->('erase_until_sum', 14, '.......s......XYaYYYYYYXYb01011111c......', 383)
#  ->('erase_until_sum', 15, '.......s.......YaYYYYYYXYb01011111c......', 382)
#  ->('erase_until_sum', 16, '.......s........aYYYYYYXYb01011111c......', 381)
#  ->('erase_until_sum', 17, '.......s.........YYYYYYXYb01011111c......', 380)
#  ->('erase_until_sum', 18, '.......s..........YYYYYXYb01011111c......', 379)
#  ->('erase_until_sum', 19, '.......s...........YYYYXYb01011111c......', 378)
#  ->('erase_until_sum', 20, '.......s............YYYXYb01011111c......', 377)
#  ->('erase_until_sum', 21, '.......s.............YYXYb01011111c......', 376)
#  ->('erase_until_sum', 22, '.......s..............YXYb01011111c......', 375)
#  ->('erase_until_sum', 23, '.......s...............XYb01011111c......', 374)
#  ->('erase_until_sum', 24, '.......s................Yb01011111c......', 373)
#  ->('erase_until_sum', 25, '.......s.................b01011111c......', 372)
#  ->('find_end_of_sum', 26, '.......s..................01011111c......', 371)
#  ->('find_end_of_sum', 27, '.......s..................01011111c......', 370)
#  ->('find_end_of_sum', 28, '.......s..................01011111c......', 369)
#  ->('find_end_of_sum', 29, '.......s..................01011111c......', 368)
#  ->('find_end_of_sum', 30, '.......s..................01011111c......', 367)
#  ->('find_end_of_sum', 31, '.......s..................01011111c......', 366)
#  ->('find_end_of_sum', 32, '.......s..................01011111c......', 365)
#  ->('find_end_of_sum', 33, '.......s..................01011111c......', 364)
#  ->('find_end_of_sum', 34, '.......s..................01011111c......', 363)
#  ->('read_msb_of_sum', 34, '.......s..................010111111......', 362)
#  ->('1_check_end_of_sum', 33, '.......s..................01011111.......', 361)
#  ->('1_find_end_of_sum', 32, '.......s..................01011111.......', 360)
#  ->('1_find_end_of_sum', 31, '.......s..................01011111.......', 359)
#  ->('1_find_end_of_sum', 30, '.......s..................01011111.......', 358)
#  ->('1_find_end_of_sum', 29, '.......s..................01011111.......', 357)
#  ->('1_find_end_of_sum', 28, '.......s..................01011111.......', 356)
#  ->('1_find_end_of_sum', 27, '.......s..................01011111.......', 355)
#  ->('1_find_end_of_sum', 26, '.......s..................01011111.......', 354)
#  ->('1_find_end_of_sum', 25, '.......s..................01011111.......', 353)
#  ->('1_find_answer', 24, '.......s..................01011111.......', 352)
#  ->('1_find_answer', 23, '.......s..................01011111.......', 351)
#  ->('1_find_answer', 22, '.......s..................01011111.......', 350)
#  ->('1_find_answer', 21, '.......s..................01011111.......', 349)
#  ->('1_find_answer', 20, '.......s..................01011111.......', 348)
#  ->('1_find_answer', 19, '.......s..................01011111.......', 347)
#  ->('1_find_answer', 18, '.......s..................01011111.......', 346)
#  ->('1_find_answer', 17, '.......s..................01011111.......', 345)
#  ->('1_find_answer', 16, '.......s..................01011111.......', 344)
#  ->('1_find_answer', 15, '.......s..................01011111.......', 343)
#  ->('1_find_answer', 14, '.......s..................01011111.......', 342)
#  ->('1_find_answer', 13, '.......s..................01011111.......', 341)
#  ->('1_find_answer', 12, '.......s..................01011111.......', 340)
#  ->('1_find_answer', 11, '.......s..................01011111.......', 339)
#  ->('1_find_answer', 10, '.......s..................01011111.......', 338)
#  ->('1_find_answer', 9, '.......s..................01011111.......', 337)
#  ->('1_find_answer', 8, '.......s..................01011111.......', 336)
#  ->('1_find_answer', 7, '.......s..................01011111.......', 335)
#  ->('write_1', 8, '..........................01011111.......', 334)
#  ->('find_start_of_sum', 9, '........1.................01011111.......', 333)
#  ->('find_start_of_sum', 10, '........1.................01011111.......', 332)
#  ->('find_start_of_sum', 11, '........1.................01011111.......', 331)
#  ->('find_start_of_sum', 12, '........1.................01011111.......', 330)
#  ->('find_start_of_sum', 13, '........1.................01011111.......', 329)
#  ->('find_start_of_sum', 14, '........1.................01011111.......', 328)
#  ->('find_start_of_sum', 15, '........1.................01011111.......', 327)
#  ->('find_start_of_sum', 16, '........1.................01011111.......', 326)
#  ->('find_start_of_sum', 17, '........1.................01011111.......', 325)
#  ->('find_start_of_sum', 18, '........1.................01011111.......', 324)
#  ->('find_start_of_sum', 19, '........1.................01011111.......', 323)
#  ->('find_start_of_sum', 20, '........1.................01011111.......', 322)
#  ->('find_start_of_sum', 21, '........1.................01011111.......', 321)
#  ->('find_start_of_sum', 22, '........1.................01011111.......', 320)
#  ->('find_start_of_sum', 23, '........1.................01011111.......', 319)
#  ->('find_start_of_sum', 24, '........1.................01011111.......', 318)
#  ->('find_start_of_sum', 25, '........1.................01011111.......', 317)
#  ->('find_start_of_sum', 26, '........1.................01011111.......', 316)
#  ->('find_end_of_sum', 26, '........1.................01011111.......', 315)
#  ->('find_end_of_sum', 27, '........1.................01011111.......', 314)
#  ->('find_end_of_sum', 28, '........1.................01011111.......', 313)
#  ->('find_end_of_sum', 29, '........1.................01011111.......', 312)
#  ->('find_end_of_sum', 30, '........1.................01011111.......', 311)
#  ->('find_end_of_sum', 31, '........1.................01011111.......', 310)
#  ->('find_end_of_sum', 32, '........1.................01011111.......', 309)
#  ->('find_end_of_sum', 33, '........1.................01011111.......', 308)
#  ->('find_end_of_sum', 34, '........1.................01011111.......', 307)
#  ->('read_msb_of_sum', 33, '........1.................01011111.......', 306)
#  ->('1_check_end_of_sum', 32, '........1.................0101111........', 305)
#  ->('1_find_end_of_sum', 31, '........1.................0101111........', 304)
#  ->('1_find_end_of_sum', 30, '........1.................0101111........', 303)
#  ->('1_find_end_of_sum', 29, '........1.................0101111........', 302)
#  ->('1_find_end_of_sum', 28, '........1.................0101111........', 301)
#  ->('1_find_end_of_sum', 27, '........1.................0101111........', 300)
#  ->('1_find_end_of_sum', 26, '........1.................0101111........', 299)
#  ->('1_find_end_of_sum', 25, '........1.................0101111........', 298)
#  ->('1_find_answer', 24, '........1.................0101111........', 297)
#  ->('1_find_answer', 23, '........1.................0101111........', 296)
#  ->('1_find_answer', 22, '........1.................0101111........', 295)
#  ->('1_find_answer', 21, '........1.................0101111........', 294)
#  ->('1_find_answer', 20, '........1.................0101111........', 293)
#  ->('1_find_answer', 19, '........1.................0101111........', 292)
#  ->('1_find_answer', 18, '........1.................0101111........', 291)
#  ->('1_find_answer', 17, '........1.................0101111........', 290)
#  ->('1_find_answer', 16, '........1.................0101111........', 289)
#  ->('1_find_answer', 15, '........1.................0101111........', 288)
#  ->('1_find_answer', 14, '........1.................0101111........', 287)
#  ->('1_find_answer', 13, '........1.................0101111........', 286)
#  ->('1_find_answer', 12, '........1.................0101111........', 285)
#  ->('1_find_answer', 11, '........1.................0101111........', 284)
#  ->('1_find_answer', 10, '........1.................0101111........', 283)
#  ->('1_find_answer', 9, '........1.................0101111........', 282)
#  ->('1_find_answer', 8, '........1.................0101111........', 281)
#  ->('write_1', 9, '........1.................0101111........', 280)
#  ->('find_start_of_sum', 10, '........11................0101111........', 279)
#  ->('find_start_of_sum', 11, '........11................0101111........', 278)
#  ->('find_start_of_sum', 12, '........11................0101111........', 277)
#  ->('find_start_of_sum', 13, '........11................0101111........', 276)
#  ->('find_start_of_sum', 14, '........11................0101111........', 275)
#  ->('find_start_of_sum', 15, '........11................0101111........', 274)
#  ->('find_start_of_sum', 16, '........11................0101111........', 273)
#  ->('find_start_of_sum', 17, '........11................0101111........', 272)
#  ->('find_start_of_sum', 18, '........11................0101111........', 271)
#  ->('find_start_of_sum', 19, '........11................0101111........', 270)
#  ->('find_start_of_sum', 20, '........11................0101111........', 269)
#  ->('find_start_of_sum', 21, '........11................0101111........', 268)
#  ->('find_start_of_sum', 22, '........11................0101111........', 267)
#  ->('find_start_of_sum', 23, '........11................0101111........', 266)
#  ->('find_start_of_sum', 24, '........11................0101111........', 265)
#  ->('find_start_of_sum', 25, '........11................0101111........', 264)
#  ->('find_start_of_sum', 26, '........11................0101111........', 263)
#  ->('find_end_of_sum', 26, '........11................0101111........', 262)
#  ->('find_end_of_sum', 27, '........11................0101111........', 261)
#  ->('find_end_of_sum', 28, '........11................0101111........', 260)
#  ->('find_end_of_sum', 29, '........11................0101111........', 259)
#  ->('find_end_of_sum', 30, '........11................0101111........', 258)
#  ->('find_end_of_sum', 31, '........11................0101111........', 257)
#  ->('find_end_of_sum', 32, '........11................0101111........', 256)
#  ->('find_end_of_sum', 33, '........11................0101111........', 255)
#  ->('read_msb_of_sum', 32, '........11................0101111........', 254)
#  ->('1_check_end_of_sum', 31, '........11................010111.........', 253)
#  ->('1_find_end_of_sum', 30, '........11................010111.........', 252)
#  ->('1_find_end_of_sum', 29, '........11................010111.........', 251)
#  ->('1_find_end_of_sum', 28, '........11................010111.........', 250)
#  ->('1_find_end_of_sum', 27, '........11................010111.........', 249)
#  ->('1_find_end_of_sum', 26, '........11................010111.........', 248)
#  ->('1_find_end_of_sum', 25, '........11................010111.........', 247)
#  ->('1_find_answer', 24, '........11................010111.........', 246)
#  ->('1_find_answer', 23, '........11................010111.........', 245)
#  ->('1_find_answer', 22, '........11................010111.........', 244)
#  ->('1_find_answer', 21, '........11................010111.........', 243)
#  ->('1_find_answer', 20, '........11................010111.........', 242)
#  ->('1_find_answer', 19, '........11................010111.........', 241)
#  ->('1_find_answer', 18, '........11................010111.........', 240)
#  ->('1_find_answer', 17, '........11................010111.........', 239)
#  ->('1_find_answer', 16, '........11................010111.........', 238)
#  ->('1_find_answer', 15, '........11................010111.........', 237)
#  ->('1_find_answer', 14, '........11................010111.........', 236)
#  ->('1_find_answer', 13, '........11................010111.........', 235)
#  ->('1_find_answer', 12, '........11................010111.........', 234)
#  ->('1_find_answer', 11, '........11................010111.........', 233)
#  ->('1_find_answer', 10, '........11................010111.........', 232)
#  ->('1_find_answer', 9, '........11................010111.........', 231)
#  ->('write_1', 10, '........11................010111.........', 230)
#  ->('find_start_of_sum', 11, '........111...............010111.........', 229)
#  ->('find_start_of_sum', 12, '........111...............010111.........', 228)
#  ->('find_start_of_sum', 13, '........111...............010111.........', 227)
#  ->('find_start_of_sum', 14, '........111...............010111.........', 226)
#  ->('find_start_of_sum', 15, '........111...............010111.........', 225)
#  ->('find_start_of_sum', 16, '........111...............010111.........', 224)
#  ->('find_start_of_sum', 17, '........111...............010111.........', 223)
#  ->('find_start_of_sum', 18, '........111...............010111.........', 222)
#  ->('find_start_of_sum', 19, '........111...............010111.........', 221)
#  ->('find_start_of_sum', 20, '........111...............010111.........', 220)
#  ->('find_start_of_sum', 21, '........111...............010111.........', 219)
#  ->('find_start_of_sum', 22, '........111...............010111.........', 218)
#  ->('find_start_of_sum', 23, '........111...............010111.........', 217)
#  ->('find_start_of_sum', 24, '........111...............010111.........', 216)
#  ->('find_start_of_sum', 25, '........111...............010111.........', 215)
#  ->('find_start_of_sum', 26, '........111...............010111.........', 214)
#  ->('find_end_of_sum', 26, '........111...............010111.........', 213)
#  ->('find_end_of_sum', 27, '........111...............010111.........', 212)
#  ->('find_end_of_sum', 28, '........111...............010111.........', 211)
#  ->('find_end_of_sum', 29, '........111...............010111.........', 210)
#  ->('find_end_of_sum', 30, '........111...............010111.........', 209)
#  ->('find_end_of_sum', 31, '........111...............010111.........', 208)
#  ->('find_end_of_sum', 32, '........111...............010111.........', 207)
#  ->('read_msb_of_sum', 31, '........111...............010111.........', 206)
#  ->('1_check_end_of_sum', 30, '........111...............01011..........', 205)
#  ->('1_find_end_of_sum', 29, '........111...............01011..........', 204)
#  ->('1_find_end_of_sum', 28, '........111...............01011..........', 203)
#  ->('1_find_end_of_sum', 27, '........111...............01011..........', 202)
#  ->('1_find_end_of_sum', 26, '........111...............01011..........', 201)
#  ->('1_find_end_of_sum', 25, '........111...............01011..........', 200)
#  ->('1_find_answer', 24, '........111...............01011..........', 199)
#  ->('1_find_answer', 23, '........111...............01011..........', 198)
#  ->('1_find_answer', 22, '........111...............01011..........', 197)
#  ->('1_find_answer', 21, '........111...............01011..........', 196)
#  ->('1_find_answer', 20, '........111...............01011..........', 195)
#  ->('1_find_answer', 19, '........111...............01011..........', 194)
#  ->('1_find_answer', 18, '........111...............01011..........', 193)
#  ->('1_find_answer', 17, '........111...............01011..........', 192)
#  ->('1_find_answer', 16, '........111...............01011..........', 191)
#  ->('1_find_answer', 15, '........111...............01011..........', 190)
#  ->('1_find_answer', 14, '........111...............01011..........', 189)
#  ->('1_find_answer', 13, '........111...............01011..........', 188)
#  ->('1_find_answer', 12, '........111...............01011..........', 187)
#  ->('1_find_answer', 11, '........111...............01011..........', 186)
#  ->('1_find_answer', 10, '........111...............01011..........', 185)
#  ->('write_1', 11, '........111...............01011..........', 184)
#  ->('find_start_of_sum', 12, '........1111..............01011..........', 183)
#  ->('find_start_of_sum', 13, '........1111..............01011..........', 182)
#  ->('find_start_of_sum', 14, '........1111..............01011..........', 181)
#  ->('find_start_of_sum', 15, '........1111..............01011..........', 180)
#  ->('find_start_of_sum', 16, '........1111..............01011..........', 179)
#  ->('find_start_of_sum', 17, '........1111..............01011..........', 178)
#  ->('find_start_of_sum', 18, '........1111..............01011..........', 177)
#  ->('find_start_of_sum', 19, '........1111..............01011..........', 176)
#  ->('find_start_of_sum', 20, '........1111..............01011..........', 175)
#  ->('find_start_of_sum', 21, '........1111..............01011..........', 174)
#  ->('find_start_of_sum', 22, '........1111..............01011..........', 173)
#  ->('find_start_of_sum', 23, '........1111..............01011..........', 172)
#  ->('find_start_of_sum', 24, '........1111..............01011..........', 171)
#  ->('find_start_of_sum', 25, '........1111..............01011..........', 170)
#  ->('find_start_of_sum', 26, '........1111..............01011..........', 169)
#  ->('find_end_of_sum', 26, '........1111..............01011..........', 168)
#  ->('find_end_of_sum', 27, '........1111..............01011..........', 167)
#  ->('find_end_of_sum', 28, '........1111..............01011..........', 166)
#  ->('find_end_of_sum', 29, '........1111..............01011..........', 165)
#  ->('find_end_of_sum', 30, '........1111..............01011..........', 164)
#  ->('find_end_of_sum', 31, '........1111..............01011..........', 163)
#  ->('read_msb_of_sum', 30, '........1111..............01011..........', 162)
#  ->('1_check_end_of_sum', 29, '........1111..............0101...........', 161)
#  ->('1_find_end_of_sum', 28, '........1111..............0101...........', 160)
#  ->('1_find_end_of_sum', 27, '........1111..............0101...........', 159)
#  ->('1_find_end_of_sum', 26, '........1111..............0101...........', 158)
#  ->('1_find_end_of_sum', 25, '........1111..............0101...........', 157)
#  ->('1_find_answer', 24, '........1111..............0101...........', 156)
#  ->('1_find_answer', 23, '........1111..............0101...........', 155)
#  ->('1_find_answer', 22, '........1111..............0101...........', 154)
#  ->('1_find_answer', 21, '........1111..............0101...........', 153)
#  ->('1_find_answer', 20, '........1111..............0101...........', 152)
#  ->('1_find_answer', 19, '........1111..............0101...........', 151)
#  ->('1_find_answer', 18, '........1111..............0101...........', 150)
#  ->('1_find_answer', 17, '........1111..............0101...........', 149)
#  ->('1_find_answer', 16, '........1111..............0101...........', 148)
#  ->('1_find_answer', 15, '........1111..............0101...........', 147)
#  ->('1_find_answer', 14, '........1111..............0101...........', 146)
#  ->('1_find_answer', 13, '........1111..............0101...........', 145)
#  ->('1_find_answer', 12, '........1111..............0101...........', 144)
#  ->('1_find_answer', 11, '........1111..............0101...........', 143)
#  ->('write_1', 12, '........1111..............0101...........', 142)
#  ->('find_start_of_sum', 13, '........11111.............0101...........', 141)
#  ->('find_start_of_sum', 14, '........11111.............0101...........', 140)
#  ->('find_start_of_sum', 15, '........11111.............0101...........', 139)
#  ->('find_start_of_sum', 16, '........11111.............0101...........', 138)
#  ->('find_start_of_sum', 17, '........11111.............0101...........', 137)
#  ->('find_start_of_sum', 18, '........11111.............0101...........', 136)
#  ->('find_start_of_sum', 19, '........11111.............0101...........', 135)
#  ->('find_start_of_sum', 20, '........11111.............0101...........', 134)
#  ->('find_start_of_sum', 21, '........11111.............0101...........', 133)
#  ->('find_start_of_sum', 22, '........11111.............0101...........', 132)
#  ->('find_start_of_sum', 23, '........11111.............0101...........', 131)
#  ->('find_start_of_sum', 24, '........11111.............0101...........', 130)
#  ->('find_start_of_sum', 25, '........11111.............0101...........', 129)
#  ->('find_start_of_sum', 26, '........11111.............0101...........', 128)
#  ->('find_end_of_sum', 26, '........11111.............0101...........', 127)
#  ->('find_end_of_sum', 27, '........11111.............0101...........', 126)
#  ->('find_end_of_sum', 28, '........11111.............0101...........', 125)
#  ->('find_end_of_sum', 29, '........11111.............0101...........', 124)
#  ->('find_end_of_sum', 30, '........11111.............0101...........', 123)
#  ->('read_msb_of_sum', 29, '........11111.............0101...........', 122)
#  ->('1_check_end_of_sum', 28, '........11111.............010............', 121)
#  ->('1_find_end_of_sum', 27, '........11111.............010............', 120)
#  ->('1_find_end_of_sum', 26, '........11111.............010............', 119)
#  ->('1_find_end_of_sum', 25, '........11111.............010............', 118)
#  ->('1_find_answer', 24, '........11111.............010............', 117)
#  ->('1_find_answer', 23, '........11111.............010............', 116)
#  ->('1_find_answer', 22, '........11111.............010............', 115)
#  ->('1_find_answer', 21, '........11111.............010............', 114)
#  ->('1_find_answer', 20, '........11111.............010............', 113)
#  ->('1_find_answer', 19, '........11111.............010............', 112)
#  ->('1_find_answer', 18, '........11111.............010............', 111)
#  ->('1_find_answer', 17, '........11111.............010............', 110)
#  ->('1_find_answer', 16, '........11111.............010............', 109)
#  ->('1_find_answer', 15, '........11111.............010............', 108)
#  ->('1_find_answer', 14, '........11111.............010............', 107)
#  ->('1_find_answer', 13, '........11111.............010............', 106)
#  ->('1_find_answer', 12, '........11111.............010............', 105)
#  ->('write_1', 13, '........11111.............010............', 104)
#  ->('find_start_of_sum', 14, '........111111............010............', 103)
#  ->('find_start_of_sum', 15, '........111111............010............', 102)
#  ->('find_start_of_sum', 16, '........111111............010............', 101)
#  ->('find_start_of_sum', 17, '........111111............010............', 100)
#  ->('find_start_of_sum', 18, '........111111............010............', 99)
#  ->('find_start_of_sum', 19, '........111111............010............', 98)
#  ->('find_start_of_sum', 20, '........111111............010............', 97)
#  ->('find_start_of_sum', 21, '........111111............010............', 96)
#  ->('find_start_of_sum', 22, '........111111............010............', 95)
#  ->('find_start_of_sum', 23, '........111111............010............', 94)
#  ->('find_start_of_sum', 24, '........111111............010............', 93)
#  ->('find_start_of_sum', 25, '........111111............010............', 92)
#  ->('find_start_of_sum', 26, '........111111............010............', 91)
#  ->('find_end_of_sum', 26, '........111111............010............', 90)
#  ->('find_end_of_sum', 27, '........111111............010............', 89)
#  ->('find_end_of_sum', 28, '........111111............010............', 88)
#  ->('find_end_of_sum', 29, '........111111............010............', 87)
#  ->('read_msb_of_sum', 28, '........111111............010............', 86)
#  ->('0_check_end_of_sum', 27, '........111111............01.............', 85)
#  ->('0_find_end_of_sum', 26, '........111111............01.............', 84)
#  ->('0_find_end_of_sum', 25, '........111111............01.............', 83)
#  ->('0_find_answer', 24, '........111111............01.............', 82)
#  ->('0_find_answer', 23, '........111111............01.............', 81)
#  ->('0_find_answer', 22, '........111111............01.............', 80)
#  ->('0_find_answer', 21, '........111111............01.............', 79)
#  ->('0_find_answer', 20, '........111111............01.............', 78)
#  ->('0_find_answer', 19, '........111111............01.............', 77)
#  ->('0_find_answer', 18, '........111111............01.............', 76)
#  ->('0_find_answer', 17, '........111111............01.............', 75)
#  ->('0_find_answer', 16, '........111111............01.............', 74)
#  ->('0_find_answer', 15, '........111111............01.............', 73)
#  ->('0_find_answer', 14, '........111111............01.............', 72)
#  ->('0_find_answer', 13, '........111111............01.............', 71)
#  ->('write_0', 14, '........111111............01.............', 70)
#  ->('find_start_of_sum', 15, '........1111110...........01.............', 69)
#  ->('find_start_of_sum', 16, '........1111110...........01.............', 68)
#  ->('find_start_of_sum', 17, '........1111110...........01.............', 67)
#  ->('find_start_of_sum', 18, '........1111110...........01.............', 66)
#  ->('find_start_of_sum', 19, '........1111110...........01.............', 65)
#  ->('find_start_of_sum', 20, '........1111110...........01.............', 64)
#  ->('find_start_of_sum', 21, '........1111110...........01.............', 63)
#  ->('find_start_of_sum', 22, '........1111110...........01.............', 62)
#  ->('find_start_of_sum', 23, '........1111110...........01.............', 61)
#  ->('find_start_of_sum', 24, '........1111110...........01.............', 60)
#  ->('find_start_of_sum', 25, '........1111110...........01.............', 59)
#  ->('find_start_of_sum', 26, '........1111110...........01.............', 58)
#  ->('find_end_of_sum', 26, '........1111110...........01.............', 57)
#  ->('find_end_of_sum', 27, '........1111110...........01.............', 56)
#  ->('find_end_of_sum', 28, '........1111110...........01.............', 55)
#  ->('read_msb_of_sum', 27, '........1111110...........01.............', 54)
#  ->('1_check_end_of_sum', 26, '........1111110...........0..............', 53)
#  ->('1_find_end_of_sum', 25, '........1111110...........0..............', 52)
#  ->('1_find_answer', 24, '........1111110...........0..............', 51)
#  ->('1_find_answer', 23, '........1111110...........0..............', 50)
#  ->('1_find_answer', 22, '........1111110...........0..............', 49)
#  ->('1_find_answer', 21, '........1111110...........0..............', 48)
#  ->('1_find_answer', 20, '........1111110...........0..............', 47)
#  ->('1_find_answer', 19, '........1111110...........0..............', 46)
#  ->('1_find_answer', 18, '........1111110...........0..............', 45)
#  ->('1_find_answer', 17, '........1111110...........0..............', 44)
#  ->('1_find_answer', 16, '........1111110...........0..............', 43)
#  ->('1_find_answer', 15, '........1111110...........0..............', 42)
#  ->('1_find_answer', 14, '........1111110...........0..............', 41)
#  ->('write_1', 15, '........1111110...........0..............', 40)
#  ->('find_start_of_sum', 16, '........11111101..........0..............', 39)
#  ->('find_start_of_sum', 17, '........11111101..........0..............', 38)
#  ->('find_start_of_sum', 18, '........11111101..........0..............', 37)
#  ->('find_start_of_sum', 19, '........11111101..........0..............', 36)
#  ->('find_start_of_sum', 20, '........11111101..........0..............', 35)
#  ->('find_start_of_sum', 21, '........11111101..........0..............', 34)
#  ->('find_start_of_sum', 22, '........11111101..........0..............', 33)
#  ->('find_start_of_sum', 23, '........11111101..........0..............', 32)
#  ->('find_start_of_sum', 24, '........11111101..........0..............', 31)
#  ->('find_start_of_sum', 25, '........11111101..........0..............', 30)
#  ->('find_start_of_sum', 26, '........11111101..........0..............', 29)
#  ->('find_end_of_sum', 26, '........11111101..........0..............', 28)
#  ->('find_end_of_sum', 27, '........11111101..........0..............', 27)
#  ->('read_msb_of_sum', 26, '........11111101..........0..............', 26)
#  ->('0_check_end_of_sum', 25, '........11111101.........................', 25)
#  ->('0_write_last_digit', 24, '........11111101.........................', 24)
#  ->('0_write_last_digit', 23, '........11111101.........................', 23)
#  ->('0_write_last_digit', 22, '........11111101.........................', 22)
#  ->('0_write_last_digit', 21, '........11111101.........................', 21)
#  ->('0_write_last_digit', 20, '........11111101.........................', 20)
#  ->('0_write_last_digit', 19, '........11111101.........................', 19)
#  ->('0_write_last_digit', 18, '........11111101.........................', 18)
#  ->('0_write_last_digit', 17, '........11111101.........................', 17)
#  ->('0_write_last_digit', 16, '........11111101.........................', 16)
#  ->('0_write_last_digit', 15, '........11111101.........................', 15)
#  ->('write_last_0', 16, '........11111101.........................', 14)
#  ->('find_start_of_answer', 16, '........111111010........................', 13)
#  ->('find_start_of_answer', 15, '........111111010........................', 12)
#  ->('find_start_of_answer', 14, '........111111010........................', 11)
#  ->('find_start_of_answer', 13, '........111111010........................', 10)
#  ->('find_start_of_answer', 12, '........111111010........................', 9)
#  ->('find_start_of_answer', 11, '........111111010........................', 8)
#  ->('find_start_of_answer', 10, '........111111010........................', 7)
#  ->('find_start_of_answer', 9, '........111111010........................', 6)
#  ->('find_start_of_answer', 8, '........111111010........................', 5)
#  ->('find_start_of_answer', 7, '........111111010........................', 4)
#  ->('erase_leading_zeros', 8, '........111111010........................', 3)
#  ->('done', 8, '........111111010........................', 2)

# %%
dec_doub = md2mc(src='File', fname='tmfiles/decimal_double_tm.tm')
dotObj_tm(dec_doub)

# %%
dotObj_tm(dec_doub, FuseEdges = True)

# %%
# Doubles the number given on the tape in decimal!
explore_tm(dec_doub, "231", 100)
# Out:
# Allocating  8  tape cells to the RIGHT!
# Allocating  8  tape cells to the LEFT!
# Detailing the halted configs now.
# Accepted at  ('f_done', 7, '........462........', 92)
#  via ..
#  ->('i_start', 0, '231', 100)
#  ->('goto_lsd', 1, '231', 99)
#  ->('goto_lsd', 2, '231', 98)
#  ->('goto_lsd', 3, '231', 97)
#  ->('0_carry', 2, '231........', 96)
#  ->('0_carry', 1, '232........', 95)
#  ->('0_carry', 0, '262........', 94)
#  ->('0_carry', 7, '........462........', 93)
#  ->('f_done', 7, '........462........', 92)

# %%
collatz_tm = md2mc(src='File', fname='tmfiles/collatz_tm.tm')
dotObj_tm(collatz_tm)

# %%
DOcollatz = dotObj_tm(collatz_tm, FuseEdges=True)
DOcollatz

# %%
DOcollatz.source
# Out:
# '// TO_St15\ndigraph {\n\tgraph [rankdir=LR]\n\t\tEMPTY [label="" shape=plaintext]\n\t\tgoto_lsb [label=goto_lsb peripheries=1 shape=circle]\n\t\t"01_fma" [label="01_fma" peripheries=1 shape=circle]\n\t\tcheck_n_eq_1 [label=check_n_eq_1 peripheries=1 shape=circle]\n\t\t"10_fma" [label="10_fma" peripheries=1 shape=circle]\n\t\t"00_fma" [label="00_fma" peripheries=1 shape=circle]\n\t\tbranch [label=branch peripheries=1 shape=circle]\n\t\terror [label=error peripheries=1 shape=circle]\n\t\ti_start [label=i_start peripheries=1 shape=circle]\n\t\tf_halt [label=f_halt peripheries=2 shape=circle]\n\t\t\tEMPTY -> i_start\n\t\t\ti_start -> i_start [label="0 ; .,R"]\n\t\t\ti_start -> goto_lsb [label="1 ; 1,R"]\n\t\t\ti_start -> error [label=". ; .,S"]\n\t\t\tgoto_lsb -> goto_lsb [label="0 ; 0,R \n 1 ; 1,R"]\n\t\t\tgoto_lsb -> branch [label=". ; .,L"]\n\t\t\tbranch -> branch [label="0 ; .,L"]\n\t\t\tbranch -> check_n_eq_1 [label="1 ; 1,L"]\n\t\t\tcheck_n_eq_1 -> "01_fma" [label="0 ; 0,R \n 1 ; 1,R"]\n\t\t\tcheck_n_eq_1 -> f_halt [label=". ; .,R"]\n\t\t\t"00_fma" -> "00_fma" [label="0 ; 0,L"]\n\t\t\t"00_fma" -> "01_fma" [label="1 ; 1,L"]\n\t\t\t"00_fma" -> goto_lsb [label=". ; .,R"]\n\t\t\t"01_fma" -> "00_fma" [label="0 ; 1,L"]\n\t\t\t"01_fma" -> "10_fma" [label="1 ; 0,L"]\n\t\t\t"01_fma" -> goto_lsb [label=". ; 1,R"]\n\t\t\t"10_fma" -> "01_fma" [label="0 ; 0,L \n . ; 0,L"]\n\t\t\t"10_fma" -> "10_fma" [label="1 ; 1,L"]\n}'

# %%
# Will loop if the Collatz ("3x+1") program will ever loop!
explore_tm(collatz_tm, "0110", 100)
# Out:
# Allocating  8  tape cells to the RIGHT!
# Allocating  8  tape cells to the LEFT!
# Detailing the halted configs now.
# Accepted at  ('f_halt', 5, '.....1..............', 65)
#  via ..
#  ->('i_start', 0, '0110', 100)
#  ->('i_start', 1, '.110', 99)
#  ->('goto_lsb', 2, '.110', 98)
#  ->('goto_lsb', 3, '.110', 97)
#  ->('goto_lsb', 4, '.110', 96)
#  ->('branch', 3, '.110........', 95)
#  ->('branch', 2, '.11.........', 94)
#  ->('check_n_eq_1', 1, '.11.........', 93)
#  ->('01_fma', 2, '.11.........', 92)
#  ->('10_fma', 1, '.10.........', 91)
#  ->('10_fma', 0, '.10.........', 90)
#  ->('01_fma', 7, '........010.........', 89)
#  ->('goto_lsb', 8, '.......1010.........', 88)
#  ->('goto_lsb', 9, '.......1010.........', 87)
#  ->('goto_lsb', 10, '.......1010.........', 86)
#  ->('goto_lsb', 11, '.......1010.........', 85)
#  ->('branch', 10, '.......1010.........', 84)
#  ->('branch', 9, '.......101..........', 83)
#  ->('check_n_eq_1', 8, '.......101..........', 82)
#  ->('01_fma', 9, '.......101..........', 81)
#  ->('10_fma', 8, '.......100..........', 80)
#  ->('01_fma', 7, '.......100..........', 79)
#  ->('10_fma', 6, '.......000..........', 78)
#  ->('01_fma', 5, '......0000..........', 77)
#  ->('goto_lsb', 6, '.....10000..........', 76)
#  ->('goto_lsb', 7, '.....10000..........', 75)
#  ->('goto_lsb', 8, '.....10000..........', 74)
#  ->('goto_lsb', 9, '.....10000..........', 73)
#  ->('goto_lsb', 10, '.....10000..........', 72)
#  ->('branch', 9, '.....10000..........', 71)
#  ->('branch', 8, '.....1000...........', 70)
#  ->('branch', 7, '.....100............', 69)
#  ->('branch', 6, '.....10.............', 68)
#  ->('branch', 5, '.....1..............', 67)
#  ->('check_n_eq_1', 4, '.....1..............', 66)
#  ->('f_halt', 5, '.....1..............', 65)

# %%
shiftl_tm = md2mc(src='File', fname='tmfiles/shift_left_tm.tm')
dotObj_tm(shiftl_tm)

# %%
dotObj_tm(shiftl_tm, FuseEdges=True)

# %%
explore_tm(shiftl_tm, "abaaba", 100)
# Out:
# Allocating  8  tape cells to the RIGHT!
# Allocating  8  tape cells to the LEFT!
# Detailing the halted configs now.
# Accepted at  ('f_done', 6, '.......abaab.a........', 86)
#  via ..
#  ->('i_start', 0, 'abaaba', 100)
#  ->('scan_to_end', 1, 'abaaba', 99)
#  ->('scan_to_end', 2, 'abaaba', 98)
#  ->('scan_to_end', 3, 'abaaba', 97)
#  ->('scan_to_end', 4, 'abaaba', 96)
#  ->('scan_to_end', 5, 'abaaba', 95)
#  ->('scan_to_end', 6, 'abaaba', 94)
#  ->('move_left', 5, 'abaaba........', 93)
#  ->('read', 4, 'abaaba........', 92)
#  ->('b_next', 3, 'abaa.a........', 91)
#  ->('a_next', 2, 'abab.a........', 90)
#  ->('a_next', 1, 'abab.a........', 89)
#  ->('b_next', 0, 'aaab.a........', 88)
#  ->('a_next', 7, '........baab.a........', 87)
#  ->('f_done', 6, '.......abaab.a........', 86)

# %%
shiftr_tm = md2mc(src='File', fname='tmfiles/shift_right_tm.tm')
dotObj_tm(shiftr_tm)

# %%
dotObj_tm(shiftr_tm, True)

# %%
explore_tm(shiftr_tm, "ababba", 100)
# Out:
# Allocating  8  tape cells to the RIGHT!
# Detailing the halted configs now.
# Accepted at  ('f_done', 6, 'a.babba.......', 93)
#  via ..
#  ->('i_move_right', 0, 'ababba', 100)
#  ->('read', 1, 'ababba', 99)
#  ->('b_next', 2, 'a.abba', 98)
#  ->('a_next', 3, 'a.bbba', 97)
#  ->('b_next', 4, 'a.baba', 96)
#  ->('b_next', 5, 'a.baba', 95)
#  ->('a_next', 6, 'a.babb', 94)
#  ->('f_done', 6, 'a.babba.......', 93)

# %%
flipperTM = md2mc('''TM
I : . ; ., S -> F
I : 0 ; 1, R -> I
I : 1 ; 0, R -> I
''')
DOflipperTM = dotObj_tm(flipperTM, FuseEdges=True)
DOflipperTM

# %%
explore_tm(flipperTM, "010011", 100)
# Out:
# Allocating  8  tape cells to the RIGHT!
# Detailing the halted configs now.
# Accepted at  ('F', 6, '101100........', 93)
#  via ..
#  ->('I', 0, '010011', 100)
#  ->('I', 1, '110011', 99)
#  ->('I', 2, '100011', 98)
#  ->('I', 3, '101011', 97)
#  ->('I', 4, '101111', 96)
#  ->('I', 5, '101101', 95)
#  ->('I', 6, '101100', 94)
#  ->('F', 6, '101100........', 93)

# %%
DOflipperTM.source
# Out:
# '// TO_St22\ndigraph {\n\tgraph [rankdir=LR]\n\t\tEMPTY [label="" shape=plaintext]\n\t\tI [label=I peripheries=1 shape=circle]\n\t\tF [label=F peripheries=2 shape=circle]\n\t\t\tEMPTY -> I\n\t\t\tI -> F [label=". ; .,S"]\n\t\t\tI -> I [label="1 ; 0,R \n 0 ; 1,R"]\n}'
