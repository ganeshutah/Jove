# %% [markdown]
# # Chapter 4 &mdash; How to Read the Jove Code
#
# **Concept 11 of the Chapter 4 decomposition:** *How to Read the Jove Code*
#
# Understand it enough to drive it. The `Def_*` files hold the machinery; `help(foo)` explains any function.
#
# ---
#
# *Run on Colab:* [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ganeshutah/Jove/blob/master/Chapter4-DFA/Concept-Reading-Jove-Code/Concept-Reading-Jove-Code.ipynb)
# *Or run locally from inside a Jove checkout.*

# %% [markdown]
# ## 0. Setup

# %%
# Run me first.  Works on Colab and on a local Jove checkout.
import os, subprocess, sys

def _git(*a):
    r = subprocess.run(('git',) + a, capture_output=True, text=True)
    return r.stdout.strip() if r.returncode == 0 else ''

REPO = 'https://github.com/ganeshutah/Jove'
try:                       # ---- Colab: clone once, pull thereafter ----
    import google.colab
    was = _git('-C', 'Jove', 'rev-parse', '--short', 'HEAD') if os.path.isdir('Jove') else ''
    if os.path.isdir('Jove') and not was:
        print('Jove: WARNING ./Jove exists but is not a git checkout -- left as is')
    elif was:
        _git('-C', 'Jove', 'pull', '-q', '--ff-only')
        now = _git('-C', 'Jove', 'rev-parse', '--short', 'HEAD')
        if now and now != was:
            print('Jove: PULLED  %s -> %s' % (was, now))
            print(_git('-C', 'Jove', 'log', '--oneline', was + '..' + now))
        else:
            print('Jove: PULLED  already current at %s' % (now or was))
    else:
        _git('clone', '-q', REPO, 'Jove')
        print('Jove: CLONED  at %s' % (_git('-C', 'Jove', 'rev-parse',
                                             '--short', 'HEAD') or '?'))
    JOVE = 'Jove'
except ImportError:        # ---- local: the checkout above Chapter<N>/ ----
    JOVE = next((p for p in ('../..', '../../..', '..', '.')
                 if os.path.isdir(os.path.join(p, 'jove'))), '../..')
    print('Jove: LOCAL   checkout at %s'
          % (_git('-C', JOVE, 'rev-parse', '--short', 'HEAD') or '?'))
sys.path.insert(0, JOVE)

# A session can already hold an OLDER jove in sys.modules.  The pull above
# updates the files on disk, but `import` would hand back the cached module --
# so a fixed library still behaves like the broken one.  Drop them first.
for _m in [k for k in list(sys.modules) if k == 'jove' or k.startswith('jove.')]:
    del sys.modules[_m]

from jove.Def_md2mc      import *
from jove.DotBashers     import *
from jove.Def_DFA        import *

import jove; print('Jove loaded from', list(jove.__path__)[0])

# %% [markdown]
# ## 1. The idea
#
#
# The book's stance: **understand the code enough to drive it**, as you understand a car
# enough to drive it &mdash; with occasional pushes to go deeper.
#
# * All important functions for a machine type live in **`Def_...`** files:
#   `Def_DFA`, `Def_NFA`, `Def_PDA`, `Def_TM`.
# * Each lists its functions at the end, and **`help(foo)`** explains any one.
# * The notebooks often carry **more detail** than the book's listings.

# %% [markdown]
# ## 2. Definitions

# %% [markdown]
# ### What is in `Def_DFA`?

# %%
import jove.Def_DFA as DD
fns = [n for n in dir(DD) if not n.startswith('_') and callable(getattr(DD, n))]
print("callables exported by Def_DFA:")
print("  ", ', '.join(sorted(fns)[:18]))

# %% [markdown]
# ### `help` on any of them

# %%
help(accepts_dfa)

# %% [markdown]
# <!-- nav-strip -->
#
# ---
#
# &larr;&nbsp;[Ch4&nbsp;10.&nbsp;Formal Acceptance: $\delta$, $\hat{\delta}$, and the `accepts` Predicate](https://colab.research.google.com/github/ganeshutah/Jove/blob/master/Chapter4-DFA/Concept-Delta-Hat-Acceptance/Concept-Delta-Hat-Acceptance.ipynb) &nbsp;&middot;&nbsp; [**Chapter 4** index](https://github.com/ganeshutah/Jove/blob/master/Chapter4-DFA/README.md) &nbsp;&middot;&nbsp; [Ch4&nbsp;12.&nbsp;The "Lasso" Shape of DFA](https://colab.research.google.com/github/ganeshutah/Jove/blob/master/Chapter4-DFA/Concept-Lasso-Shape/Concept-Lasso-Shape.ipynb)&nbsp;&rarr;
#
# ---

# %% [markdown]
# ## 3. Tests

# %% [markdown]
# The docstrings carry the In/Out contract.

# %%
for f in [step_dfa, run_dfa, accepts_dfa]:
    doc = (f.__doc__ or '').strip().split('\n')[0]
    print("%-14s %s" % (f.__name__, doc))
assert accepts_dfa.__doc__

# %% [markdown]
# Which module does a name come from? Useful when a star-import surprises you.

# %%
for f in [step_dfa, md2mc, dotObj_dfa]:
    print("%-12s from %s" % (f.__name__, f.__module__))

# %% [markdown]
# ## 4. Exercises
#
#
# 1. Run `help(min_dfa)`. What does its `state_name_mode` argument do?
# 2. Find the `Def_DFA` source and read `run_dfa_h`. Is it recursive or iterative?
# 3. List every Jove function whose name ends in `_dfa`.

# %%
# Your work for the exercises above.

# %% [markdown]
# ## 5. Where next

# %%
# Previous / next, and a search box for all 254 concepts.
# Type a chapter (Chapter7, ch7, NFA) or words from a title (pumping).
#
# Following a link opens a NEW Colab runtime. To pull another concept's
# definitions into THIS session instead:
#     load_here('Chapter7-NFA/Concept-...')
import os, sys
try:                       # usually already done by the Setup cell
    import jove
except ModuleNotFoundError:
    _p = next((p for p in ('Jove', '../..', '../../..', '..', '.')
               if os.path.isdir(os.path.join(p, 'jove'))), None)
    if _p:
        sys.path.insert(0, _p)
try:
    from jove.Nav import nav, load_here
    nav(here='Chapter4-DFA/Concept-Reading-Jove-Code')
except ModuleNotFoundError:
    print('Jove is not on the path yet.')
    print('Run the Setup cell at the top of this notebook, then re-run this one.')
